# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
import xgboost as xgb
import matplotlib.pyplot as plt
import openpyxl
from openpyxl.styles import PatternFill
from openpyxl.drawing.image import Image
from openpyxl import Workbook
import os
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib
from imblearn.over_sampling import RandomOverSampler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-1:  Model Initializing for Injury/Illness Details Prediction
print("start execution")

# directory to save models
model_dir = 'saved_models_additional_v2'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    
# set GPU acceleration
def setup_gpu_acceleration():
    try:
        from xgboost import XGBClassifier
        return XGBClassifier(tree_method='hist', device='cpu')
    except ImportError:
        print("Metal acceleration not available. Falling back to CPU.")
        return XGBClassifier(tree_method='hist', device='cpu')

# set checkpoints
def train_model_with_checkpoints(model, X_train, y_train, model_path, model_type="injury", checkpoint_interval=1, max_rounds=20):
    checkpoint_path = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint.pkl')
    checkpoint_file = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint_rounds.txt')
    start_iteration = 0

    # check if there's an existing model or checkpoint to resume from
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        model = joblib.load(model_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration
    elif os.path.exists(checkpoint_path):
        print(f"Resuming training from checkpoint: {checkpoint_path}")
        model = joblib.load(checkpoint_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration

        if os.path.exists(checkpoint_file):
            with open(checkpoint_file, 'r') as f:
                checkpoint_rounds = int(f.read().strip())
                print(f"Resuming from saved round: {checkpoint_rounds}")
                start_iteration = checkpoint_rounds

            if checkpoint_rounds is not None:
                start_iteration = checkpoint_rounds

    # training the model
    eval_set = [(X_train, y_train)]

    # if continuing from an existing model or checkpoint, resume training
    for i in range(start_iteration, max_rounds):
        model.fit(X_train, y_train, eval_set=eval_set, verbose=True, xgb_model=model.get_booster() if i > 0 else None)
        
        # save checkpoint after each round
        print(f"Saving model after iteration {i+1}")
        joblib.dump(model, checkpoint_path)  # save the model checkpoint
        
        # save the round checkpoint number
        with open(checkpoint_file, 'w') as f:
            f.write(str(i + 1))

    # save the final model
    joblib.dump(model, model_path)

    return model

# load training and testing data
train_df = pd.read_excel("cleaned_training_data_v3.xlsx")
test_df = pd.read_excel("cleaned_test_data_v3.xlsx")
realuse_df = pd.read_excel("cleaned_realuse_data_v3.xlsx")

# preprocessing the numeric features
numeric_features = ['Gender_m2f1', 'Menstruation_y1n0', 'Mood state', 'Energy levels',
                    'Muscle readiness', 'Academic Pressure', 'Diet Yesterday', 'Sleep quality',
                    'Sleep duration', 'sleep_score', 'total_training_load', 'total_training_duration',
                    'weekly_training_load', 'weekly_training_duration', 'ACWR', 'RTT', 'illed', 'injured']

# separate numeric features from the rest
X_train = train_df[numeric_features]
X_test = test_df[numeric_features]
X_real = realuse_df[numeric_features]

# preprocessing the text data

# combine text columns for illness and injury separately
illness_columns = ['Type of illness', 'Illness severity']
injury_columns = ['Injury location', 'Injury type', 'Injury severity']

# fill missing values with empty strings and concatenate the text columns
train_df['illness_text'] = train_df[illness_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_text'] = train_df[injury_columns].fillna('').agg(' '.join, axis=1)
test_df['illness_text'] = test_df[illness_columns].fillna('').agg(' '.join, axis=1)
test_df['injury_text'] = test_df[injury_columns].fillna('').agg(' '.join, axis=1)
realuse_df['illness_text'] = realuse_df[illness_columns].fillna('').agg(' '.join, axis=1)
realuse_df['injury_text'] = realuse_df[injury_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_information'] = train_df['injury_text'].fillna("No Injury")
train_df['illness_information'] = train_df['illness_text'].fillna("No Illness")
test_df['injury_information'] = test_df['injury_text'].fillna("No Injury")
test_df['illness_information'] = test_df['illness_text'].fillna("No Illness")
realuse_df['injury_information'] = realuse_df['injury_text'].fillna("No Injury")
realuse_df['illness_information'] = realuse_df['illness_text'].fillna("No Illness")

# vectorize the text data using TfidfVectorizer
tfidf_vectorizer_illness = TfidfVectorizer(max_features=500)
tfidf_vectorizer_injury = TfidfVectorizer(max_features=500)

# fit on training data, then transform test and real use data
X_illness_train = tfidf_vectorizer_illness.fit_transform(train_df['illness_information'])
X_injury_train = tfidf_vectorizer_injury.fit_transform(train_df['injury_information'])
# check feature dimensions
print("Training features for illness model:", X_illness_train.shape[1])
print("Injury train shape:", X_injury_train.shape)
print("Vocabulary size of TF-IDF Vectorizer:", len(tfidf_vectorizer_injury.get_feature_names_out()))


# save the vectorizers
print("Saving vectorizers...")
joblib.dump(tfidf_vectorizer_illness, os.path.join(model_dir, 'tfidf_vectorizer_illness.pkl'))
joblib.dump(tfidf_vectorizer_injury, os.path.join(model_dir, 'tfidf_vectorizer_injury.pkl'))

X_illness_test = tfidf_vectorizer_illness.transform(test_df['illness_information'])
X_injury_test = tfidf_vectorizer_injury.transform(test_df['injury_information'])
print("Injury test shape:", X_injury_test.shape)
X_illness_real = tfidf_vectorizer_illness.transform(realuse_df['illness_information'])
X_injury_real = tfidf_vectorizer_injury.transform(realuse_df['injury_information'])
# check feature dimensions for test and real-use data
print("Test features for illness model:", X_illness_test.shape[1])
print("Real-use features for illness model:", X_illness_real.shape[1])
print("Test features for injury model:",X_injury_train.shape)
print("Real-use features for injury model:",X_injury_test.shape)

# create an instance of RandomOverSampler
ros = RandomOverSampler(random_state=42)

# resample the training data based on illness and injury (use RandomOverSampler instead of SMOTE)
X_resampled_illness, y_resampled_illness = ros.fit_resample(X_illness_train, train_df['illness_information'])
X_resampled_injury, y_resampled_injury = ros.fit_resample(X_injury_train, train_df['injury_information'])

X_train_illness, X_test_illness, y_train_illness, y_test_illness = train_test_split(X_resampled_illness, y_resampled_illness, test_size=0.2, random_state=42)
X_train_injury, X_test_injury, y_train_injury, y_test_injury = train_test_split(X_resampled_injury, y_resampled_injury, test_size=0.2, random_state=42)
# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-2: Model Selection, Hyperparameters Fine Tuning, Training

# model file paths
rf_illness_model_path = os.path.join(model_dir, 'rf_model_illness.pkl')
rf_injury_model_path = os.path.join(model_dir, 'rf_model_injury.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_injury_model_path = os.path.join(model_dir, 'log_reg_model_injury.pkl')
xgb_illness_model_path = os.path.join(model_dir, 'xgb_model_illness.pkl')
xgb_injury_model_path = os.path.join(model_dir, 'xgb_model_injury.pkl')
xgb_illness_label_encoder_path = os.path.join(model_dir, 'xgb_illness_label_encoder.pkl')
xgb_injury_label_encoder_path = os.path.join(model_dir, 'xgb_injury_label_encoder.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_illness_label_encoder_path = os.path.join(model_dir, 'label_encoder_log_reg_illness.pkl')

# check if models are saved, and load them if available
def load_model(model_path):
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        return joblib.load(model_path)
    return None

# load existing models or train if they exist
best_rf_model_illness = load_model(rf_illness_model_path)
best_rf_model_injury = load_model(rf_injury_model_path)
best_log_reg_model_illness = load_model(log_reg_illness_model_path)
best_log_reg_model_injury = load_model(log_reg_injury_model_path)
best_xgb_model_illness = load_model(xgb_illness_model_path)
best_xgb_model_injury = load_model(xgb_injury_model_path)

# if no model is loaded, perform hyperparameter tuning and training
if best_rf_model_illness is None:
    # randomForest for illness prediction with predefined hyperparameters
    rf_param_illness = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_illness = RandomForestClassifier(random_state=42, **rf_param_illness)
    best_rf_model_illness.fit(X_train_illness, y_train_illness)
    joblib.dump(best_rf_model_illness, rf_illness_model_path)

if best_rf_model_injury is None:
    # randomForest for injury prediction with predefined hyperparameters
    rf_param_injury = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_injury = RandomForestClassifier(random_state=42, **rf_param_injury)
    best_rf_model_injury.fit(X_train_injury, y_train_injury)
    joblib.dump(best_rf_model_injury, rf_injury_model_path)

if best_log_reg_model_illness is None:
    # encode the string labels to numeric labels
    label_encoder_illness = LabelEncoder()
    y_train_illness_encoded = label_encoder_illness.fit_transform(y_train_illness)
    joblib.dump(label_encoder_illness, 'label_encoder_log_reg_illness.pkl')
    # get unique classes in the encoded labels
    unique_classes_illness = np.unique(y_train_illness_encoded)
    # calculate class weights
    class_weights_illness = compute_class_weight('balanced', classes=unique_classes_illness, y=y_train_illness_encoded)
    class_weight_dict_illness = dict(zip(unique_classes_illness, class_weights_illness))
    log_reg_param_illness = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_illness
    }
    best_log_reg_model_illness = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_illness)
    best_log_reg_model_illness.fit(X_train_illness, y_train_illness_encoded)
    joblib.dump(best_log_reg_model_illness, log_reg_illness_model_path)


if best_log_reg_model_injury is None:
    # encode the string labels to numeric labels
    label_encoder_injury = LabelEncoder()
    y_train_injury_encoded = label_encoder_injury.fit_transform(y_train_injury)
    joblib.dump(label_encoder_injury, 'label_encoder_log_reg_injury.pkl')
    # get unique classes in the encoded labels
    unique_classes_injury = np.unique(y_train_injury_encoded)
    # calculate class weights
    class_weights_injury = compute_class_weight('balanced', classes=unique_classes_injury, y=y_train_injury_encoded)
    class_weight_dict_injury = dict(zip(unique_classes_injury, class_weights_injury))
    log_reg_param_injury = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_injury
    }
    best_log_reg_model_injury = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_injury)
    best_log_reg_model_injury.fit(X_train_injury, y_train_injury_encoded)
    joblib.dump(best_log_reg_model_injury, log_reg_injury_model_path)

# function to encode the target variable
def handle_label_encoder(y_train, encoder_path):
    if os.path.exists(encoder_path):
        print(f"loading label encoder for xgb: {encoder_path}")
        encoder = joblib.load(encoder_path)
        y_encoded = encoder.transform(y_train) 
    else:
        print(f"creating new label encoder for xgb: {encoder_path}")
        encoder = LabelEncoder()
        y_encoded = encoder.fit_transform(y_train)
        joblib.dump(encoder, encoder_path)
    return y_encoded, encoder

print("\n" + "="*50 + " handling xgb illness label encoder " + "="*50)
y_train_illness_encoded, illness_encoder = handle_label_encoder(y_train_illness, xgb_illness_label_encoder_path)

print("\n" + "="*50 + " handling xgb injury label encoder " + "="*50)
y_train_injury_encoded, injury_encoder = handle_label_encoder(y_train_injury, xgb_injury_label_encoder_path)

if best_xgb_model_illness is None:
    # XGBoost for illness prediction with GPU acceleration
    positive_class_count_illness = sum(y_train_illness_encoded == 1)
    negative_class_count_illness = sum(y_train_illness_encoded == 0)

    if positive_class_count_illness > 0:
        scale_pos_weight_illness = negative_class_count_illness / positive_class_count_illness
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist', 
            'device': 'cpu',
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10,
            'scale_pos_weight': scale_pos_weight_illness
        }
    else:
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10
        }
    best_xgb_model_illness = xgb.XGBClassifier(random_state=42, **xgb_param_illness)
    best_xgb_model_illness = train_model_with_checkpoints(
        model=best_xgb_model_illness,
        X_train=X_train_illness,
        y_train=y_train_illness_encoded,
        model_path=xgb_illness_model_path,
        model_type="illness",
        checkpoint_interval=1,
        max_rounds=20
    )

if best_xgb_model_injury is None:
    # XGBoost for injury prediction with predefined hyperparameters
    positive_class_count_injury = np.sum(y_train_injury_encoded == 1)
    negative_class_count_injury = np.sum(y_train_injury_encoded == 0)
    if positive_class_count_injury > 0:
        scale_pos_weight_injury = negative_class_count_injury / positive_class_count_injury
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3,
            'scale_pos_weight': scale_pos_weight_injury
        }
    else:
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3
        }
    best_xgb_model_injury = xgb.XGBClassifier(random_state=42, **xgb_param_injury)
    best_xgb_model_injury = train_model_with_checkpoints(
        model=best_xgb_model_injury,
        X_train=X_train_injury,
        y_train=y_train_injury_encoded,
        model_path=xgb_injury_model_path,
        model_type="injury",
        checkpoint_interval=1,
        max_rounds=20
    )

# after GridSearchCV, we can use the best models for prediction:
y_pred_illness_rf_test = best_rf_model_illness.predict(X_illness_test)
y_pred_injury_rf_test = best_rf_model_injury.predict(X_injury_test)

log_reg_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
y_pred_illness_lr_test = best_log_reg_model_illness.predict(X_illness_test)
y_pred_illness_lr_test_labels = log_reg_label_encoder_illness.inverse_transform(y_pred_illness_lr_test)
log_reg_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
y_pred_injury_lr_test = best_log_reg_model_injury.predict(X_injury_test)
y_pred_injury_lr_test_labels = log_reg_label_encoder_injury.inverse_transform(y_pred_injury_lr_test)

y_pred_illness_xgb_test = best_xgb_model_illness.predict(X_illness_test)
y_pred_injury_xgb_test = best_xgb_model_injury.predict(X_injury_test)

# -----------------------------------------------------------------------------------------------------------------------------------------
# model evaluation for all illness prediction
print("Random Forest Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Confusion Matrix:")
cm_illness_rf_test = confusion_matrix(test_df['illness_information'], y_pred_illness_rf_test)
sns.heatmap(cm_illness_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_illness_lr_test = confusion_matrix(test_df['illness_information'], y_pred_illness_lr_test_labels)
# load the logistic regression label encoder for illness
lr_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
sns.heatmap(cm_illness_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_illness.classes_,
            yticklabels=lr_label_encoder_illness.classes_)
plt.title("Logistic Regression - Illness Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_illness = joblib.load(xgb_illness_label_encoder_path)
# convert predictions back to original labels
y_pred_illness_xgb_test_labels = label_encoder_illness.inverse_transform(y_pred_illness_xgb_test)
print("XGBoost Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Confusion Matrix:")
cm_illness_xgb_test = confusion_matrix(test_df['illness_information'], y_pred_illness_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_illness_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_illness.classes_,
            yticklabels=label_encoder_illness.classes_)
plt.title("XGBoost Illness Prediction - Confusion Matrix")
plt.show()

# model evaluation for all injury prediction
print("Random Forest Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Confusion Matrix:")
cm_injury_rf_test = confusion_matrix(test_df['injury_information'], y_pred_injury_rf_test)
sns.heatmap(cm_injury_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_injury_lr_test = confusion_matrix(test_df['injury_information'], y_pred_injury_lr_test_labels)
# load the logistic regression label encoder for injury
lr_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
sns.heatmap(cm_injury_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_injury.classes_,
            yticklabels=lr_label_encoder_injury.classes_)
plt.title("Logistic Regression - Injury Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_injury = joblib.load(xgb_injury_label_encoder_path)
# convert predictions back to original labels
y_pred_injury_xgb_test_labels = label_encoder_injury.inverse_transform(y_pred_injury_xgb_test)
print("XGBoost Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Confusion Matrix:")
cm_injury_xgb_test = confusion_matrix(test_df['injury_information'], y_pred_injury_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_injury_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_injury.classes_,
            yticklabels=label_encoder_injury.classes_)
plt.title("XGBoost Injury Prediction - Confusion Matrix")
plt.show()
# Out:
# start execution
# Training features for illness model: 19
# Injury train shape: (138640, 41)
# Vocabulary size of TF-IDF Vectorizer: 41
# Saving vectorizers...
# Injury test shape: (100107, 41)
# Test features for illness model: 19
# Real-use features for illness model: 19
# Test features for injury model: (138640, 41)
# Real-use features for injury model: (100107, 41)
#
# ================================================== handling xgb illness label encoder ==================================================
# creating new label encoder for xgb: saved_models_additional_v2/xgb_illness_label_encoder.pkl
#
# ================================================== handling xgb injury label encoder ==================================================
# creating new label encoder for xgb: saved_models_additional_v2/xgb_injury_label_encoder.pkl
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:1.98356
# [1]	validation_0-mlogloss:1.64422
# [2]	validation_0-mlogloss:1.40636
# [3]	validation_0-mlogloss:1.21864
# [4]	validation_0-mlogloss:1.07238
# [5]	validation_0-mlogloss:0.94845
# [6]	validation_0-mlogloss:0.84121
# [7]	validation_0-mlogloss:0.75045
# [8]	validation_0-mlogloss:0.67020
# [9]	validation_0-mlogloss:0.59992
# [10]	validation_0-mlogloss:0.53891
# [11]	validation_0-mlogloss:0.48399
# [12]	validation_0-mlogloss:0.43518
# [13]	validation_0-mlogloss:0.39217
# [14]	validation_0-mlogloss:0.35375
# [15]	validation_0-mlogloss:0.31922
# [16]	validation_0-mlogloss:0.28849
# [17]	validation_0-mlogloss:0.26083
# [18]	validation_0-mlogloss:0.23541
# [19]	validation_0-mlogloss:0.21255
# Saving model after iteration 1
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.37633
# [1]	validation_0-mlogloss:0.33068
# [2]	validation_0-mlogloss:0.29304
# [3]	validation_0-mlogloss:0.26149
# [4]	validation_0-mlogloss:0.23404
# [5]	validation_0-mlogloss:0.21039
# [6]	validation_0-mlogloss:0.18901
# [7]	validation_0-mlogloss:0.17003
# [8]	validation_0-mlogloss:0.15321
# [9]	validation_0-mlogloss:0.13817
# [10]	validation_0-mlogloss:0.12475
# [11]	validation_0-mlogloss:0.11271
# [12]	validation_0-mlogloss:0.10174
# [13]	validation_0-mlogloss:0.09187
# [14]	validation_0-mlogloss:0.08298
# [15]	validation_0-mlogloss:0.07497
# [16]	validation_0-mlogloss:0.06784
# [17]	validation_0-mlogloss:0.06131
# [18]	validation_0-mlogloss:0.05549
# [19]	validation_0-mlogloss:0.05020
# Saving model after iteration 2
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.17199
# [1]	validation_0-mlogloss:0.15169
# [2]	validation_0-mlogloss:0.13461
# [3]	validation_0-mlogloss:0.11997
# [4]	validation_0-mlogloss:0.10724
# [5]	validation_0-mlogloss:0.09609
# [6]	validation_0-mlogloss:0.08629
# [7]	validation_0-mlogloss:0.07758
# [8]	validation_0-mlogloss:0.06983
# [9]	validation_0-mlogloss:0.06292
# [10]	validation_0-mlogloss:0.05671
# [11]	validation_0-mlogloss:0.05115
# [12]	validation_0-mlogloss:0.04617
# [13]	validation_0-mlogloss:0.04167
# [14]	validation_0-mlogloss:0.03763
# [15]	validation_0-mlogloss:0.03398
# [16]	validation_0-mlogloss:0.03070
# [17]	validation_0-mlogloss:0.02774
# [18]	validation_0-mlogloss:0.02508
# [19]	validation_0-mlogloss:0.02267
# Saving model after iteration 3
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.07735
# [1]	validation_0-mlogloss:0.06947
# [2]	validation_0-mlogloss:0.06246
# [3]	validation_0-mlogloss:0.05622
# [4]	validation_0-mlogloss:0.05064
# [5]	validation_0-mlogloss:0.04565
# [6]	validation_0-mlogloss:0.04117
# [7]	validation_0-mlogloss:0.03715
# [8]	validation_0-mlogloss:0.03354
# [9]	validation_0-mlogloss:0.03028
# [10]	validation_0-mlogloss:0.02735
# [11]	validation_0-mlogloss:0.02471
# [12]	validation_0-mlogloss:0.02233
# [13]	validation_0-mlogloss:0.02018
# [14]	validation_0-mlogloss:0.01824
# [15]	validation_0-mlogloss:0.01650
# [16]	validation_0-mlogloss:0.01492
# [17]	validation_0-mlogloss:0.01349
# [18]	validation_0-mlogloss:0.01220
# [19]	validation_0-mlogloss:0.01103
# Saving model after iteration 4
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.04948
# [1]	validation_0-mlogloss:0.04459
# [2]	validation_0-mlogloss:0.04021
# [3]	validation_0-mlogloss:0.03627
# [4]	validation_0-mlogloss:0.03273
# [5]	validation_0-mlogloss:0.02955
# [6]	validation_0-mlogloss:0.02669
# [7]	validation_0-mlogloss:0.02411
# [8]	validation_0-mlogloss:0.02178
# [9]	validation_0-mlogloss:0.01968
# [10]	validation_0-mlogloss:0.01779
# [11]	validation_0-mlogloss:0.01608
# [12]	validation_0-mlogloss:0.01454
# [13]	validation_0-mlogloss:0.01315
# [14]	validation_0-mlogloss:0.01189
# [15]	validation_0-mlogloss:0.01075
# [16]	validation_0-mlogloss:0.00972
# [17]	validation_0-mlogloss:0.00879
# [18]	validation_0-mlogloss:0.00795
# [19]	validation_0-mlogloss:0.00719
# Saving model after iteration 5
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03094
# [1]	validation_0-mlogloss:0.02793
# [2]	validation_0-mlogloss:0.02522
# [3]	validation_0-mlogloss:0.02278
# [4]	validation_0-mlogloss:0.02058
# [5]	validation_0-mlogloss:0.01859
# [6]	validation_0-mlogloss:0.01680
# [7]	validation_0-mlogloss:0.01519
# [8]	validation_0-mlogloss:0.01373
# [9]	validation_0-mlogloss:0.01241
# [10]	validation_0-mlogloss:0.01122
# [11]	validation_0-mlogloss:0.01015
# [12]	validation_0-mlogloss:0.00918
# [13]	validation_0-mlogloss:0.00830
# [14]	validation_0-mlogloss:0.00751
# [15]	validation_0-mlogloss:0.00679
# [16]	validation_0-mlogloss:0.00614
# [17]	validation_0-mlogloss:0.00556
# [18]	validation_0-mlogloss:0.00503
# [19]	validation_0-mlogloss:0.00455
# Saving model after iteration 6
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02316
# [1]	validation_0-mlogloss:0.02092
# [2]	validation_0-mlogloss:0.01890
# [3]	validation_0-mlogloss:0.01708
# [4]	validation_0-mlogloss:0.01543
# [5]	validation_0-mlogloss:0.01395
# [6]	validation_0-mlogloss:0.01261
# [7]	validation_0-mlogloss:0.01140
# [8]	validation_0-mlogloss:0.01031
# [9]	validation_0-mlogloss:0.00932
# [10]	validation_0-mlogloss:0.00843
# [11]	validation_0-mlogloss:0.00762
# [12]	validation_0-mlogloss:0.00690
# [13]	validation_0-mlogloss:0.00624
# [14]	validation_0-mlogloss:0.00564
# [15]	validation_0-mlogloss:0.00510
# [16]	validation_0-mlogloss:0.00462
# [17]	validation_0-mlogloss:0.00418
# [18]	validation_0-mlogloss:0.00378
# [19]	validation_0-mlogloss:0.00342
# Saving model after iteration 7
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01683
# [1]	validation_0-mlogloss:0.01521
# [2]	validation_0-mlogloss:0.01374
# [3]	validation_0-mlogloss:0.01242
# [4]	validation_0-mlogloss:0.01123
# [5]	validation_0-mlogloss:0.01016
# [6]	validation_0-mlogloss:0.00918
# [7]	validation_0-mlogloss:0.00830
# [8]	validation_0-mlogloss:0.00751
# [9]	validation_0-mlogloss:0.00679
# [10]	validation_0-mlogloss:0.00614
# [11]	validation_0-mlogloss:0.00556
# [12]	validation_0-mlogloss:0.00503
# [13]	validation_0-mlogloss:0.00455
# [14]	validation_0-mlogloss:0.00411
# [15]	validation_0-mlogloss:0.00372
# [16]	validation_0-mlogloss:0.00337
# [17]	validation_0-mlogloss:0.00305
# [18]	validation_0-mlogloss:0.00276
# [19]	validation_0-mlogloss:0.00249
# Saving model after iteration 8
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01151
# [1]	validation_0-mlogloss:0.01040
# [2]	validation_0-mlogloss:0.00941
# [3]	validation_0-mlogloss:0.00851
# [4]	validation_0-mlogloss:0.00769
# [5]	validation_0-mlogloss:0.00696
# [6]	validation_0-mlogloss:0.00629
# [7]	validation_0-mlogloss:0.00569
# [8]	validation_0-mlogloss:0.00515
# [9]	validation_0-mlogloss:0.00466
# [10]	validation_0-mlogloss:0.00422
# [11]	validation_0-mlogloss:0.00381
# [12]	validation_0-mlogloss:0.00345
# [13]	validation_0-mlogloss:0.00312
# [14]	validation_0-mlogloss:0.00283
# [15]	validation_0-mlogloss:0.00256
# [16]	validation_0-mlogloss:0.00231
# [17]	validation_0-mlogloss:0.00209
# [18]	validation_0-mlogloss:0.00189
# [19]	validation_0-mlogloss:0.00171
# Saving model after iteration 9
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:29:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00916
# [1]	validation_0-mlogloss:0.00828
# [2]	validation_0-mlogloss:0.00749
# [3]	validation_0-mlogloss:0.00677
# [4]	validation_0-mlogloss:0.00613
# [5]	validation_0-mlogloss:0.00554
# [6]	validation_0-mlogloss:0.00501
# [7]	validation_0-mlogloss:0.00454
# [8]	validation_0-mlogloss:0.00410
# [9]	validation_0-mlogloss:0.00371
# [10]	validation_0-mlogloss:0.00336
# [11]	validation_0-mlogloss:0.00304
# [12]	validation_0-mlogloss:0.00275
# [13]	validation_0-mlogloss:0.00249
# [14]	validation_0-mlogloss:0.00225
# [15]	validation_0-mlogloss:0.00204
# [16]	validation_0-mlogloss:0.00184
# [17]	validation_0-mlogloss:0.00167
# [18]	validation_0-mlogloss:0.00151
# [19]	validation_0-mlogloss:0.00137
# Saving model after iteration 10
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:30:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00565
# [1]	validation_0-mlogloss:0.00511
# [2]	validation_0-mlogloss:0.00462
# [3]	validation_0-mlogloss:0.00418
# [4]	validation_0-mlogloss:0.00379
# [5]	validation_0-mlogloss:0.00342
# [6]	validation_0-mlogloss:0.00310
# [7]	validation_0-mlogloss:0.00280
# [8]	validation_0-mlogloss:0.00254
# [9]	validation_0-mlogloss:0.00230
# [10]	validation_0-mlogloss:0.00208
# [11]	validation_0-mlogloss:0.00188
# [12]	validation_0-mlogloss:0.00170
# [13]	validation_0-mlogloss:0.00154
# [14]	validation_0-mlogloss:0.00139
# [15]	validation_0-mlogloss:0.00126
# [16]	validation_0-mlogloss:0.00114
# [17]	validation_0-mlogloss:0.00103
# [18]	validation_0-mlogloss:0.00094
# [19]	validation_0-mlogloss:0.00085
# Saving model after iteration 11
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:30:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00431
# [1]	validation_0-mlogloss:0.00390
# [2]	validation_0-mlogloss:0.00353
# [3]	validation_0-mlogloss:0.00320
# [4]	validation_0-mlogloss:0.00289
# [5]	validation_0-mlogloss:0.00262
# [6]	validation_0-mlogloss:0.00237
# [7]	validation_0-mlogloss:0.00214
# [8]	validation_0-mlogloss:0.00194
# [9]	validation_0-mlogloss:0.00175
# [10]	validation_0-mlogloss:0.00159
# [11]	validation_0-mlogloss:0.00144
# [12]	validation_0-mlogloss:0.00130
# [13]	validation_0-mlogloss:0.00118
# [14]	validation_0-mlogloss:0.00107
# [15]	validation_0-mlogloss:0.00097
# [16]	validation_0-mlogloss:0.00087
# [17]	validation_0-mlogloss:0.00079
# [18]	validation_0-mlogloss:0.00072
# [19]	validation_0-mlogloss:0.00065
# Saving model after iteration 12
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:30:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00421
# [1]	validation_0-mlogloss:0.00381
# [2]	validation_0-mlogloss:0.00344
# [3]	validation_0-mlogloss:0.00312
# [4]	validation_0-mlogloss:0.00282
# [5]	validation_0-mlogloss:0.00255
# [6]	validation_0-mlogloss:0.00231
# [7]	validation_0-mlogloss:0.00209
# [8]	validation_0-mlogloss:0.00189
# [9]	validation_0-mlogloss:0.00171
# [10]	validation_0-mlogloss:0.00155
# [11]	validation_0-mlogloss:0.00140
# [12]	validation_0-mlogloss:0.00127
# [13]	validation_0-mlogloss:0.00115
# [14]	validation_0-mlogloss:0.00104
# [15]	validation_0-mlogloss:0.00094
# [16]	validation_0-mlogloss:0.00085
# [17]	validation_0-mlogloss:0.00077
# [18]	validation_0-mlogloss:0.00070
# [19]	validation_0-mlogloss:0.00063
# Saving model after iteration 13
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:30:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00446
# [1]	validation_0-mlogloss:0.00403
# [2]	validation_0-mlogloss:0.00365
# [3]	validation_0-mlogloss:0.00330
# [4]	validation_0-mlogloss:0.00299
# [5]	validation_0-mlogloss:0.00270
# [6]	validation_0-mlogloss:0.00245
# [7]	validation_0-mlogloss:0.00221
# [8]	validation_0-mlogloss:0.00200
# [9]	validation_0-mlogloss:0.00181
# [10]	validation_0-mlogloss:0.00164
# [11]	validation_0-mlogloss:0.00148
# [12]	validation_0-mlogloss:0.00134
# [13]	validation_0-mlogloss:0.00122
# [14]	validation_0-mlogloss:0.00110
# [15]	validation_0-mlogloss:0.00100
# [16]	validation_0-mlogloss:0.00090
# [17]	validation_0-mlogloss:0.00082
# [18]	validation_0-mlogloss:0.00074
# [19]	validation_0-mlogloss:0.00067
# Saving model after iteration 14
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:30:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00424
# [1]	validation_0-mlogloss:0.00384
# [2]	validation_0-mlogloss:0.00347
# [3]	validation_0-mlogloss:0.00314
# [4]	validation_0-mlogloss:0.00284
# [5]	validation_0-mlogloss:0.00257
# [6]	validation_0-mlogloss:0.00233
# [7]	validation_0-mlogloss:0.00211
# [8]	validation_0-mlogloss:0.00191
# [9]	validation_0-mlogloss:0.00172
# [10]	validation_0-mlogloss:0.00156
# [11]	validation_0-mlogloss:0.00141
# [12]	validation_0-mlogloss:0.00128
# [13]	validation_0-mlogloss:0.00116
# [14]	validation_0-mlogloss:0.00105
# [15]	validation_0-mlogloss:0.00095
# [16]	validation_0-mlogloss:0.00086
# [17]	validation_0-mlogloss:0.00078
# [18]	validation_0-mlogloss:0.00070
# [19]	validation_0-mlogloss:0.00064
# Saving model after iteration 15
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:30:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00559
# [1]	validation_0-mlogloss:0.00506
# [2]	validation_0-mlogloss:0.00457
# [3]	validation_0-mlogloss:0.00414
# [4]	validation_0-mlogloss:0.00374
# [5]	validation_0-mlogloss:0.00339
# [6]	validation_0-mlogloss:0.00306
# [7]	validation_0-mlogloss:0.00277
# [8]	validation_0-mlogloss:0.00251
# [9]	validation_0-mlogloss:0.00227
# [10]	validation_0-mlogloss:0.00205
# [11]	validation_0-mlogloss:0.00186
# [12]	validation_0-mlogloss:0.00168
# [13]	validation_0-mlogloss:0.00152
# [14]	validation_0-mlogloss:0.00138
# [15]	validation_0-mlogloss:0.00125
# [16]	validation_0-mlogloss:0.00113
# [17]	validation_0-mlogloss:0.00102
# [18]	validation_0-mlogloss:0.00093
# [19]	validation_0-mlogloss:0.00084
# Saving model after iteration 16
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:31:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00649
# [1]	validation_0-mlogloss:0.00587
# [2]	validation_0-mlogloss:0.00531
# [3]	validation_0-mlogloss:0.00480
# [4]	validation_0-mlogloss:0.00434
# [5]	validation_0-mlogloss:0.00393
# [6]	validation_0-mlogloss:0.00355
# [7]	validation_0-mlogloss:0.00321
# [8]	validation_0-mlogloss:0.00291
# [9]	validation_0-mlogloss:0.00263
# [10]	validation_0-mlogloss:0.00238
# [11]	validation_0-mlogloss:0.00215
# [12]	validation_0-mlogloss:0.00195
# [13]	validation_0-mlogloss:0.00176
# [14]	validation_0-mlogloss:0.00160
# [15]	validation_0-mlogloss:0.00144
# [16]	validation_0-mlogloss:0.00131
# [17]	validation_0-mlogloss:0.00118
# [18]	validation_0-mlogloss:0.00107
# [19]	validation_0-mlogloss:0.00097
# Saving model after iteration 17
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:31:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00879
# [1]	validation_0-mlogloss:0.00795
# [2]	validation_0-mlogloss:0.00718
# [3]	validation_0-mlogloss:0.00650
# [4]	validation_0-mlogloss:0.00588
# [5]	validation_0-mlogloss:0.00531
# [6]	validation_0-mlogloss:0.00481
# [7]	validation_0-mlogloss:0.00435
# [8]	validation_0-mlogloss:0.00393
# [9]	validation_0-mlogloss:0.00356
# [10]	validation_0-mlogloss:0.00322
# [11]	validation_0-mlogloss:0.00291
# [12]	validation_0-mlogloss:0.00263
# [13]	validation_0-mlogloss:0.00238
# [14]	validation_0-mlogloss:0.00216
# [15]	validation_0-mlogloss:0.00195
# [16]	validation_0-mlogloss:0.00177
# [17]	validation_0-mlogloss:0.00160
# [18]	validation_0-mlogloss:0.00145
# [19]	validation_0-mlogloss:0.00131
# Saving model after iteration 18
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:31:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01005
# [1]	validation_0-mlogloss:0.00908
# [2]	validation_0-mlogloss:0.00821
# [3]	validation_0-mlogloss:0.00742
# [4]	validation_0-mlogloss:0.00671
# [5]	validation_0-mlogloss:0.00607
# [6]	validation_0-mlogloss:0.00549
# [7]	validation_0-mlogloss:0.00496
# [8]	validation_0-mlogloss:0.00449
# [9]	validation_0-mlogloss:0.00406
# [10]	validation_0-mlogloss:0.00367
# [11]	validation_0-mlogloss:0.00332
# [12]	validation_0-mlogloss:0.00301
# [13]	validation_0-mlogloss:0.00272
# [14]	validation_0-mlogloss:0.00246
# [15]	validation_0-mlogloss:0.00223
# [16]	validation_0-mlogloss:0.00201
# [17]	validation_0-mlogloss:0.00182
# [18]	validation_0-mlogloss:0.00165
# [19]	validation_0-mlogloss:0.00149
# Saving model after iteration 19
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:31:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01242
# [1]	validation_0-mlogloss:0.01122
# [2]	validation_0-mlogloss:0.01014
# [3]	validation_0-mlogloss:0.00916
# [4]	validation_0-mlogloss:0.00828
# [5]	validation_0-mlogloss:0.00749
# [6]	validation_0-mlogloss:0.00677
# [7]	validation_0-mlogloss:0.00612
# [8]	validation_0-mlogloss:0.00554
# [9]	validation_0-mlogloss:0.00501
# [10]	validation_0-mlogloss:0.00453
# [11]	validation_0-mlogloss:0.00410
# [12]	validation_0-mlogloss:0.00371
# [13]	validation_0-mlogloss:0.00335
# [14]	validation_0-mlogloss:0.00303
# [15]	validation_0-mlogloss:0.00274
# [16]	validation_0-mlogloss:0.00248
# [17]	validation_0-mlogloss:0.00225
# [18]	validation_0-mlogloss:0.00203
# [19]	validation_0-mlogloss:0.00184
# Saving model after iteration 20
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:32:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.30271
# [1]	validation_0-mlogloss:0.24489
# [2]	validation_0-mlogloss:0.22138
# [3]	validation_0-mlogloss:0.20001
# [4]	validation_0-mlogloss:0.18074
# [5]	validation_0-mlogloss:0.16343
# [6]	validation_0-mlogloss:0.14788
# [7]	validation_0-mlogloss:0.13370
# [8]	validation_0-mlogloss:0.12091
# [9]	validation_0-mlogloss:0.10937
# [10]	validation_0-mlogloss:0.09900
# [11]	validation_0-mlogloss:0.08962
# [12]	validation_0-mlogloss:0.08108
# [13]	validation_0-mlogloss:0.07335
# [14]	validation_0-mlogloss:0.06635
# [15]	validation_0-mlogloss:0.06004
# [16]	validation_0-mlogloss:0.05432
# [17]	validation_0-mlogloss:0.04915
# [18]	validation_0-mlogloss:0.04446
# [19]	validation_0-mlogloss:0.04024
# Saving model after iteration 1
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:35:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.44731
# [1]	validation_0-mlogloss:0.38324
# [2]	validation_0-mlogloss:0.33853
# [3]	validation_0-mlogloss:0.30090
# [4]	validation_0-mlogloss:0.26865
# [5]	validation_0-mlogloss:0.24055
# [6]	validation_0-mlogloss:0.21580
# [7]	validation_0-mlogloss:0.19390
# [8]	validation_0-mlogloss:0.17450
# [9]	validation_0-mlogloss:0.15718
# [10]	validation_0-mlogloss:0.14174
# [11]	validation_0-mlogloss:0.12785
# [12]	validation_0-mlogloss:0.11540
# [13]	validation_0-mlogloss:0.10421
# [14]	validation_0-mlogloss:0.09411
# [15]	validation_0-mlogloss:0.08503
# [16]	validation_0-mlogloss:0.07687
# [17]	validation_0-mlogloss:0.06948
# [18]	validation_0-mlogloss:0.06281
# [19]	validation_0-mlogloss:0.05679
# Saving model after iteration 2
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:40:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.49115
# [1]	validation_0-mlogloss:0.41786
# [2]	validation_0-mlogloss:0.36408
# [3]	validation_0-mlogloss:0.32050
# [4]	validation_0-mlogloss:0.28405
# [5]	validation_0-mlogloss:0.25293
# [6]	validation_0-mlogloss:0.22599
# [7]	validation_0-mlogloss:0.20244
# [8]	validation_0-mlogloss:0.18168
# [9]	validation_0-mlogloss:0.16329
# [10]	validation_0-mlogloss:0.14695
# [11]	validation_0-mlogloss:0.13238
# [12]	validation_0-mlogloss:0.11934
# [13]	validation_0-mlogloss:0.10765
# [14]	validation_0-mlogloss:0.09715
# [15]	validation_0-mlogloss:0.08774
# [16]	validation_0-mlogloss:0.07926
# [17]	validation_0-mlogloss:0.07160
# [18]	validation_0-mlogloss:0.06470
# [19]	validation_0-mlogloss:0.05848
# Saving model after iteration 3
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:45:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.43676
# [1]	validation_0-mlogloss:0.37147
# [2]	validation_0-mlogloss:0.32276
# [3]	validation_0-mlogloss:0.28369
# [4]	validation_0-mlogloss:0.25116
# [5]	validation_0-mlogloss:0.22347
# [6]	validation_0-mlogloss:0.19954
# [7]	validation_0-mlogloss:0.17865
# [8]	validation_0-mlogloss:0.16028
# [9]	validation_0-mlogloss:0.14402
# [10]	validation_0-mlogloss:0.12957
# [11]	validation_0-mlogloss:0.11673
# [12]	validation_0-mlogloss:0.10521
# [13]	validation_0-mlogloss:0.09488
# [14]	validation_0-mlogloss:0.08562
# [15]	validation_0-mlogloss:0.07730
# [16]	validation_0-mlogloss:0.06981
# [17]	validation_0-mlogloss:0.06307
# [18]	validation_0-mlogloss:0.05699
# [19]	validation_0-mlogloss:0.05151
# Saving model after iteration 4
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:51:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.36592
# [1]	validation_0-mlogloss:0.31252
# [2]	validation_0-mlogloss:0.27220
# [3]	validation_0-mlogloss:0.23963
# [4]	validation_0-mlogloss:0.21239
# [5]	validation_0-mlogloss:0.18920
# [6]	validation_0-mlogloss:0.16905
# [7]	validation_0-mlogloss:0.15143
# [8]	validation_0-mlogloss:0.13591
# [9]	validation_0-mlogloss:0.12216
# [10]	validation_0-mlogloss:0.10993
# [11]	validation_0-mlogloss:0.09904
# [12]	validation_0-mlogloss:0.08932
# [13]	validation_0-mlogloss:0.08056
# [14]	validation_0-mlogloss:0.07270
# [15]	validation_0-mlogloss:0.06564
# [16]	validation_0-mlogloss:0.05929
# [17]	validation_0-mlogloss:0.05356
# [18]	validation_0-mlogloss:0.04840
# [19]	validation_0-mlogloss:0.04375
# Saving model after iteration 5
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [13:57:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.26563
# [1]	validation_0-mlogloss:0.23078
# [2]	validation_0-mlogloss:0.20322
# [3]	validation_0-mlogloss:0.18016
# [4]	validation_0-mlogloss:0.16050
# [5]	validation_0-mlogloss:0.14347
# [6]	validation_0-mlogloss:0.12856
# [7]	validation_0-mlogloss:0.11542
# [8]	validation_0-mlogloss:0.10377
# [9]	validation_0-mlogloss:0.09340
# [10]	validation_0-mlogloss:0.08415
# [11]	validation_0-mlogloss:0.07587
# [12]	validation_0-mlogloss:0.06846
# [13]	validation_0-mlogloss:0.06179
# [14]	validation_0-mlogloss:0.05579
# [15]	validation_0-mlogloss:0.05039
# [16]	validation_0-mlogloss:0.04553
# [17]	validation_0-mlogloss:0.04115
# [18]	validation_0-mlogloss:0.03719
# [19]	validation_0-mlogloss:0.03362
# Saving model after iteration 6
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [14:08:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.18878
# [1]	validation_0-mlogloss:0.16553
# [2]	validation_0-mlogloss:0.14655
# [3]	validation_0-mlogloss:0.13049
# [4]	validation_0-mlogloss:0.11662
# [5]	validation_0-mlogloss:0.10450
# [6]	validation_0-mlogloss:0.09382
# [7]	validation_0-mlogloss:0.08436
# [8]	validation_0-mlogloss:0.07596
# [9]	validation_0-mlogloss:0.06844
# [10]	validation_0-mlogloss:0.06171
# [11]	validation_0-mlogloss:0.05568
# [12]	validation_0-mlogloss:0.05026
# [13]	validation_0-mlogloss:0.04539
# [14]	validation_0-mlogloss:0.04100
# [15]	validation_0-mlogloss:0.03704
# [16]	validation_0-mlogloss:0.03348
# [17]	validation_0-mlogloss:0.03026
# [18]	validation_0-mlogloss:0.02736
# [19]	validation_0-mlogloss:0.02474
# Saving model after iteration 7
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [14:16:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.13690
# [1]	validation_0-mlogloss:0.12129
# [2]	validation_0-mlogloss:0.10824
# [3]	validation_0-mlogloss:0.09679
# [4]	validation_0-mlogloss:0.08678
# [5]	validation_0-mlogloss:0.07794
# [6]	validation_0-mlogloss:0.07012
# [7]	validation_0-mlogloss:0.06315
# [8]	validation_0-mlogloss:0.05691
# [9]	validation_0-mlogloss:0.05133
# [10]	validation_0-mlogloss:0.04632
# [11]	validation_0-mlogloss:0.04182
# [12]	validation_0-mlogloss:0.03777
# [13]	validation_0-mlogloss:0.03412
# [14]	validation_0-mlogloss:0.03083
# [15]	validation_0-mlogloss:0.02787
# [16]	validation_0-mlogloss:0.02519
# [17]	validation_0-mlogloss:0.02277
# [18]	validation_0-mlogloss:0.02059
# [19]	validation_0-mlogloss:0.01862
# Saving model after iteration 8
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [14:24:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.10184
# [1]	validation_0-mlogloss:0.09014
# [2]	validation_0-mlogloss:0.08037
# [3]	validation_0-mlogloss:0.07194
# [4]	validation_0-mlogloss:0.06457
# [5]	validation_0-mlogloss:0.05805
# [6]	validation_0-mlogloss:0.05225
# [7]	validation_0-mlogloss:0.04708
# [8]	validation_0-mlogloss:0.04245
# [9]	validation_0-mlogloss:0.03831
# [10]	validation_0-mlogloss:0.03458
# [11]	validation_0-mlogloss:0.03124
# [12]	validation_0-mlogloss:0.02822
# [13]	validation_0-mlogloss:0.02550
# [14]	validation_0-mlogloss:0.02305
# [15]	validation_0-mlogloss:0.02083
# [16]	validation_0-mlogloss:0.01884
# [17]	validation_0-mlogloss:0.01703
# [18]	validation_0-mlogloss:0.01540
# [19]	validation_0-mlogloss:0.01393
# Saving model after iteration 9
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [14:33:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.07397
# [1]	validation_0-mlogloss:0.06519
# [2]	validation_0-mlogloss:0.05800
# [3]	validation_0-mlogloss:0.05186
# [4]	validation_0-mlogloss:0.04652
# [5]	validation_0-mlogloss:0.04180
# [6]	validation_0-mlogloss:0.03762
# [7]	validation_0-mlogloss:0.03389
# [8]	validation_0-mlogloss:0.03056
# [9]	validation_0-mlogloss:0.02757
# [10]	validation_0-mlogloss:0.02489
# [11]	validation_0-mlogloss:0.02248
# [12]	validation_0-mlogloss:0.02031
# [13]	validation_0-mlogloss:0.01835
# [14]	validation_0-mlogloss:0.01659
# [15]	validation_0-mlogloss:0.01499
# [16]	validation_0-mlogloss:0.01356
# [17]	validation_0-mlogloss:0.01226
# [18]	validation_0-mlogloss:0.01109
# [19]	validation_0-mlogloss:0.01003
# Saving model after iteration 10
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [14:43:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.05595
# [1]	validation_0-mlogloss:0.04908
# [2]	validation_0-mlogloss:0.04356
# [3]	validation_0-mlogloss:0.03889
# [4]	validation_0-mlogloss:0.03484
# [5]	validation_0-mlogloss:0.03129
# [6]	validation_0-mlogloss:0.02815
# [7]	validation_0-mlogloss:0.02535
# [8]	validation_0-mlogloss:0.02285
# [9]	validation_0-mlogloss:0.02061
# [10]	validation_0-mlogloss:0.01860
# [11]	validation_0-mlogloss:0.01680
# [12]	validation_0-mlogloss:0.01518
# [13]	validation_0-mlogloss:0.01371
# [14]	validation_0-mlogloss:0.01239
# [15]	validation_0-mlogloss:0.01120
# [16]	validation_0-mlogloss:0.01013
# [17]	validation_0-mlogloss:0.00916
# [18]	validation_0-mlogloss:0.00828
# [19]	validation_0-mlogloss:0.00749
# Saving model after iteration 11
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [14:53:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.04291
# [1]	validation_0-mlogloss:0.03736
# [2]	validation_0-mlogloss:0.03302
# [3]	validation_0-mlogloss:0.02940
# [4]	validation_0-mlogloss:0.02629
# [5]	validation_0-mlogloss:0.02357
# [6]	validation_0-mlogloss:0.02118
# [7]	validation_0-mlogloss:0.01906
# [8]	validation_0-mlogloss:0.01717
# [9]	validation_0-mlogloss:0.01548
# [10]	validation_0-mlogloss:0.01396
# [11]	validation_0-mlogloss:0.01260
# [12]	validation_0-mlogloss:0.01138
# [13]	validation_0-mlogloss:0.01028
# [14]	validation_0-mlogloss:0.00929
# [15]	validation_0-mlogloss:0.00840
# [16]	validation_0-mlogloss:0.00759
# [17]	validation_0-mlogloss:0.00687
# [18]	validation_0-mlogloss:0.00621
# [19]	validation_0-mlogloss:0.00561
# Saving model after iteration 12
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [15:03:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03165
# [1]	validation_0-mlogloss:0.02719
# [2]	validation_0-mlogloss:0.02383
# [3]	validation_0-mlogloss:0.02110
# [4]	validation_0-mlogloss:0.01880
# [5]	validation_0-mlogloss:0.01681
# [6]	validation_0-mlogloss:0.01507
# [7]	validation_0-mlogloss:0.01354
# [8]	validation_0-mlogloss:0.01218
# [9]	validation_0-mlogloss:0.01097
# [10]	validation_0-mlogloss:0.00989
# [11]	validation_0-mlogloss:0.00892
# [12]	validation_0-mlogloss:0.00805
# [13]	validation_0-mlogloss:0.00727
# [14]	validation_0-mlogloss:0.00657
# [15]	validation_0-mlogloss:0.00594
# [16]	validation_0-mlogloss:0.00536
# [17]	validation_0-mlogloss:0.00485
# [18]	validation_0-mlogloss:0.00439
# [19]	validation_0-mlogloss:0.00397
# Saving model after iteration 13
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [15:13:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02655
# [1]	validation_0-mlogloss:0.02258
# [2]	validation_0-mlogloss:0.01968
# [3]	validation_0-mlogloss:0.01735
# [4]	validation_0-mlogloss:0.01540
# [5]	validation_0-mlogloss:0.01374
# [6]	validation_0-mlogloss:0.01230
# [7]	validation_0-mlogloss:0.01103
# [8]	validation_0-mlogloss:0.00991
# [9]	validation_0-mlogloss:0.00892
# [10]	validation_0-mlogloss:0.00803
# [11]	validation_0-mlogloss:0.00724
# [12]	validation_0-mlogloss:0.00653
# [13]	validation_0-mlogloss:0.00590
# [14]	validation_0-mlogloss:0.00533
# [15]	validation_0-mlogloss:0.00481
# [16]	validation_0-mlogloss:0.00435
# [17]	validation_0-mlogloss:0.00393
# [18]	validation_0-mlogloss:0.00355
# [19]	validation_0-mlogloss:0.00321
# Saving model after iteration 14
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [15:24:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02325
# [1]	validation_0-mlogloss:0.01961
# [2]	validation_0-mlogloss:0.01699
# [3]	validation_0-mlogloss:0.01492
# [4]	validation_0-mlogloss:0.01321
# [5]	validation_0-mlogloss:0.01176
# [6]	validation_0-mlogloss:0.01050
# [7]	validation_0-mlogloss:0.00941
# [8]	validation_0-mlogloss:0.00844
# [9]	validation_0-mlogloss:0.00759
# [10]	validation_0-mlogloss:0.00683
# [11]	validation_0-mlogloss:0.00616
# [12]	validation_0-mlogloss:0.00555
# [13]	validation_0-mlogloss:0.00501
# [14]	validation_0-mlogloss:0.00452
# [15]	validation_0-mlogloss:0.00408
# [16]	validation_0-mlogloss:0.00369
# [17]	validation_0-mlogloss:0.00333
# [18]	validation_0-mlogloss:0.00301
# [19]	validation_0-mlogloss:0.00272
# Saving model after iteration 15
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [15:35:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02136
# [1]	validation_0-mlogloss:0.01797
# [2]	validation_0-mlogloss:0.01554
# [3]	validation_0-mlogloss:0.01362
# [4]	validation_0-mlogloss:0.01205
# [5]	validation_0-mlogloss:0.01071
# [6]	validation_0-mlogloss:0.00956
# [7]	validation_0-mlogloss:0.00856
# [8]	validation_0-mlogloss:0.00767
# [9]	validation_0-mlogloss:0.00690
# [10]	validation_0-mlogloss:0.00621
# [11]	validation_0-mlogloss:0.00559
# [12]	validation_0-mlogloss:0.00504
# [13]	validation_0-mlogloss:0.00454
# [14]	validation_0-mlogloss:0.00410
# [15]	validation_0-mlogloss:0.00370
# [16]	validation_0-mlogloss:0.00335
# [17]	validation_0-mlogloss:0.00302
# [18]	validation_0-mlogloss:0.00273
# [19]	validation_0-mlogloss:0.00247
# Saving model after iteration 16
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [15:47:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01906
# [1]	validation_0-mlogloss:0.01608
# [2]	validation_0-mlogloss:0.01390
# [3]	validation_0-mlogloss:0.01218
# [4]	validation_0-mlogloss:0.01076
# [5]	validation_0-mlogloss:0.00956
# [6]	validation_0-mlogloss:0.00853
# [7]	validation_0-mlogloss:0.00763
# [8]	validation_0-mlogloss:0.00684
# [9]	validation_0-mlogloss:0.00615
# [10]	validation_0-mlogloss:0.00553
# [11]	validation_0-mlogloss:0.00498
# [12]	validation_0-mlogloss:0.00449
# [13]	validation_0-mlogloss:0.00405
# [14]	validation_0-mlogloss:0.00365
# [15]	validation_0-mlogloss:0.00330
# [16]	validation_0-mlogloss:0.00298
# [17]	validation_0-mlogloss:0.00269
# [18]	validation_0-mlogloss:0.00243
# [19]	validation_0-mlogloss:0.00220
# Saving model after iteration 17
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [16:00:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01797
# [1]	validation_0-mlogloss:0.01509
# [2]	validation_0-mlogloss:0.01301
# [3]	validation_0-mlogloss:0.01138
# [4]	validation_0-mlogloss:0.01003
# [5]	validation_0-mlogloss:0.00890
# [6]	validation_0-mlogloss:0.00793
# [7]	validation_0-mlogloss:0.00709
# [8]	validation_0-mlogloss:0.00636
# [9]	validation_0-mlogloss:0.00571
# [10]	validation_0-mlogloss:0.00513
# [11]	validation_0-mlogloss:0.00462
# [12]	validation_0-mlogloss:0.00416
# [13]	validation_0-mlogloss:0.00375
# [14]	validation_0-mlogloss:0.00339
# [15]	validation_0-mlogloss:0.00306
# [16]	validation_0-mlogloss:0.00276
# [17]	validation_0-mlogloss:0.00249
# [18]	validation_0-mlogloss:0.00225
# [19]	validation_0-mlogloss:0.00204
# Saving model after iteration 18
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [16:13:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01388
# [1]	validation_0-mlogloss:0.01201
# [2]	validation_0-mlogloss:0.01052
# [3]	validation_0-mlogloss:0.00929
# [4]	validation_0-mlogloss:0.00825
# [5]	validation_0-mlogloss:0.00735
# [6]	validation_0-mlogloss:0.00658
# [7]	validation_0-mlogloss:0.00589
# [8]	validation_0-mlogloss:0.00529
# [9]	validation_0-mlogloss:0.00476
# [10]	validation_0-mlogloss:0.00428
# [11]	validation_0-mlogloss:0.00386
# [12]	validation_0-mlogloss:0.00348
# [13]	validation_0-mlogloss:0.00314
# [14]	validation_0-mlogloss:0.00283
# [15]	validation_0-mlogloss:0.00256
# [16]	validation_0-mlogloss:0.00231
# [17]	validation_0-mlogloss:0.00209
# [18]	validation_0-mlogloss:0.00189
# [19]	validation_0-mlogloss:0.00171
# Saving model after iteration 19
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [16:28:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01284
# [1]	validation_0-mlogloss:0.01115
# [2]	validation_0-mlogloss:0.00980
# [3]	validation_0-mlogloss:0.00866
# [4]	validation_0-mlogloss:0.00770
# [5]	validation_0-mlogloss:0.00687
# [6]	validation_0-mlogloss:0.00615
# [7]	validation_0-mlogloss:0.00551
# [8]	validation_0-mlogloss:0.00495
# [9]	validation_0-mlogloss:0.00445
# [10]	validation_0-mlogloss:0.00401
# [11]	validation_0-mlogloss:0.00361
# [12]	validation_0-mlogloss:0.00326
# [13]	validation_0-mlogloss:0.00294
# [14]	validation_0-mlogloss:0.00266
# [15]	validation_0-mlogloss:0.00240
# [16]	validation_0-mlogloss:0.00217
# [17]	validation_0-mlogloss:0.00196
# [18]	validation_0-mlogloss:0.00177
# [19]	validation_0-mlogloss:0.00160
# Saving model after iteration 20
# Random Forest Illness Prediction - Accuracy Score: 0.9998401710170118
# Random Forest Illness Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                            precision    recall  f1-score   support
#
#                                                 1.00      1.00      1.00    100060
#                  Chest Infection moderate       1.00      1.00      1.00         1
#                    Chest Infection severe       1.00      1.00      1.00         1
#                          Common Cold mild       1.00      1.00      1.00         5
#                      Common Cold moderate       0.73      1.00      0.84         8
#                        Common Cold severe       0.00      0.00      0.00         3
#                        Diarrhoea moderate       0.00      0.00      0.00         0
#                           Diarrhoea other       0.00      0.00      0.00         1
#                    Eye Infection moderate       0.00      0.00      0.00         2
#                              Flu moderate       0.17      1.00      0.29         2
#                                 Flu other       0.00      0.00      0.00         2
#                                Flu severe       0.00      0.00      0.00         6
#                   Headache/Migraine other       0.00      0.00      0.00         1
#                    Nausea/Vomiting severe       1.00      1.00      1.00         1
# Other - see additional information severe       1.00      1.00      1.00         3
#              Other Viral Infection severe       1.00      1.00      1.00         2
#             Sore Throat/ Tonsillitis mild       0.80      1.00      0.89         4
#         Sore Throat/ Tonsillitis moderate       0.00      0.00      0.00         1
#           Sore Throat/ Tonsillitis severe       1.00      1.00      1.00         4
#
#                                  accuracy                           1.00    100107
#                                 macro avg       0.51      0.58      0.53    100107
#                              weighted avg       1.00      1.00      1.00    100107
#
# Random Forest Illness Prediction - Confusion Matrix:
# Logistic Regression Illness Prediction - Accuracy Score: 0.9998401710170118
# Logistic Regression Illness Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                            precision    recall  f1-score   support
#
#                                                 1.00      1.00      1.00    100060
#                  Chest Infection moderate       0.33      1.00      0.50         1
#                    Chest Infection severe       1.00      1.00      1.00         1
#                          Common Cold mild       1.00      1.00      1.00         5
#                      Common Cold moderate       0.73      1.00      0.84         8
#                        Common Cold severe       0.00      0.00      0.00         3
#                        Diarrhoea moderate       0.00      0.00      0.00         0
#                           Diarrhoea other       0.00      0.00      0.00         1
#                    Eye Infection moderate       0.00      0.00      0.00         2
#                              Flu moderate       0.20      1.00      0.33         2
#                                 Flu other       0.00      0.00      0.00         2
#                                Flu severe       0.00      0.00      0.00         6
# ...
#               Knee Other moderate       1.00      1.00      1.00         3
#              Knee Sprain moderate       1.00      1.00      1.00         1
#                  Knee Strain mild       0.00      0.00      0.00         0
#              Knee Strain moderate       1.00      1.00      1.00         3
#                 Knee Strain other       0.00      0.00      0.00         1
#                Knee Strain severe       1.00      1.00      1.00         1
#     Lumbar Fracture/Stress severe       0.00      0.00      0.00         1
#             Lumbar Other moderate       0.00      0.00      0.00         2
#            Lumbar Strain moderate       0.50      1.00      0.67         2
#              Lumbar Strain severe       1.00      1.00      1.00         1
# Other - see notes Sprain moderate       0.00      0.00      0.00         0
#   Other - see notes Sprain severe       0.00      0.00      0.00         1
#     Ribs Fracture/Stress moderate       0.00      0.00      0.00         0
#     Shoulder Dislocation moderate       0.00      0.00      0.00         0
#              Shoulder Strain mild       0.00      0.00      0.00         1
#          Shoulder Strain moderate       1.00      1.00      1.00         4
#             Shoulder Strain other       0.50      1.00      0.67         1
#            Shoulder Strain severe       1.00      1.00      1.00         1
#       Shoulder Subluxation severe       1.00      1.00      1.00         1
#             Thumb Sprain moderate       1.00      1.00      1.00         1
#          Upper Leg Other moderate       1.00      1.00      1.00         1
#     Wrist Fracture/Break moderate       0.00      0.00      0.00         2
#                Wrist Sprain other       0.00      0.00      0.00         0
#
#                          accuracy                           1.00    100107
#                         macro avg       0.45      0.48      0.46    100107
#                      weighted avg       1.00      1.00      1.00    100107
#
# Random Forest Injury Prediction - Confusion Matrix:
# Logistic Regression Injury Prediction - Accuracy Score: 0.9998002137712647
# Logistic Regression Injury Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                         precision    recall  f1-score   support
#
#                                              1.00      1.00      1.00    100034
#          Ankle Fracture/Break moderate       0.00      0.00      0.00         0
#              Ankle Laceration moderate       1.00      1.00      1.00         1
#                     Ankle Other severe       1.00      1.00      1.00         1
#                      Ankle Sprain mild       1.00      1.00      1.00         5
#                  Ankle Sprain moderate       1.00      1.00      1.00         6
#                     Ankle Sprain other       0.00      0.00      0.00         1
#                    Ankle Sprain severe       1.00      1.00      1.00         2
#                  Ankle Strain moderate       1.00      1.00      1.00         1
#                     Ankle Strain other       0.00      0.00      0.00         0
#                       Chest Other mild       0.00      0.00      0.00         1
#             Elbow Dislocation moderate       0.00      0.00      0.00         1
#                  Elbow Sprain moderate       0.00      0.00      0.00         0
#             Fingers Dislocation severe       0.00      0.00      0.00         1
#            Fingers Fracture/Break mild       0.00      0.00      0.00         1
#        Fingers Fracture/Break moderate       0.25      1.00      0.40         1
#          Fingers Fracture/Break severe       0.00      0.00      0.00         1
#                     Fingers Other mild       0.00      0.00      0.00         0
#                    Fingers Sprain mild       0.00      0.00      0.00         1
#                Fingers Sprain moderate       0.00      0.00      0.00         1
#                      Foot Other severe       1.00      1.00      1.00         2
#                      Groin Strain mild       0.00      0.00      0.00         1
#                  Groin Strain moderate       0.00      0.00      0.00         0
#              Hand Fracture/Break other       0.00      0.00      0.00         0
#             Hand Fracture/Break severe       0.00      0.00      0.00         1
#                   Hand Sprain moderate       1.00      1.00      1.00         1
#               Head Concussion moderate       1.00      1.00      1.00         4
#                  Head Concussion other       1.00      1.00      1.00         1
#                 Head Concussion severe       1.00      1.00      1.00         5
#                        Hip Strain mild       1.00      1.00      1.00         2
#                Knee Dislocation severe       0.00      0.00      0.00         1
#            Knee Fracture/Stress severe       0.00      0.00      0.00         1
#                        Knee Other mild       1.00      1.00      1.00         1
#                    Knee Other moderate       1.00      1.00      1.00         3
#                   Knee Sprain moderate       1.00      1.00      1.00         1
#                   Knee Strain moderate       1.00      1.00      1.00         3
#                      Knee Strain other       0.00      0.00      0.00         1
#                     Knee Strain severe       1.00      1.00      1.00         1
#          Lumbar Fracture/Stress severe       0.00      0.00      0.00         1
#                  Lumbar Other moderate       0.00      0.00      0.00         2
#                    Lumbar Other severe       0.00      0.00      0.00         0
#                 Lumbar Strain moderate       1.00      1.00      1.00         2
#                   Lumbar Strain severe       1.00      1.00      1.00         1
# Other - see notes Fracture/Stress mild       0.00      0.00      0.00         0
#           Other - see notes Other mild       0.00      0.00      0.00         0
#         Other - see notes Other severe       0.00      0.00      0.00         0
#        Other - see notes Sprain severe       0.00      0.00      0.00         1
#            Shoulder Dislocation severe       0.00      0.00      0.00         0
#                   Shoulder Sprain mild       0.00      0.00      0.00         0
#                   Shoulder Strain mild       0.00      0.00      0.00         1
#               Shoulder Strain moderate       1.00      1.00      1.00         4
#                  Shoulder Strain other       1.00      1.00      1.00         1
#                 Shoulder Strain severe       1.00      1.00      1.00         1
#            Shoulder Subluxation severe       1.00      1.00      1.00         1
#                  Thumb Sprain moderate       1.00      1.00      1.00         1
#               Upper Leg Other moderate       1.00      1.00      1.00         1
#          Wrist Fracture/Break moderate       0.00      0.00      0.00         2
#
#                               accuracy                           1.00    100107
#                              macro avg       0.46      0.47      0.46    100107
#                           weighted avg       1.00      1.00      1.00    100107
#
# Logistic Regression Injury Prediction - Confusion Matrix:
# XGBoost Injury Prediction - Accuracy Score: 0.9998002137712647
# XGBoost Injury Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                    precision    recall  f1-score   support
#
#                                         1.00      1.00      1.00    100034
#         Ankle Laceration moderate       1.00      1.00      1.00         1
#                  Ankle Other mild       0.00      0.00      0.00         0
#                Ankle Other severe       1.00      1.00      1.00         1
#                 Ankle Sprain mild       1.00      1.00      1.00         5
#             Ankle Sprain moderate       1.00      1.00      1.00         6
#                Ankle Sprain other       0.00      0.00      0.00         1
#               Ankle Sprain severe       1.00      1.00      1.00         2
#             Ankle Strain moderate       1.00      1.00      1.00         1
#                Ankle Strain other       0.00      0.00      0.00         0
#                  Chest Other mild       0.00      0.00      0.00         1
#        Elbow Dislocation moderate       0.00      0.00      0.00         1
#         Eye Fracture/Break severe       0.00      0.00      0.00         0
#         Fingers Abrasion moderate       0.00      0.00      0.00         0
#        Fingers Dislocation severe       0.00      0.00      0.00         1
#       Fingers Fracture/Break mild       0.00      0.00      0.00         1
#   Fingers Fracture/Break moderate       0.33      1.00      0.50         1
#     Fingers Fracture/Break severe       0.00      0.00      0.00         1
#                Fingers Other mild       0.00      0.00      0.00         0
#               Fingers Sprain mild       0.00      0.00      0.00         1
#           Fingers Sprain moderate       0.00      0.00      0.00         1
#                 Foot Other severe       1.00      1.00      1.00         2
#             Groin Sprain moderate       0.00      0.00      0.00         0
#                 Groin Strain mild       0.00      0.00      0.00         1
#           Hand Dislocation severe       0.00      0.00      0.00         0
#         Hand Fracture/Break other       0.00      0.00      0.00         0
#        Hand Fracture/Break severe       0.00      0.00      0.00         1
#              Hand Sprain moderate       1.00      1.00      1.00         1
#          Head Concussion moderate       1.00      1.00      1.00         4
#             Head Concussion other       1.00      1.00      1.00         1
#            Head Concussion severe       1.00      1.00      1.00         5
#                   Hip Strain mild       1.00      1.00      1.00         2
#           Knee Dislocation severe       0.00      0.00      0.00         1
#       Knee Fracture/Stress severe       0.00      0.00      0.00         1
#             Knee Laceration other       0.00      0.00      0.00         0
#                   Knee Other mild       1.00      1.00      1.00         1
#               Knee Other moderate       1.00      1.00      1.00         3
#              Knee Sprain moderate       1.00      1.00      1.00         1
#                  Knee Strain mild       0.00      0.00      0.00         0
#              Knee Strain moderate       1.00      1.00      1.00         3
#                 Knee Strain other       0.00      0.00      0.00         1
#                Knee Strain severe       1.00      1.00      1.00         1
#     Lumbar Fracture/Stress severe       0.00      0.00      0.00         1
#             Lumbar Other moderate       0.00      0.00      0.00         2
#                Lumbar Sprain mild       0.00      0.00      0.00         0
#            Lumbar Strain moderate       1.00      1.00      1.00         2
#              Lumbar Strain severe       0.33      1.00      0.50         1
# Other - see notes Sprain moderate       0.00      0.00      0.00         0
#   Other - see notes Sprain severe       0.00      0.00      0.00         1
#     Shoulder Dislocation moderate       0.00      0.00      0.00         0
#              Shoulder Sprain mild       0.00      0.00      0.00         0
#              Shoulder Strain mild       0.00      0.00      0.00         1
#          Shoulder Strain moderate       1.00      1.00      1.00         4
#             Shoulder Strain other       1.00      1.00      1.00         1
#            Shoulder Strain severe       1.00      1.00      1.00         1
#       Shoulder Subluxation severe       1.00      1.00      1.00         1
#             Thumb Sprain moderate       1.00      1.00      1.00         1
#          Upper Leg Other moderate       1.00      1.00      1.00         1
#     Wrist Fracture/Break moderate       0.00      0.00      0.00         2
#
#                          accuracy                           1.00    100107
#                         macro avg       0.44      0.46      0.44    100107
#                      weighted avg       1.00      1.00      1.00    100107
#
# XGBoost Injury Prediction - Confusion Matrix:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
import xgboost as xgb
import matplotlib.pyplot as plt
import openpyxl
from openpyxl.styles import PatternFill
from openpyxl.drawing.image import Image
from openpyxl import Workbook
import os
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib
from imblearn.over_sampling import RandomOverSampler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
import shutil

# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-1:  Model Initializing for Injury/Illness Details Prediction
print("start execution")

# directory to save models
model_dir = 'saved_models_additional_v2_no_severity'

if os.path.exists(model_dir):
    shutil.rmtree(model_dir)
os.makedirs(model_dir)
    
# set GPU acceleration
def setup_gpu_acceleration():
    try:
        from xgboost import XGBClassifier
        return XGBClassifier(tree_method='hist', device='cpu')
    except ImportError:
        print("Metal acceleration not available. Falling back to CPU.")
        return XGBClassifier(tree_method='hist', device='cpu')

# set checkpoints
def train_model_with_checkpoints(model, X_train, y_train, model_path, model_type="injury", checkpoint_interval=1, max_rounds=20):
    checkpoint_path = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint.pkl')
    checkpoint_file = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint_rounds.txt')
    start_iteration = 0

    # check if there's an existing model or checkpoint to resume from
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        model = joblib.load(model_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration
    elif os.path.exists(checkpoint_path):
        print(f"Resuming training from checkpoint: {checkpoint_path}")
        model = joblib.load(checkpoint_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration

        if os.path.exists(checkpoint_file):
            with open(checkpoint_file, 'r') as f:
                checkpoint_rounds = int(f.read().strip())
                print(f"Resuming from saved round: {checkpoint_rounds}")
                start_iteration = checkpoint_rounds

            if checkpoint_rounds is not None:
                start_iteration = checkpoint_rounds

    # training the model
    eval_set = [(X_train, y_train)]

    # if continuing from an existing model or checkpoint, resume training
    for i in range(start_iteration, max_rounds):
        model.fit(X_train, y_train, eval_set=eval_set, verbose=True, xgb_model=model.get_booster() if i > 0 else None)
        
        # save checkpoint after each round
        print(f"Saving model after iteration {i+1}")
        joblib.dump(model, checkpoint_path)  # save the model checkpoint
        
        # save the round checkpoint number
        with open(checkpoint_file, 'w') as f:
            f.write(str(i + 1))

    # save the final model
    joblib.dump(model, model_path)

    return model

# load training and testing data
train_df = pd.read_excel("cleaned_training_data_v3.xlsx")
test_df = pd.read_excel("cleaned_test_data_v3.xlsx")
realuse_df = pd.read_excel("cleaned_realuse_data_v3.xlsx")

# preprocessing the numeric features
numeric_features = ['Gender_m2f1', 'Menstruation_y1n0', 'Mood state', 'Energy levels',
                    'Muscle readiness', 'Academic Pressure', 'Diet Yesterday', 'Sleep quality',
                    'Sleep duration', 'sleep_score', 'total_training_load', 'total_training_duration',
                    'weekly_training_load', 'weekly_training_duration', 'ACWR', 'RTT', 'illed', 'injured']

# separate numeric features from the rest
X_train = train_df[numeric_features]
X_test = test_df[numeric_features]
X_real = realuse_df[numeric_features]

# preprocessing the text data

# combine text columns for illness and injury separately
illness_columns = ['Type of illness', 'Illness severity']
injury_columns = ['Injury location', 'Injury type']

# fill missing values with empty strings and concatenate the text columns
train_df['illness_text'] = train_df[illness_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_text'] = train_df[injury_columns].fillna('').agg(' '.join, axis=1)
test_df['illness_text'] = test_df[illness_columns].fillna('').agg(' '.join, axis=1)
test_df['injury_text'] = test_df[injury_columns].fillna('').agg(' '.join, axis=1)
realuse_df['illness_text'] = realuse_df[illness_columns].fillna('').agg(' '.join, axis=1)
realuse_df['injury_text'] = realuse_df[injury_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_information'] = train_df['injury_text'].fillna("No Injury")
train_df['illness_information'] = train_df['illness_text'].fillna("No Illness")
test_df['injury_information'] = test_df['injury_text'].fillna("No Injury")
test_df['illness_information'] = test_df['illness_text'].fillna("No Illness")
realuse_df['injury_information'] = realuse_df['injury_text'].fillna("No Injury")
realuse_df['illness_information'] = realuse_df['illness_text'].fillna("No Illness")

vectorizer_files = ['tfidf_vectorizer_illness.pkl', 'tfidf_vectorizer_injury.pkl']
for file in vectorizer_files:
    filepath = os.path.join(model_dir, file)
    if os.path.exists(filepath):
        os.remove(filepath)
        
# vectorize the text data using TfidfVectorizer
tfidf_vectorizer_illness = TfidfVectorizer(max_features=500)
tfidf_vectorizer_injury = TfidfVectorizer(max_features=500)

# fit on training data, then transform test and real use data
X_illness_train = tfidf_vectorizer_illness.fit_transform(train_df['illness_information'])
X_injury_train = tfidf_vectorizer_injury.fit_transform(train_df['injury_information'])

# save the vectorizers
print("Saving vectorizers...")
joblib.dump(tfidf_vectorizer_illness, os.path.join(model_dir, 'tfidf_vectorizer_illness.pkl'))
joblib.dump(tfidf_vectorizer_injury, os.path.join(model_dir, 'tfidf_vectorizer_injury.pkl'))

X_illness_test = tfidf_vectorizer_illness.transform(test_df['illness_information'])
X_injury_test = tfidf_vectorizer_injury.transform(test_df['injury_information'])
print("Injury test shape:", X_injury_test.shape)
X_illness_real = tfidf_vectorizer_illness.transform(realuse_df['illness_information'])
X_injury_real = tfidf_vectorizer_injury.transform(realuse_df['injury_information'])
# check feature dimensions for test and real-use data
print("Test features for illness model:", X_illness_test.shape[1])
print("Real-use features for illness model:", X_illness_real.shape[1])
print("Test features for injury model:",X_injury_train.shape)
print("Real-use features for injury model:",X_injury_test.shape)

# create an instance of RandomOverSampler
ros = RandomOverSampler(random_state=42)

# resample the training data based on illness and injury (use RandomOverSampler instead of SMOTE)
X_resampled_illness, y_resampled_illness = ros.fit_resample(X_illness_train, train_df['illness_information'])
X_resampled_injury, y_resampled_injury = ros.fit_resample(X_injury_train, train_df['injury_information'])

X_train_illness, X_test_illness, y_train_illness, y_test_illness = train_test_split(X_resampled_illness, y_resampled_illness, test_size=0.2, random_state=42)
X_train_injury, X_test_injury, y_train_injury, y_test_injury = train_test_split(X_resampled_injury, y_resampled_injury, test_size=0.2, random_state=42)
# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-2: Model Selection, Hyperparameters Fine Tuning, Training

# model file paths
rf_illness_model_path = os.path.join(model_dir, 'rf_model_illness.pkl')
rf_injury_model_path = os.path.join(model_dir, 'rf_model_injury.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_injury_model_path = os.path.join(model_dir, 'log_reg_model_injury.pkl')
xgb_illness_model_path = os.path.join(model_dir, 'xgb_model_illness.pkl')
xgb_injury_model_path = os.path.join(model_dir, 'xgb_model_injury.pkl')
xgb_illness_label_encoder_path = os.path.join(model_dir, 'xgb_illness_label_encoder.pkl')
xgb_injury_label_encoder_path = os.path.join(model_dir, 'xgb_injury_label_encoder.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_illness_label_encoder_path = os.path.join(model_dir, 'label_encoder_log_reg_illness.pkl')

# check if models are saved, and load them if available
def load_model(model_path):
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        return joblib.load(model_path)
    return None

# load existing models or train if they exist
best_rf_model_illness = load_model(rf_illness_model_path)
best_rf_model_injury = load_model(rf_injury_model_path)
best_log_reg_model_illness = load_model(log_reg_illness_model_path)
best_log_reg_model_injury = load_model(log_reg_injury_model_path)
best_xgb_model_illness = load_model(xgb_illness_model_path)
best_xgb_model_injury = load_model(xgb_injury_model_path)

# if no model is loaded, perform hyperparameter tuning and training
if best_rf_model_illness is None:
    # randomForest for illness prediction with predefined hyperparameters
    rf_param_illness = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_illness = RandomForestClassifier(random_state=42, **rf_param_illness)
    best_rf_model_illness.fit(X_train_illness, y_train_illness)
    joblib.dump(best_rf_model_illness, rf_illness_model_path)

if best_rf_model_injury is None:
    # randomForest for injury prediction with predefined hyperparameters
    rf_param_injury = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_injury = RandomForestClassifier(random_state=42, **rf_param_injury)
    best_rf_model_injury.fit(X_train_injury, y_train_injury)
    joblib.dump(best_rf_model_injury, rf_injury_model_path)

if best_log_reg_model_illness is None:
    # encode the string labels to numeric labels
    label_encoder_illness = LabelEncoder()
    y_train_illness_encoded = label_encoder_illness.fit_transform(y_train_illness)
    joblib.dump(label_encoder_illness, 'label_encoder_log_reg_illness.pkl')
    # get unique classes in the encoded labels
    unique_classes_illness = np.unique(y_train_illness_encoded)
    # calculate class weights
    class_weights_illness = compute_class_weight('balanced', classes=unique_classes_illness, y=y_train_illness_encoded)
    class_weight_dict_illness = dict(zip(unique_classes_illness, class_weights_illness))
    log_reg_param_illness = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_illness
    }
    best_log_reg_model_illness = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_illness)
    best_log_reg_model_illness.fit(X_train_illness, y_train_illness_encoded)
    joblib.dump(best_log_reg_model_illness, log_reg_illness_model_path)


if best_log_reg_model_injury is None:
    # encode the string labels to numeric labels
    label_encoder_injury = LabelEncoder()
    y_train_injury_encoded = label_encoder_injury.fit_transform(y_train_injury)
    joblib.dump(label_encoder_injury, 'label_encoder_log_reg_injury.pkl')
    # get unique classes in the encoded labels
    unique_classes_injury = np.unique(y_train_injury_encoded)
    # calculate class weights
    class_weights_injury = compute_class_weight('balanced', classes=unique_classes_injury, y=y_train_injury_encoded)
    class_weight_dict_injury = dict(zip(unique_classes_injury, class_weights_injury))
    log_reg_param_injury = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_injury
    }
    best_log_reg_model_injury = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_injury)
    best_log_reg_model_injury.fit(X_train_injury, y_train_injury_encoded)
    joblib.dump(best_log_reg_model_injury, log_reg_injury_model_path)

# function to encode the target variable
def handle_label_encoder(y_train, encoder_path):
    if os.path.exists(encoder_path):
        os.remove(encoder_path)
        
    print(f"creating new label encoder for xgb: {encoder_path}")
    encoder = LabelEncoder()
    y_encoded = encoder.fit_transform(y_train)
    joblib.dump(encoder, encoder_path)
    return y_encoded, encoder

print("\n" + "="*50 + " handling xgb illness label encoder " + "="*50)
y_train_illness_encoded, illness_encoder = handle_label_encoder(y_train_illness, xgb_illness_label_encoder_path)

print("\n" + "="*50 + " handling xgb injury label encoder " + "="*50)
y_train_injury_encoded, injury_encoder = handle_label_encoder(y_train_injury, xgb_injury_label_encoder_path)

if best_xgb_model_illness is None:
    # XGBoost for illness prediction with GPU acceleration
    positive_class_count_illness = sum(y_train_illness_encoded == 1)
    negative_class_count_illness = sum(y_train_illness_encoded == 0)

    if positive_class_count_illness > 0:
        scale_pos_weight_illness = negative_class_count_illness / positive_class_count_illness
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist', 
            'device': 'cpu',
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10,
            'scale_pos_weight': scale_pos_weight_illness
        }
    else:
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10
        }
    best_xgb_model_illness = xgb.XGBClassifier(random_state=42, **xgb_param_illness)
    best_xgb_model_illness = train_model_with_checkpoints(
        model=best_xgb_model_illness,
        X_train=X_train_illness,
        y_train=y_train_illness_encoded,
        model_path=xgb_illness_model_path,
        model_type="illness",
        checkpoint_interval=1,
        max_rounds=20
    )

if best_xgb_model_injury is None:
    # XGBoost for injury prediction with predefined hyperparameters
    positive_class_count_injury = np.sum(y_train_injury_encoded == 1)
    negative_class_count_injury = np.sum(y_train_injury_encoded == 0)
    if positive_class_count_injury > 0:
        scale_pos_weight_injury = negative_class_count_injury / positive_class_count_injury
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3,
            'scale_pos_weight': scale_pos_weight_injury
        }
    else:
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3
        }
    best_xgb_model_injury = xgb.XGBClassifier(random_state=42, **xgb_param_injury)
    best_xgb_model_injury = train_model_with_checkpoints(
        model=best_xgb_model_injury,
        X_train=X_train_injury,
        y_train=y_train_injury_encoded,
        model_path=xgb_injury_model_path,
        model_type="injury",
        checkpoint_interval=1,
        max_rounds=20
    )

# after GridSearchCV, we can use the best models for prediction:
y_pred_illness_rf_test = best_rf_model_illness.predict(X_illness_test)
y_pred_injury_rf_test = best_rf_model_injury.predict(X_injury_test)

log_reg_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
y_pred_illness_lr_test = best_log_reg_model_illness.predict(X_illness_test)
y_pred_illness_lr_test_labels = log_reg_label_encoder_illness.inverse_transform(y_pred_illness_lr_test)
log_reg_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
y_pred_injury_lr_test = best_log_reg_model_injury.predict(X_injury_test)
y_pred_injury_lr_test_labels = log_reg_label_encoder_injury.inverse_transform(y_pred_injury_lr_test)

y_pred_illness_xgb_test = best_xgb_model_illness.predict(X_illness_test)
y_pred_injury_xgb_test = best_xgb_model_injury.predict(X_injury_test)

# -----------------------------------------------------------------------------------------------------------------------------------------
# model evaluation for all illness prediction
print("Random Forest Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Confusion Matrix:")
cm_illness_rf_test = confusion_matrix(test_df['illness_information'], y_pred_illness_rf_test)
sns.heatmap(cm_illness_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_illness_lr_test = confusion_matrix(test_df['illness_information'], y_pred_illness_lr_test_labels)
# load the logistic regression label encoder for illness
lr_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
sns.heatmap(cm_illness_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_illness.classes_,
            yticklabels=lr_label_encoder_illness.classes_)
plt.title("Logistic Regression - Illness Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_illness = joblib.load(xgb_illness_label_encoder_path)
# convert predictions back to original labels
y_pred_illness_xgb_test_labels = label_encoder_illness.inverse_transform(y_pred_illness_xgb_test)
print("XGBoost Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Confusion Matrix:")
cm_illness_xgb_test = confusion_matrix(test_df['illness_information'], y_pred_illness_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_illness_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_illness.classes_,
            yticklabels=label_encoder_illness.classes_)
plt.title("XGBoost Illness Prediction - Confusion Matrix")
plt.show()

# model evaluation for all injury prediction
print("Random Forest Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Confusion Matrix:")
cm_injury_rf_test = confusion_matrix(test_df['injury_information'], y_pred_injury_rf_test)
sns.heatmap(cm_injury_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_injury_lr_test = confusion_matrix(test_df['injury_information'], y_pred_injury_lr_test_labels)
# load the logistic regression label encoder for injury
lr_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
sns.heatmap(cm_injury_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_injury.classes_,
            yticklabels=lr_label_encoder_injury.classes_)
plt.title("Logistic Regression - Injury Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_injury = joblib.load(xgb_injury_label_encoder_path)
# convert predictions back to original labels
y_pred_injury_xgb_test_labels = label_encoder_injury.inverse_transform(y_pred_injury_xgb_test)
print("XGBoost Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Confusion Matrix:")
cm_injury_xgb_test = confusion_matrix(test_df['injury_information'], y_pred_injury_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_injury_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_injury.classes_,
            yticklabels=label_encoder_injury.classes_)
plt.title("XGBoost Injury Prediction - Confusion Matrix")
plt.show()
# Out:
# start execution
# Training features for illness model: 19
# Injury train shape: (138640, 38)
# Vocabulary size of TF-IDF Vectorizer: 38
# Saving vectorizers...
# Injury test shape: (100107, 38)
# Test features for illness model: 19
# Real-use features for illness model: 19
# Test features for injury model: (138640, 38)
# Real-use features for injury model: (100107, 38)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 227
#     218     rf_param_injury = {
#     219         'n_estimators': 200,
#     220         'max_depth': 20,
#    (...)    224         'class_weight': 'balanced'
#     225     }
#     226     best_rf_model_injury = RandomForestClassifier(random_state=42, **rf_param_injury)
# --> 227     best_rf_model_injury.fit(X_train_injury, y_train_injury)
#     228     joblib.dump(best_rf_model_injury, rf_injury_model_path)
#     230 if best_log_reg_model_illness is None:
#     231     # encode the string labels to numeric labels
#
# File ~/miniconda3/lib/python3.11/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:487, in BaseForest.fit(self, X, y, sample_weight)
#     476 trees = [
#     477     self._make_estimator(append=False, random_state=random_state)
#     478     for i in range(n_more_estimators)
#     479 ]
#     481 # Parallel loop: we prefer the threading backend as the Cython code
#     482 # for fitting the trees is internally releasing the Python GIL
#     483 # making threading more efficient than multiprocessing in
#     484 # that case. However, for joblib 0.12+ we respect any
#     485 # parallel_backend contexts set at a higher level,
#     486 # since correctness does not rely on using threads.
# --> 487 trees = Parallel(
#     488     n_jobs=self.n_jobs,
#     489     verbose=self.verbose,
#     490     prefer="threads",
#     491 )(
#     492     delayed(_parallel_build_trees)(
#     493         t,
#     494         self.bootstrap,
#     495         X,
#     496         y,
#     497         sample_weight,
#     498         i,
#     499         len(trees),
#     500         verbose=self.verbose,
#     501         class_weight=self.class_weight,
#     502         n_samples_bootstrap=n_samples_bootstrap,
#     503         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     504     )
#     505     for i, t in enumerate(trees)
#     506 )
#     508 # Collect newly grown trees
#     509 self.estimators_.extend(trees)
#
# File ~/miniconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/miniconda3/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/miniconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree._fit(
#     190         X,
#     191         y,
#     192         sample_weight=curr_sample_weight,
#     193         check_input=False,
#     194         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     195     )
#     196 else:
#     197     tree._fit(
#     198         X,
#     199         y,
#    (...)    202         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     203     )
#
# File ~/miniconda3/lib/python3.11/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)    469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
import xgboost as xgb
import matplotlib.pyplot as plt
import openpyxl
from openpyxl.styles import PatternFill
from openpyxl.drawing.image import Image
from openpyxl import Workbook
import os
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib
from imblearn.over_sampling import RandomOverSampler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
import shutil

# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-1:  Model Initializing for Injury/Illness Details Prediction
print("start execution")

# directory to save models
model_dir = 'saved_models_additional_v3'

if os.path.exists(model_dir):
    shutil.rmtree(model_dir)
os.makedirs(model_dir)
    
# set GPU acceleration
def setup_gpu_acceleration():
    try:
        from xgboost import XGBClassifier
        return XGBClassifier(tree_method='hist', device='cpu')
    except ImportError:
        print("Metal acceleration not available. Falling back to CPU.")
        return XGBClassifier(tree_method='hist', device='cpu')

# set checkpoints
def train_model_with_checkpoints(model, X_train, y_train, model_path, model_type="injury", checkpoint_interval=1, max_rounds=20):
    checkpoint_path = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint.pkl')
    checkpoint_file = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint_rounds.txt')
    start_iteration = 0

    # check if there's an existing model or checkpoint to resume from
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        model = joblib.load(model_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration
    elif os.path.exists(checkpoint_path):
        print(f"Resuming training from checkpoint: {checkpoint_path}")
        model = joblib.load(checkpoint_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration

        if os.path.exists(checkpoint_file):
            with open(checkpoint_file, 'r') as f:
                checkpoint_rounds = int(f.read().strip())
                print(f"Resuming from saved round: {checkpoint_rounds}")
                start_iteration = checkpoint_rounds

            if checkpoint_rounds is not None:
                start_iteration = checkpoint_rounds

    # training the model
    eval_set = [(X_train, y_train)]

    # if continuing from an existing model or checkpoint, resume training
    for i in range(start_iteration, max_rounds):
        model.fit(X_train, y_train, eval_set=eval_set, verbose=True, xgb_model=model.get_booster() if i > 0 else None)
        
        # save checkpoint after each round
        print(f"Saving model after iteration {i+1}")
        joblib.dump(model, checkpoint_path)  # save the model checkpoint
        
        # save the round checkpoint number
        with open(checkpoint_file, 'w') as f:
            f.write(str(i + 1))

    # save the final model
    joblib.dump(model, model_path)

    return model

# load training and testing data
train_df = pd.read_excel("cleaned_training_data_v3.xlsx")
test_df = pd.read_excel("cleaned_test_data_v3.xlsx")
realuse_df = pd.read_excel("cleaned_realuse_data_v3.xlsx")

# preprocessing the numeric features
numeric_features = ['Gender_m2f1', 'Menstruation_y1n0', 'Mood state', 'Energy levels',
                    'Muscle readiness', 'Academic Pressure', 'Diet Yesterday', 'Sleep quality',
                    'Sleep duration', 'sleep_score', 'total_training_load', 'total_training_duration',
                    'weekly_training_load', 'weekly_training_duration', 'ACWR', 'RTT', 'illed', 'injured']

# separate numeric features from the rest
X_train = train_df[numeric_features]
X_test = test_df[numeric_features]
X_real = realuse_df[numeric_features]

# preprocessing the text data

# combine text columns for illness and injury separately
illness_columns = ['Type of illness', 'Illness severity']
injury_columns = ['Injury location', 'Injury type', 'Injury severity']

# fill missing values with empty strings and concatenate the text columns
train_df['illness_text'] = train_df[illness_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_text'] = train_df[injury_columns].fillna('').agg(' '.join, axis=1)
test_df['illness_text'] = test_df[illness_columns].fillna('').agg(' '.join, axis=1)
test_df['injury_text'] = test_df[injury_columns].fillna('').agg(' '.join, axis=1)
realuse_df['illness_text'] = realuse_df[illness_columns].fillna('').agg(' '.join, axis=1)
realuse_df['injury_text'] = realuse_df[injury_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_information'] = train_df['injury_text'].fillna("No Injury")
train_df['illness_information'] = train_df['illness_text'].fillna("No Illness")
test_df['injury_information'] = test_df['injury_text'].fillna("No Injury")
test_df['illness_information'] = test_df['illness_text'].fillna("No Illness")
realuse_df['injury_information'] = realuse_df['injury_text'].fillna("No Injury")
realuse_df['illness_information'] = realuse_df['illness_text'].fillna("No Illness")

vectorizer_files = ['tfidf_vectorizer_illness.pkl', 'tfidf_vectorizer_injury.pkl']
for file in vectorizer_files:
    filepath = os.path.join(model_dir, file)
    if os.path.exists(filepath):
        os.remove(filepath)
        
# vectorize the text data using TfidfVectorizer
tfidf_vectorizer_illness = TfidfVectorizer(max_features=500)
tfidf_vectorizer_injury = TfidfVectorizer(max_features=500)

# fit on training data, then transform test and real use data
X_illness_train = tfidf_vectorizer_illness.fit_transform(train_df['illness_information'])
X_injury_train = tfidf_vectorizer_injury.fit_transform(train_df['injury_information'])

# save the vectorizers
print("Saving vectorizers...")
joblib.dump(tfidf_vectorizer_illness, os.path.join(model_dir, 'tfidf_vectorizer_illness.pkl'))
joblib.dump(tfidf_vectorizer_injury, os.path.join(model_dir, 'tfidf_vectorizer_injury.pkl'))

X_illness_test = tfidf_vectorizer_illness.transform(test_df['illness_information'])
X_injury_test = tfidf_vectorizer_injury.transform(test_df['injury_information'])
print("Injury test shape:", X_injury_test.shape)
X_illness_real = tfidf_vectorizer_illness.transform(realuse_df['illness_information'])
X_injury_real = tfidf_vectorizer_injury.transform(realuse_df['injury_information'])
# check feature dimensions for test and real-use data
print("Test features for illness model:", X_illness_test.shape[1])
print("Real-use features for illness model:", X_illness_real.shape[1])
print("Test features for injury model:",X_injury_train.shape)
print("Real-use features for injury model:",X_injury_test.shape)

# create an instance of RandomOverSampler
ros = RandomOverSampler(random_state=42)

# resample the training data based on illness and injury (use RandomOverSampler instead of SMOTE)
X_resampled_illness, y_resampled_illness = ros.fit_resample(X_illness_train, train_df['illness_information'])
X_resampled_injury, y_resampled_injury = ros.fit_resample(X_injury_train, train_df['injury_information'])

X_train_illness, X_test_illness, y_train_illness, y_test_illness = train_test_split(X_resampled_illness, y_resampled_illness, test_size=0.2, random_state=42)
X_train_injury, X_test_injury, y_train_injury, y_test_injury = train_test_split(X_resampled_injury, y_resampled_injury, test_size=0.2, random_state=42)
# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-2: Model Selection, Hyperparameters Fine Tuning, Training

# model file paths
rf_illness_model_path = os.path.join(model_dir, 'rf_model_illness.pkl')
rf_injury_model_path = os.path.join(model_dir, 'rf_model_injury.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_injury_model_path = os.path.join(model_dir, 'log_reg_model_injury.pkl')
xgb_illness_model_path = os.path.join(model_dir, 'xgb_model_illness.pkl')
xgb_injury_model_path = os.path.join(model_dir, 'xgb_model_injury.pkl')
xgb_illness_label_encoder_path = os.path.join(model_dir, 'xgb_illness_label_encoder.pkl')
xgb_injury_label_encoder_path = os.path.join(model_dir, 'xgb_injury_label_encoder.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_illness_label_encoder_path = os.path.join(model_dir, 'label_encoder_log_reg_illness.pkl')

# check if models are saved, and load them if available
def load_model(model_path):
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        return joblib.load(model_path)
    return None

# load existing models or train if they exist
best_rf_model_illness = load_model(rf_illness_model_path)
best_rf_model_injury = load_model(rf_injury_model_path)
best_log_reg_model_illness = load_model(log_reg_illness_model_path)
best_log_reg_model_injury = load_model(log_reg_injury_model_path)
best_xgb_model_illness = load_model(xgb_illness_model_path)
best_xgb_model_injury = load_model(xgb_injury_model_path)

# if no model is loaded, perform hyperparameter tuning and training
if best_rf_model_illness is None:
    # randomForest for illness prediction with predefined hyperparameters
    rf_param_illness = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_illness = RandomForestClassifier(random_state=42, **rf_param_illness)
    best_rf_model_illness.fit(X_train_illness, y_train_illness)
    joblib.dump(best_rf_model_illness, rf_illness_model_path)

if best_rf_model_injury is None:
    # randomForest for injury prediction with predefined hyperparameters
    rf_param_injury = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_injury = RandomForestClassifier(random_state=42, **rf_param_injury)
    best_rf_model_injury.fit(X_train_injury, y_train_injury)
    joblib.dump(best_rf_model_injury, rf_injury_model_path)

if best_log_reg_model_illness is None:
    # encode the string labels to numeric labels
    label_encoder_illness = LabelEncoder()
    y_train_illness_encoded = label_encoder_illness.fit_transform(y_train_illness)
    joblib.dump(label_encoder_illness, 'label_encoder_log_reg_illness.pkl')
    # get unique classes in the encoded labels
    unique_classes_illness = np.unique(y_train_illness_encoded)
    # calculate class weights
    class_weights_illness = compute_class_weight('balanced', classes=unique_classes_illness, y=y_train_illness_encoded)
    class_weight_dict_illness = dict(zip(unique_classes_illness, class_weights_illness))
    log_reg_param_illness = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_illness
    }
    best_log_reg_model_illness = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_illness)
    best_log_reg_model_illness.fit(X_train_illness, y_train_illness_encoded)
    joblib.dump(best_log_reg_model_illness, log_reg_illness_model_path)


if best_log_reg_model_injury is None:
    # encode the string labels to numeric labels
    label_encoder_injury = LabelEncoder()
    y_train_injury_encoded = label_encoder_injury.fit_transform(y_train_injury)
    joblib.dump(label_encoder_injury, 'label_encoder_log_reg_injury.pkl')
    # get unique classes in the encoded labels
    unique_classes_injury = np.unique(y_train_injury_encoded)
    # calculate class weights
    class_weights_injury = compute_class_weight('balanced', classes=unique_classes_injury, y=y_train_injury_encoded)
    class_weight_dict_injury = dict(zip(unique_classes_injury, class_weights_injury))
    log_reg_param_injury = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_injury
    }
    best_log_reg_model_injury = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_injury)
    best_log_reg_model_injury.fit(X_train_injury, y_train_injury_encoded)
    joblib.dump(best_log_reg_model_injury, log_reg_injury_model_path)

# function to encode the target variable
def handle_label_encoder(y_train, encoder_path):
    if os.path.exists(encoder_path):
        os.remove(encoder_path)
        
    print(f"creating new label encoder for xgb: {encoder_path}")
    encoder = LabelEncoder()
    y_encoded = encoder.fit_transform(y_train)
    joblib.dump(encoder, encoder_path)
    return y_encoded, encoder

print("\n" + "="*50 + " handling xgb illness label encoder " + "="*50)
y_train_illness_encoded, illness_encoder = handle_label_encoder(y_train_illness, xgb_illness_label_encoder_path)

print("\n" + "="*50 + " handling xgb injury label encoder " + "="*50)
y_train_injury_encoded, injury_encoder = handle_label_encoder(y_train_injury, xgb_injury_label_encoder_path)

if best_xgb_model_illness is None:
    # XGBoost for illness prediction with GPU acceleration
    positive_class_count_illness = sum(y_train_illness_encoded == 1)
    negative_class_count_illness = sum(y_train_illness_encoded == 0)

    if positive_class_count_illness > 0:
        scale_pos_weight_illness = negative_class_count_illness / positive_class_count_illness
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist', 
            'device': 'cpu',
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10,
            'scale_pos_weight': scale_pos_weight_illness
        }
    else:
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10
        }
    best_xgb_model_illness = xgb.XGBClassifier(random_state=42, **xgb_param_illness)
    best_xgb_model_illness = train_model_with_checkpoints(
        model=best_xgb_model_illness,
        X_train=X_train_illness,
        y_train=y_train_illness_encoded,
        model_path=xgb_illness_model_path,
        model_type="illness",
        checkpoint_interval=1,
        max_rounds=20
    )

if best_xgb_model_injury is None:
    # XGBoost for injury prediction with predefined hyperparameters
    positive_class_count_injury = np.sum(y_train_injury_encoded == 1)
    negative_class_count_injury = np.sum(y_train_injury_encoded == 0)
    if positive_class_count_injury > 0:
        scale_pos_weight_injury = negative_class_count_injury / positive_class_count_injury
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3,
            'scale_pos_weight': scale_pos_weight_injury
        }
    else:
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3
        }
    best_xgb_model_injury = xgb.XGBClassifier(random_state=42, **xgb_param_injury)
    best_xgb_model_injury = train_model_with_checkpoints(
        model=best_xgb_model_injury,
        X_train=X_train_injury,
        y_train=y_train_injury_encoded,
        model_path=xgb_injury_model_path,
        model_type="injury",
        checkpoint_interval=1,
        max_rounds=20
    )

# after GridSearchCV, we can use the best models for prediction:
y_pred_illness_rf_test = best_rf_model_illness.predict(X_illness_test)
y_pred_injury_rf_test = best_rf_model_injury.predict(X_injury_test)

log_reg_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
y_pred_illness_lr_test = best_log_reg_model_illness.predict(X_illness_test)
y_pred_illness_lr_test_labels = log_reg_label_encoder_illness.inverse_transform(y_pred_illness_lr_test)
log_reg_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
y_pred_injury_lr_test = best_log_reg_model_injury.predict(X_injury_test)
y_pred_injury_lr_test_labels = log_reg_label_encoder_injury.inverse_transform(y_pred_injury_lr_test)

y_pred_illness_xgb_test = best_xgb_model_illness.predict(X_illness_test)
y_pred_injury_xgb_test = best_xgb_model_injury.predict(X_injury_test)

# -----------------------------------------------------------------------------------------------------------------------------------------
# model evaluation for all illness prediction
print("Random Forest Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Confusion Matrix:")
cm_illness_rf_test = confusion_matrix(test_df['illness_information'], y_pred_illness_rf_test)
sns.heatmap(cm_illness_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_illness_lr_test = confusion_matrix(test_df['illness_information'], y_pred_illness_lr_test_labels)
# load the logistic regression label encoder for illness
lr_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
sns.heatmap(cm_illness_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_illness.classes_,
            yticklabels=lr_label_encoder_illness.classes_)
plt.title("Logistic Regression - Illness Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_illness = joblib.load(xgb_illness_label_encoder_path)
# convert predictions back to original labels
y_pred_illness_xgb_test_labels = label_encoder_illness.inverse_transform(y_pred_illness_xgb_test)
print("XGBoost Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Confusion Matrix:")
cm_illness_xgb_test = confusion_matrix(test_df['illness_information'], y_pred_illness_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_illness_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_illness.classes_,
            yticklabels=label_encoder_illness.classes_)
plt.title("XGBoost Illness Prediction - Confusion Matrix")
plt.show()

# model evaluation for all injury prediction
print("Random Forest Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Confusion Matrix:")
cm_injury_rf_test = confusion_matrix(test_df['injury_information'], y_pred_injury_rf_test)
sns.heatmap(cm_injury_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_injury_lr_test = confusion_matrix(test_df['injury_information'], y_pred_injury_lr_test_labels)
# load the logistic regression label encoder for injury
lr_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
sns.heatmap(cm_injury_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_injury.classes_,
            yticklabels=lr_label_encoder_injury.classes_)
plt.title("Logistic Regression - Injury Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_injury = joblib.load(xgb_injury_label_encoder_path)
# convert predictions back to original labels
y_pred_injury_xgb_test_labels = label_encoder_injury.inverse_transform(y_pred_injury_xgb_test)
print("XGBoost Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Confusion Matrix:")
cm_injury_xgb_test = confusion_matrix(test_df['injury_information'], y_pred_injury_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_injury_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_injury.classes_,
            yticklabels=label_encoder_injury.classes_)
plt.title("XGBoost Injury Prediction - Confusion Matrix")
plt.show()
# Out:
# start execution
# Saving vectorizers...
# Injury test shape: (100107, 41)
# Test features for illness model: 19
# Real-use features for illness model: 19
# Test features for injury model: (138640, 41)
# Real-use features for injury model: (100107, 41)
#
# ================================================== handling xgb illness label encoder ==================================================
# creating new label encoder for xgb: saved_models_additional_v3/xgb_illness_label_encoder.pkl
#
# ================================================== handling xgb injury label encoder ==================================================
# creating new label encoder for xgb: saved_models_additional_v3/xgb_injury_label_encoder.pkl
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:37:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:1.98356
# [1]	validation_0-mlogloss:1.64422
# [2]	validation_0-mlogloss:1.40636
# [3]	validation_0-mlogloss:1.21864
# [4]	validation_0-mlogloss:1.07238
# [5]	validation_0-mlogloss:0.94845
# [6]	validation_0-mlogloss:0.84121
# [7]	validation_0-mlogloss:0.75045
# [8]	validation_0-mlogloss:0.67020
# [9]	validation_0-mlogloss:0.59992
# [10]	validation_0-mlogloss:0.53891
# [11]	validation_0-mlogloss:0.48399
# [12]	validation_0-mlogloss:0.43518
# [13]	validation_0-mlogloss:0.39217
# [14]	validation_0-mlogloss:0.35375
# [15]	validation_0-mlogloss:0.31922
# [16]	validation_0-mlogloss:0.28849
# [17]	validation_0-mlogloss:0.26083
# [18]	validation_0-mlogloss:0.23541
# [19]	validation_0-mlogloss:0.21255
# Saving model after iteration 1
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:37:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.37633
# [1]	validation_0-mlogloss:0.33068
# [2]	validation_0-mlogloss:0.29304
# [3]	validation_0-mlogloss:0.26149
# [4]	validation_0-mlogloss:0.23404
# [5]	validation_0-mlogloss:0.21039
# [6]	validation_0-mlogloss:0.18901
# [7]	validation_0-mlogloss:0.17003
# [8]	validation_0-mlogloss:0.15321
# [9]	validation_0-mlogloss:0.13817
# [10]	validation_0-mlogloss:0.12475
# [11]	validation_0-mlogloss:0.11271
# [12]	validation_0-mlogloss:0.10174
# [13]	validation_0-mlogloss:0.09187
# [14]	validation_0-mlogloss:0.08298
# [15]	validation_0-mlogloss:0.07497
# [16]	validation_0-mlogloss:0.06784
# [17]	validation_0-mlogloss:0.06131
# [18]	validation_0-mlogloss:0.05549
# [19]	validation_0-mlogloss:0.05020
# Saving model after iteration 2
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:37:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.17199
# [1]	validation_0-mlogloss:0.15169
# [2]	validation_0-mlogloss:0.13461
# [3]	validation_0-mlogloss:0.11997
# [4]	validation_0-mlogloss:0.10724
# [5]	validation_0-mlogloss:0.09609
# [6]	validation_0-mlogloss:0.08629
# [7]	validation_0-mlogloss:0.07758
# [8]	validation_0-mlogloss:0.06983
# [9]	validation_0-mlogloss:0.06292
# [10]	validation_0-mlogloss:0.05671
# [11]	validation_0-mlogloss:0.05115
# [12]	validation_0-mlogloss:0.04617
# [13]	validation_0-mlogloss:0.04167
# [14]	validation_0-mlogloss:0.03763
# [15]	validation_0-mlogloss:0.03398
# [16]	validation_0-mlogloss:0.03070
# [17]	validation_0-mlogloss:0.02774
# [18]	validation_0-mlogloss:0.02508
# [19]	validation_0-mlogloss:0.02267
# Saving model after iteration 3
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:37:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.07735
# [1]	validation_0-mlogloss:0.06947
# [2]	validation_0-mlogloss:0.06246
# [3]	validation_0-mlogloss:0.05622
# [4]	validation_0-mlogloss:0.05064
# [5]	validation_0-mlogloss:0.04565
# [6]	validation_0-mlogloss:0.04117
# [7]	validation_0-mlogloss:0.03715
# [8]	validation_0-mlogloss:0.03354
# [9]	validation_0-mlogloss:0.03028
# [10]	validation_0-mlogloss:0.02735
# [11]	validation_0-mlogloss:0.02471
# [12]	validation_0-mlogloss:0.02233
# [13]	validation_0-mlogloss:0.02018
# [14]	validation_0-mlogloss:0.01824
# [15]	validation_0-mlogloss:0.01650
# [16]	validation_0-mlogloss:0.01492
# [17]	validation_0-mlogloss:0.01349
# [18]	validation_0-mlogloss:0.01220
# [19]	validation_0-mlogloss:0.01103
# Saving model after iteration 4
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:37:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.04948
# [1]	validation_0-mlogloss:0.04459
# [2]	validation_0-mlogloss:0.04021
# [3]	validation_0-mlogloss:0.03627
# [4]	validation_0-mlogloss:0.03273
# [5]	validation_0-mlogloss:0.02955
# [6]	validation_0-mlogloss:0.02669
# [7]	validation_0-mlogloss:0.02411
# [8]	validation_0-mlogloss:0.02178
# [9]	validation_0-mlogloss:0.01968
# [10]	validation_0-mlogloss:0.01779
# [11]	validation_0-mlogloss:0.01608
# [12]	validation_0-mlogloss:0.01454
# [13]	validation_0-mlogloss:0.01315
# [14]	validation_0-mlogloss:0.01189
# [15]	validation_0-mlogloss:0.01075
# [16]	validation_0-mlogloss:0.00972
# [17]	validation_0-mlogloss:0.00879
# [18]	validation_0-mlogloss:0.00795
# [19]	validation_0-mlogloss:0.00719
# Saving model after iteration 5
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:37:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03094
# [1]	validation_0-mlogloss:0.02793
# [2]	validation_0-mlogloss:0.02522
# [3]	validation_0-mlogloss:0.02278
# [4]	validation_0-mlogloss:0.02058
# [5]	validation_0-mlogloss:0.01859
# [6]	validation_0-mlogloss:0.01680
# [7]	validation_0-mlogloss:0.01519
# [8]	validation_0-mlogloss:0.01373
# [9]	validation_0-mlogloss:0.01241
# [10]	validation_0-mlogloss:0.01122
# [11]	validation_0-mlogloss:0.01015
# [12]	validation_0-mlogloss:0.00918
# [13]	validation_0-mlogloss:0.00830
# [14]	validation_0-mlogloss:0.00751
# [15]	validation_0-mlogloss:0.00679
# [16]	validation_0-mlogloss:0.00614
# [17]	validation_0-mlogloss:0.00556
# [18]	validation_0-mlogloss:0.00503
# [19]	validation_0-mlogloss:0.00455
# Saving model after iteration 6
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:37:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02316
# [1]	validation_0-mlogloss:0.02092
# [2]	validation_0-mlogloss:0.01890
# [3]	validation_0-mlogloss:0.01708
# [4]	validation_0-mlogloss:0.01543
# [5]	validation_0-mlogloss:0.01395
# [6]	validation_0-mlogloss:0.01261
# [7]	validation_0-mlogloss:0.01140
# [8]	validation_0-mlogloss:0.01031
# [9]	validation_0-mlogloss:0.00932
# [10]	validation_0-mlogloss:0.00843
# [11]	validation_0-mlogloss:0.00762
# [12]	validation_0-mlogloss:0.00690
# [13]	validation_0-mlogloss:0.00624
# [14]	validation_0-mlogloss:0.00564
# [15]	validation_0-mlogloss:0.00510
# [16]	validation_0-mlogloss:0.00462
# [17]	validation_0-mlogloss:0.00418
# [18]	validation_0-mlogloss:0.00378
# [19]	validation_0-mlogloss:0.00342
# Saving model after iteration 7
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:38:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01683
# [1]	validation_0-mlogloss:0.01521
# [2]	validation_0-mlogloss:0.01374
# [3]	validation_0-mlogloss:0.01242
# [4]	validation_0-mlogloss:0.01123
# [5]	validation_0-mlogloss:0.01016
# [6]	validation_0-mlogloss:0.00918
# [7]	validation_0-mlogloss:0.00830
# [8]	validation_0-mlogloss:0.00751
# [9]	validation_0-mlogloss:0.00679
# [10]	validation_0-mlogloss:0.00614
# [11]	validation_0-mlogloss:0.00556
# [12]	validation_0-mlogloss:0.00503
# [13]	validation_0-mlogloss:0.00455
# [14]	validation_0-mlogloss:0.00411
# [15]	validation_0-mlogloss:0.00372
# [16]	validation_0-mlogloss:0.00337
# [17]	validation_0-mlogloss:0.00305
# [18]	validation_0-mlogloss:0.00276
# [19]	validation_0-mlogloss:0.00249
# Saving model after iteration 8
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:38:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01151
# [1]	validation_0-mlogloss:0.01040
# [2]	validation_0-mlogloss:0.00941
# [3]	validation_0-mlogloss:0.00851
# [4]	validation_0-mlogloss:0.00769
# [5]	validation_0-mlogloss:0.00696
# [6]	validation_0-mlogloss:0.00629
# [7]	validation_0-mlogloss:0.00569
# [8]	validation_0-mlogloss:0.00515
# [9]	validation_0-mlogloss:0.00466
# [10]	validation_0-mlogloss:0.00422
# [11]	validation_0-mlogloss:0.00381
# [12]	validation_0-mlogloss:0.00345
# [13]	validation_0-mlogloss:0.00312
# [14]	validation_0-mlogloss:0.00283
# [15]	validation_0-mlogloss:0.00256
# [16]	validation_0-mlogloss:0.00231
# [17]	validation_0-mlogloss:0.00209
# [18]	validation_0-mlogloss:0.00189
# [19]	validation_0-mlogloss:0.00171
# Saving model after iteration 9
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:38:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00916
# [1]	validation_0-mlogloss:0.00828
# [2]	validation_0-mlogloss:0.00749
# [3]	validation_0-mlogloss:0.00677
# [4]	validation_0-mlogloss:0.00613
# [5]	validation_0-mlogloss:0.00554
# [6]	validation_0-mlogloss:0.00501
# [7]	validation_0-mlogloss:0.00454
# [8]	validation_0-mlogloss:0.00410
# [9]	validation_0-mlogloss:0.00371
# [10]	validation_0-mlogloss:0.00336
# [11]	validation_0-mlogloss:0.00304
# [12]	validation_0-mlogloss:0.00275
# [13]	validation_0-mlogloss:0.00249
# [14]	validation_0-mlogloss:0.00225
# [15]	validation_0-mlogloss:0.00204
# [16]	validation_0-mlogloss:0.00184
# [17]	validation_0-mlogloss:0.00167
# [18]	validation_0-mlogloss:0.00151
# [19]	validation_0-mlogloss:0.00137
# Saving model after iteration 10
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:38:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00565
# [1]	validation_0-mlogloss:0.00511
# [2]	validation_0-mlogloss:0.00462
# [3]	validation_0-mlogloss:0.00418
# [4]	validation_0-mlogloss:0.00379
# [5]	validation_0-mlogloss:0.00342
# [6]	validation_0-mlogloss:0.00310
# [7]	validation_0-mlogloss:0.00280
# [8]	validation_0-mlogloss:0.00254
# [9]	validation_0-mlogloss:0.00230
# [10]	validation_0-mlogloss:0.00208
# [11]	validation_0-mlogloss:0.00188
# [12]	validation_0-mlogloss:0.00170
# [13]	validation_0-mlogloss:0.00154
# [14]	validation_0-mlogloss:0.00139
# [15]	validation_0-mlogloss:0.00126
# [16]	validation_0-mlogloss:0.00114
# [17]	validation_0-mlogloss:0.00103
# [18]	validation_0-mlogloss:0.00094
# [19]	validation_0-mlogloss:0.00085
# Saving model after iteration 11
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:38:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00431
# [1]	validation_0-mlogloss:0.00390
# [2]	validation_0-mlogloss:0.00353
# [3]	validation_0-mlogloss:0.00320
# [4]	validation_0-mlogloss:0.00289
# [5]	validation_0-mlogloss:0.00262
# [6]	validation_0-mlogloss:0.00237
# [7]	validation_0-mlogloss:0.00214
# [8]	validation_0-mlogloss:0.00194
# [9]	validation_0-mlogloss:0.00175
# [10]	validation_0-mlogloss:0.00159
# [11]	validation_0-mlogloss:0.00144
# [12]	validation_0-mlogloss:0.00130
# [13]	validation_0-mlogloss:0.00118
# [14]	validation_0-mlogloss:0.00107
# [15]	validation_0-mlogloss:0.00097
# [16]	validation_0-mlogloss:0.00087
# [17]	validation_0-mlogloss:0.00079
# [18]	validation_0-mlogloss:0.00072
# [19]	validation_0-mlogloss:0.00065
# Saving model after iteration 12
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:38:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00421
# [1]	validation_0-mlogloss:0.00381
# [2]	validation_0-mlogloss:0.00344
# [3]	validation_0-mlogloss:0.00312
# [4]	validation_0-mlogloss:0.00282
# [5]	validation_0-mlogloss:0.00255
# [6]	validation_0-mlogloss:0.00231
# [7]	validation_0-mlogloss:0.00209
# [8]	validation_0-mlogloss:0.00189
# [9]	validation_0-mlogloss:0.00171
# [10]	validation_0-mlogloss:0.00155
# [11]	validation_0-mlogloss:0.00140
# [12]	validation_0-mlogloss:0.00127
# [13]	validation_0-mlogloss:0.00115
# [14]	validation_0-mlogloss:0.00104
# [15]	validation_0-mlogloss:0.00094
# [16]	validation_0-mlogloss:0.00085
# [17]	validation_0-mlogloss:0.00077
# [18]	validation_0-mlogloss:0.00070
# [19]	validation_0-mlogloss:0.00063
# Saving model after iteration 13
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:38:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00446
# [1]	validation_0-mlogloss:0.00403
# [2]	validation_0-mlogloss:0.00365
# [3]	validation_0-mlogloss:0.00330
# [4]	validation_0-mlogloss:0.00299
# [5]	validation_0-mlogloss:0.00270
# [6]	validation_0-mlogloss:0.00245
# [7]	validation_0-mlogloss:0.00221
# [8]	validation_0-mlogloss:0.00200
# [9]	validation_0-mlogloss:0.00181
# [10]	validation_0-mlogloss:0.00164
# [11]	validation_0-mlogloss:0.00148
# [12]	validation_0-mlogloss:0.00134
# [13]	validation_0-mlogloss:0.00122
# [14]	validation_0-mlogloss:0.00110
# [15]	validation_0-mlogloss:0.00100
# [16]	validation_0-mlogloss:0.00090
# [17]	validation_0-mlogloss:0.00082
# [18]	validation_0-mlogloss:0.00074
# [19]	validation_0-mlogloss:0.00067
# Saving model after iteration 14
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:39:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00424
# [1]	validation_0-mlogloss:0.00384
# [2]	validation_0-mlogloss:0.00347
# [3]	validation_0-mlogloss:0.00314
# [4]	validation_0-mlogloss:0.00284
# [5]	validation_0-mlogloss:0.00257
# [6]	validation_0-mlogloss:0.00233
# [7]	validation_0-mlogloss:0.00211
# [8]	validation_0-mlogloss:0.00191
# [9]	validation_0-mlogloss:0.00172
# [10]	validation_0-mlogloss:0.00156
# [11]	validation_0-mlogloss:0.00141
# [12]	validation_0-mlogloss:0.00128
# [13]	validation_0-mlogloss:0.00116
# [14]	validation_0-mlogloss:0.00105
# [15]	validation_0-mlogloss:0.00095
# [16]	validation_0-mlogloss:0.00086
# [17]	validation_0-mlogloss:0.00078
# [18]	validation_0-mlogloss:0.00070
# [19]	validation_0-mlogloss:0.00064
# Saving model after iteration 15
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:39:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00559
# [1]	validation_0-mlogloss:0.00506
# [2]	validation_0-mlogloss:0.00457
# [3]	validation_0-mlogloss:0.00414
# [4]	validation_0-mlogloss:0.00374
# [5]	validation_0-mlogloss:0.00339
# [6]	validation_0-mlogloss:0.00306
# [7]	validation_0-mlogloss:0.00277
# [8]	validation_0-mlogloss:0.00251
# [9]	validation_0-mlogloss:0.00227
# [10]	validation_0-mlogloss:0.00205
# [11]	validation_0-mlogloss:0.00186
# [12]	validation_0-mlogloss:0.00168
# [13]	validation_0-mlogloss:0.00152
# [14]	validation_0-mlogloss:0.00138
# [15]	validation_0-mlogloss:0.00125
# [16]	validation_0-mlogloss:0.00113
# [17]	validation_0-mlogloss:0.00102
# [18]	validation_0-mlogloss:0.00093
# [19]	validation_0-mlogloss:0.00084
# Saving model after iteration 16
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:39:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00649
# [1]	validation_0-mlogloss:0.00587
# [2]	validation_0-mlogloss:0.00531
# [3]	validation_0-mlogloss:0.00480
# [4]	validation_0-mlogloss:0.00434
# [5]	validation_0-mlogloss:0.00393
# [6]	validation_0-mlogloss:0.00355
# [7]	validation_0-mlogloss:0.00321
# [8]	validation_0-mlogloss:0.00291
# [9]	validation_0-mlogloss:0.00263
# [10]	validation_0-mlogloss:0.00238
# [11]	validation_0-mlogloss:0.00215
# [12]	validation_0-mlogloss:0.00195
# [13]	validation_0-mlogloss:0.00176
# [14]	validation_0-mlogloss:0.00160
# [15]	validation_0-mlogloss:0.00144
# [16]	validation_0-mlogloss:0.00131
# [17]	validation_0-mlogloss:0.00118
# [18]	validation_0-mlogloss:0.00107
# [19]	validation_0-mlogloss:0.00097
# Saving model after iteration 17
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:39:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00879
# [1]	validation_0-mlogloss:0.00795
# [2]	validation_0-mlogloss:0.00718
# [3]	validation_0-mlogloss:0.00650
# [4]	validation_0-mlogloss:0.00588
# [5]	validation_0-mlogloss:0.00531
# [6]	validation_0-mlogloss:0.00481
# [7]	validation_0-mlogloss:0.00435
# [8]	validation_0-mlogloss:0.00393
# [9]	validation_0-mlogloss:0.00356
# [10]	validation_0-mlogloss:0.00322
# [11]	validation_0-mlogloss:0.00291
# [12]	validation_0-mlogloss:0.00263
# [13]	validation_0-mlogloss:0.00238
# [14]	validation_0-mlogloss:0.00216
# [15]	validation_0-mlogloss:0.00195
# [16]	validation_0-mlogloss:0.00177
# [17]	validation_0-mlogloss:0.00160
# [18]	validation_0-mlogloss:0.00145
# [19]	validation_0-mlogloss:0.00131
# Saving model after iteration 18
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:39:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01005
# [1]	validation_0-mlogloss:0.00908
# [2]	validation_0-mlogloss:0.00821
# [3]	validation_0-mlogloss:0.00742
# [4]	validation_0-mlogloss:0.00671
# [5]	validation_0-mlogloss:0.00607
# [6]	validation_0-mlogloss:0.00549
# [7]	validation_0-mlogloss:0.00496
# [8]	validation_0-mlogloss:0.00449
# [9]	validation_0-mlogloss:0.00406
# [10]	validation_0-mlogloss:0.00367
# [11]	validation_0-mlogloss:0.00332
# [12]	validation_0-mlogloss:0.00301
# [13]	validation_0-mlogloss:0.00272
# [14]	validation_0-mlogloss:0.00246
# [15]	validation_0-mlogloss:0.00223
# [16]	validation_0-mlogloss:0.00201
# [17]	validation_0-mlogloss:0.00182
# [18]	validation_0-mlogloss:0.00165
# [19]	validation_0-mlogloss:0.00149
# Saving model after iteration 19
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:40:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01242
# [1]	validation_0-mlogloss:0.01122
# [2]	validation_0-mlogloss:0.01014
# [3]	validation_0-mlogloss:0.00916
# [4]	validation_0-mlogloss:0.00828
# [5]	validation_0-mlogloss:0.00749
# [6]	validation_0-mlogloss:0.00677
# [7]	validation_0-mlogloss:0.00612
# [8]	validation_0-mlogloss:0.00554
# [9]	validation_0-mlogloss:0.00501
# [10]	validation_0-mlogloss:0.00453
# [11]	validation_0-mlogloss:0.00410
# [12]	validation_0-mlogloss:0.00371
# [13]	validation_0-mlogloss:0.00335
# [14]	validation_0-mlogloss:0.00303
# [15]	validation_0-mlogloss:0.00274
# [16]	validation_0-mlogloss:0.00248
# [17]	validation_0-mlogloss:0.00225
# [18]	validation_0-mlogloss:0.00203
# [19]	validation_0-mlogloss:0.00184
# Saving model after iteration 20
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:40:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.30271
# [1]	validation_0-mlogloss:0.24489
# [2]	validation_0-mlogloss:0.22138
# [3]	validation_0-mlogloss:0.20001
# [4]	validation_0-mlogloss:0.18074
# [5]	validation_0-mlogloss:0.16343
# [6]	validation_0-mlogloss:0.14788
# [7]	validation_0-mlogloss:0.13370
# [8]	validation_0-mlogloss:0.12091
# [9]	validation_0-mlogloss:0.10937
# [10]	validation_0-mlogloss:0.09900
# [11]	validation_0-mlogloss:0.08962
# [12]	validation_0-mlogloss:0.08108
# [13]	validation_0-mlogloss:0.07335
# [14]	validation_0-mlogloss:0.06635
# [15]	validation_0-mlogloss:0.06004
# [16]	validation_0-mlogloss:0.05432
# [17]	validation_0-mlogloss:0.04915
# [18]	validation_0-mlogloss:0.04446
# [19]	validation_0-mlogloss:0.04024
# Saving model after iteration 1
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:44:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.44731
# [1]	validation_0-mlogloss:0.38324
# [2]	validation_0-mlogloss:0.33853
# [3]	validation_0-mlogloss:0.30090
# [4]	validation_0-mlogloss:0.26865
# [5]	validation_0-mlogloss:0.24055
# [6]	validation_0-mlogloss:0.21580
# [7]	validation_0-mlogloss:0.19390
# [8]	validation_0-mlogloss:0.17450
# [9]	validation_0-mlogloss:0.15718
# [10]	validation_0-mlogloss:0.14174
# [11]	validation_0-mlogloss:0.12785
# [12]	validation_0-mlogloss:0.11540
# [13]	validation_0-mlogloss:0.10421
# [14]	validation_0-mlogloss:0.09411
# [15]	validation_0-mlogloss:0.08503
# [16]	validation_0-mlogloss:0.07687
# [17]	validation_0-mlogloss:0.06948
# [18]	validation_0-mlogloss:0.06281
# [19]	validation_0-mlogloss:0.05679
# Saving model after iteration 2
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:48:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.49115
# [1]	validation_0-mlogloss:0.41786
# [2]	validation_0-mlogloss:0.36408
# [3]	validation_0-mlogloss:0.32050
# [4]	validation_0-mlogloss:0.28405
# [5]	validation_0-mlogloss:0.25293
# [6]	validation_0-mlogloss:0.22599
# [7]	validation_0-mlogloss:0.20244
# [8]	validation_0-mlogloss:0.18168
# [9]	validation_0-mlogloss:0.16329
# [10]	validation_0-mlogloss:0.14695
# [11]	validation_0-mlogloss:0.13238
# [12]	validation_0-mlogloss:0.11934
# [13]	validation_0-mlogloss:0.10765
# [14]	validation_0-mlogloss:0.09715
# [15]	validation_0-mlogloss:0.08774
# [16]	validation_0-mlogloss:0.07926
# [17]	validation_0-mlogloss:0.07160
# [18]	validation_0-mlogloss:0.06470
# [19]	validation_0-mlogloss:0.05848
# Saving model after iteration 3
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:53:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.43676
# [1]	validation_0-mlogloss:0.37147
# [2]	validation_0-mlogloss:0.32276
# [3]	validation_0-mlogloss:0.28369
# [4]	validation_0-mlogloss:0.25116
# [5]	validation_0-mlogloss:0.22347
# [6]	validation_0-mlogloss:0.19954
# [7]	validation_0-mlogloss:0.17865
# [8]	validation_0-mlogloss:0.16028
# [9]	validation_0-mlogloss:0.14402
# [10]	validation_0-mlogloss:0.12957
# [11]	validation_0-mlogloss:0.11673
# [12]	validation_0-mlogloss:0.10521
# [13]	validation_0-mlogloss:0.09488
# [14]	validation_0-mlogloss:0.08562
# [15]	validation_0-mlogloss:0.07730
# [16]	validation_0-mlogloss:0.06981
# [17]	validation_0-mlogloss:0.06307
# [18]	validation_0-mlogloss:0.05699
# [19]	validation_0-mlogloss:0.05151
# Saving model after iteration 4
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [17:59:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.36592
# [1]	validation_0-mlogloss:0.31252
# [2]	validation_0-mlogloss:0.27220
# [3]	validation_0-mlogloss:0.23963
# [4]	validation_0-mlogloss:0.21239
# [5]	validation_0-mlogloss:0.18920
# [6]	validation_0-mlogloss:0.16905
# [7]	validation_0-mlogloss:0.15143
# [8]	validation_0-mlogloss:0.13591
# [9]	validation_0-mlogloss:0.12216
# [10]	validation_0-mlogloss:0.10993
# [11]	validation_0-mlogloss:0.09904
# [12]	validation_0-mlogloss:0.08932
# [13]	validation_0-mlogloss:0.08056
# [14]	validation_0-mlogloss:0.07270
# [15]	validation_0-mlogloss:0.06564
# [16]	validation_0-mlogloss:0.05929
# [17]	validation_0-mlogloss:0.05356
# [18]	validation_0-mlogloss:0.04840
# [19]	validation_0-mlogloss:0.04375
# Saving model after iteration 5
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [18:04:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.26563
# [1]	validation_0-mlogloss:0.23078
# [2]	validation_0-mlogloss:0.20322
# [3]	validation_0-mlogloss:0.18016
# [4]	validation_0-mlogloss:0.16050
# [5]	validation_0-mlogloss:0.14347
# [6]	validation_0-mlogloss:0.12856
# [7]	validation_0-mlogloss:0.11542
# [8]	validation_0-mlogloss:0.10377
# [9]	validation_0-mlogloss:0.09340
# [10]	validation_0-mlogloss:0.08415
# [11]	validation_0-mlogloss:0.07587
# [12]	validation_0-mlogloss:0.06846
# [13]	validation_0-mlogloss:0.06179
# [14]	validation_0-mlogloss:0.05579
# [15]	validation_0-mlogloss:0.05039
# [16]	validation_0-mlogloss:0.04553
# [17]	validation_0-mlogloss:0.04115
# [18]	validation_0-mlogloss:0.03719
# [19]	validation_0-mlogloss:0.03362
# Saving model after iteration 6
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [18:11:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.18878
# [1]	validation_0-mlogloss:0.16553
# [2]	validation_0-mlogloss:0.14655
# [3]	validation_0-mlogloss:0.13049
# [4]	validation_0-mlogloss:0.11662
# [5]	validation_0-mlogloss:0.10450
# [6]	validation_0-mlogloss:0.09382
# [7]	validation_0-mlogloss:0.08436
# [8]	validation_0-mlogloss:0.07596
# [9]	validation_0-mlogloss:0.06844
# [10]	validation_0-mlogloss:0.06171
# [11]	validation_0-mlogloss:0.05568
# [12]	validation_0-mlogloss:0.05026
# [13]	validation_0-mlogloss:0.04539
# [14]	validation_0-mlogloss:0.04100
# [15]	validation_0-mlogloss:0.03704
# [16]	validation_0-mlogloss:0.03348
# [17]	validation_0-mlogloss:0.03026
# [18]	validation_0-mlogloss:0.02736
# [19]	validation_0-mlogloss:0.02474
# Saving model after iteration 7
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [18:18:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.13690
# [1]	validation_0-mlogloss:0.12129
# [2]	validation_0-mlogloss:0.10824
# [3]	validation_0-mlogloss:0.09679
# [4]	validation_0-mlogloss:0.08678
# [5]	validation_0-mlogloss:0.07794
# [6]	validation_0-mlogloss:0.07012
# [7]	validation_0-mlogloss:0.06315
# [8]	validation_0-mlogloss:0.05691
# [9]	validation_0-mlogloss:0.05133
# [10]	validation_0-mlogloss:0.04632
# [11]	validation_0-mlogloss:0.04182
# [12]	validation_0-mlogloss:0.03777
# [13]	validation_0-mlogloss:0.03412
# [14]	validation_0-mlogloss:0.03083
# [15]	validation_0-mlogloss:0.02787
# [16]	validation_0-mlogloss:0.02519
# [17]	validation_0-mlogloss:0.02277
# [18]	validation_0-mlogloss:0.02059
# [19]	validation_0-mlogloss:0.01862
# Saving model after iteration 8
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [18:25:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.10184
# [1]	validation_0-mlogloss:0.09014
# [2]	validation_0-mlogloss:0.08037
# [3]	validation_0-mlogloss:0.07194
# [4]	validation_0-mlogloss:0.06457
# [5]	validation_0-mlogloss:0.05805
# [6]	validation_0-mlogloss:0.05225
# [7]	validation_0-mlogloss:0.04708
# [8]	validation_0-mlogloss:0.04245
# [9]	validation_0-mlogloss:0.03831
# [10]	validation_0-mlogloss:0.03458
# [11]	validation_0-mlogloss:0.03124
# [12]	validation_0-mlogloss:0.02822
# [13]	validation_0-mlogloss:0.02550
# [14]	validation_0-mlogloss:0.02305
# [15]	validation_0-mlogloss:0.02083
# [16]	validation_0-mlogloss:0.01884
# [17]	validation_0-mlogloss:0.01703
# [18]	validation_0-mlogloss:0.01540
# [19]	validation_0-mlogloss:0.01393
# Saving model after iteration 9
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [18:33:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.07397
# [1]	validation_0-mlogloss:0.06519
# [2]	validation_0-mlogloss:0.05800
# [3]	validation_0-mlogloss:0.05186
# [4]	validation_0-mlogloss:0.04652
# [5]	validation_0-mlogloss:0.04180
# [6]	validation_0-mlogloss:0.03762
# [7]	validation_0-mlogloss:0.03389
# [8]	validation_0-mlogloss:0.03056
# [9]	validation_0-mlogloss:0.02757
# [10]	validation_0-mlogloss:0.02489
# [11]	validation_0-mlogloss:0.02248
# [12]	validation_0-mlogloss:0.02031
# [13]	validation_0-mlogloss:0.01835
# [14]	validation_0-mlogloss:0.01659
# [15]	validation_0-mlogloss:0.01499
# [16]	validation_0-mlogloss:0.01356
# [17]	validation_0-mlogloss:0.01226
# [18]	validation_0-mlogloss:0.01109
# [19]	validation_0-mlogloss:0.01003
# Saving model after iteration 10
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [18:42:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.05595
# [1]	validation_0-mlogloss:0.04908
# [2]	validation_0-mlogloss:0.04356
# [3]	validation_0-mlogloss:0.03889
# [4]	validation_0-mlogloss:0.03484
# [5]	validation_0-mlogloss:0.03129
# [6]	validation_0-mlogloss:0.02815
# [7]	validation_0-mlogloss:0.02535
# [8]	validation_0-mlogloss:0.02285
# [9]	validation_0-mlogloss:0.02061
# [10]	validation_0-mlogloss:0.01860
# [11]	validation_0-mlogloss:0.01680
# [12]	validation_0-mlogloss:0.01518
# [13]	validation_0-mlogloss:0.01371
# [14]	validation_0-mlogloss:0.01239
# [15]	validation_0-mlogloss:0.01120
# [16]	validation_0-mlogloss:0.01013
# [17]	validation_0-mlogloss:0.00916
# [18]	validation_0-mlogloss:0.00828
# [19]	validation_0-mlogloss:0.00749
# Saving model after iteration 11
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [18:51:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.04291
# [1]	validation_0-mlogloss:0.03736
# [2]	validation_0-mlogloss:0.03302
# [3]	validation_0-mlogloss:0.02940
# [4]	validation_0-mlogloss:0.02629
# [5]	validation_0-mlogloss:0.02357
# [6]	validation_0-mlogloss:0.02118
# [7]	validation_0-mlogloss:0.01906
# [8]	validation_0-mlogloss:0.01717
# [9]	validation_0-mlogloss:0.01548
# [10]	validation_0-mlogloss:0.01396
# [11]	validation_0-mlogloss:0.01260
# [12]	validation_0-mlogloss:0.01138
# [13]	validation_0-mlogloss:0.01028
# [14]	validation_0-mlogloss:0.00929
# [15]	validation_0-mlogloss:0.00840
# [16]	validation_0-mlogloss:0.00759
# [17]	validation_0-mlogloss:0.00687
# [18]	validation_0-mlogloss:0.00621
# [19]	validation_0-mlogloss:0.00561
# Saving model after iteration 12
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [19:01:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03165
# [1]	validation_0-mlogloss:0.02719
# [2]	validation_0-mlogloss:0.02383
# [3]	validation_0-mlogloss:0.02110
# [4]	validation_0-mlogloss:0.01880
# [5]	validation_0-mlogloss:0.01681
# [6]	validation_0-mlogloss:0.01507
# [7]	validation_0-mlogloss:0.01354
# [8]	validation_0-mlogloss:0.01218
# [9]	validation_0-mlogloss:0.01097
# [10]	validation_0-mlogloss:0.00989
# [11]	validation_0-mlogloss:0.00892
# [12]	validation_0-mlogloss:0.00805
# [13]	validation_0-mlogloss:0.00727
# [14]	validation_0-mlogloss:0.00657
# [15]	validation_0-mlogloss:0.00594
# [16]	validation_0-mlogloss:0.00536
# [17]	validation_0-mlogloss:0.00485
# [18]	validation_0-mlogloss:0.00439
# [19]	validation_0-mlogloss:0.00397
# Saving model after iteration 13
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [19:11:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02655
# [1]	validation_0-mlogloss:0.02258
# [2]	validation_0-mlogloss:0.01968
# [3]	validation_0-mlogloss:0.01735
# [4]	validation_0-mlogloss:0.01540
# [5]	validation_0-mlogloss:0.01374
# [6]	validation_0-mlogloss:0.01230
# [7]	validation_0-mlogloss:0.01103
# [8]	validation_0-mlogloss:0.00991
# [9]	validation_0-mlogloss:0.00892
# [10]	validation_0-mlogloss:0.00803
# [11]	validation_0-mlogloss:0.00724
# [12]	validation_0-mlogloss:0.00653
# [13]	validation_0-mlogloss:0.00590
# [14]	validation_0-mlogloss:0.00533
# [15]	validation_0-mlogloss:0.00481
# [16]	validation_0-mlogloss:0.00435
# [17]	validation_0-mlogloss:0.00393
# [18]	validation_0-mlogloss:0.00355
# [19]	validation_0-mlogloss:0.00321
# Saving model after iteration 14
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [19:22:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02325
# [1]	validation_0-mlogloss:0.01961
# [2]	validation_0-mlogloss:0.01699
# [3]	validation_0-mlogloss:0.01492
# [4]	validation_0-mlogloss:0.01321
# [5]	validation_0-mlogloss:0.01176
# [6]	validation_0-mlogloss:0.01050
# [7]	validation_0-mlogloss:0.00941
# [8]	validation_0-mlogloss:0.00844
# [9]	validation_0-mlogloss:0.00759
# [10]	validation_0-mlogloss:0.00683
# [11]	validation_0-mlogloss:0.00616
# [12]	validation_0-mlogloss:0.00555
# [13]	validation_0-mlogloss:0.00501
# [14]	validation_0-mlogloss:0.00452
# [15]	validation_0-mlogloss:0.00408
# [16]	validation_0-mlogloss:0.00369
# [17]	validation_0-mlogloss:0.00333
# [18]	validation_0-mlogloss:0.00301
# [19]	validation_0-mlogloss:0.00272
# Saving model after iteration 15
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [19:34:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02136
# [1]	validation_0-mlogloss:0.01797
# [2]	validation_0-mlogloss:0.01554
# [3]	validation_0-mlogloss:0.01362
# [4]	validation_0-mlogloss:0.01205
# [5]	validation_0-mlogloss:0.01071
# [6]	validation_0-mlogloss:0.00956
# [7]	validation_0-mlogloss:0.00856
# [8]	validation_0-mlogloss:0.00767
# [9]	validation_0-mlogloss:0.00690
# [10]	validation_0-mlogloss:0.00621
# [11]	validation_0-mlogloss:0.00559
# [12]	validation_0-mlogloss:0.00504
# [13]	validation_0-mlogloss:0.00454
# [14]	validation_0-mlogloss:0.00410
# [15]	validation_0-mlogloss:0.00370
# [16]	validation_0-mlogloss:0.00335
# [17]	validation_0-mlogloss:0.00302
# [18]	validation_0-mlogloss:0.00273
# [19]	validation_0-mlogloss:0.00247
# Saving model after iteration 16
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [19:47:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01906
# [1]	validation_0-mlogloss:0.01608
# [2]	validation_0-mlogloss:0.01390
# [3]	validation_0-mlogloss:0.01218
# [4]	validation_0-mlogloss:0.01076
# [5]	validation_0-mlogloss:0.00956
# [6]	validation_0-mlogloss:0.00853
# [7]	validation_0-mlogloss:0.00763
# [8]	validation_0-mlogloss:0.00684
# [9]	validation_0-mlogloss:0.00615
# [10]	validation_0-mlogloss:0.00553
# [11]	validation_0-mlogloss:0.00498
# [12]	validation_0-mlogloss:0.00449
# [13]	validation_0-mlogloss:0.00405
# [14]	validation_0-mlogloss:0.00365
# [15]	validation_0-mlogloss:0.00330
# [16]	validation_0-mlogloss:0.00298
# [17]	validation_0-mlogloss:0.00269
# [18]	validation_0-mlogloss:0.00243
# [19]	validation_0-mlogloss:0.00220
# Saving model after iteration 17
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [20:00:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01797
# [1]	validation_0-mlogloss:0.01509
# [2]	validation_0-mlogloss:0.01301
# [3]	validation_0-mlogloss:0.01138
# [4]	validation_0-mlogloss:0.01003
# [5]	validation_0-mlogloss:0.00890
# [6]	validation_0-mlogloss:0.00793
# [7]	validation_0-mlogloss:0.00709
# [8]	validation_0-mlogloss:0.00636
# [9]	validation_0-mlogloss:0.00571
# [10]	validation_0-mlogloss:0.00513
# [11]	validation_0-mlogloss:0.00462
# [12]	validation_0-mlogloss:0.00416
# [13]	validation_0-mlogloss:0.00375
# [14]	validation_0-mlogloss:0.00339
# [15]	validation_0-mlogloss:0.00306
# [16]	validation_0-mlogloss:0.00276
# [17]	validation_0-mlogloss:0.00249
# [18]	validation_0-mlogloss:0.00225
# [19]	validation_0-mlogloss:0.00204
# Saving model after iteration 18
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [20:14:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01388
# [1]	validation_0-mlogloss:0.01201
# [2]	validation_0-mlogloss:0.01052
# [3]	validation_0-mlogloss:0.00929
# [4]	validation_0-mlogloss:0.00825
# [5]	validation_0-mlogloss:0.00735
# [6]	validation_0-mlogloss:0.00658
# [7]	validation_0-mlogloss:0.00589
# [8]	validation_0-mlogloss:0.00529
# [9]	validation_0-mlogloss:0.00476
# [10]	validation_0-mlogloss:0.00428
# [11]	validation_0-mlogloss:0.00386
# [12]	validation_0-mlogloss:0.00348
# [13]	validation_0-mlogloss:0.00314
# [14]	validation_0-mlogloss:0.00283
# [15]	validation_0-mlogloss:0.00256
# [16]	validation_0-mlogloss:0.00231
# [17]	validation_0-mlogloss:0.00209
# [18]	validation_0-mlogloss:0.00189
# [19]	validation_0-mlogloss:0.00171
# Saving model after iteration 19
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [20:29:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01284
# [1]	validation_0-mlogloss:0.01115
# [2]	validation_0-mlogloss:0.00980
# [3]	validation_0-mlogloss:0.00866
# [4]	validation_0-mlogloss:0.00770
# [5]	validation_0-mlogloss:0.00687
# [6]	validation_0-mlogloss:0.00615
# [7]	validation_0-mlogloss:0.00551
# [8]	validation_0-mlogloss:0.00495
# [9]	validation_0-mlogloss:0.00445
# [10]	validation_0-mlogloss:0.00401
# [11]	validation_0-mlogloss:0.00361
# [12]	validation_0-mlogloss:0.00326
# [13]	validation_0-mlogloss:0.00294
# [14]	validation_0-mlogloss:0.00266
# [15]	validation_0-mlogloss:0.00240
# [16]	validation_0-mlogloss:0.00217
# [17]	validation_0-mlogloss:0.00196
# [18]	validation_0-mlogloss:0.00177
# [19]	validation_0-mlogloss:0.00160
# Saving model after iteration 20
# Random Forest Illness Prediction - Accuracy Score: 0.9998401710170118
# Random Forest Illness Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                            precision    recall  f1-score   support
#
#                                                 1.00      1.00      1.00    100060
#                  Chest Infection moderate       1.00      1.00      1.00         1
#                    Chest Infection severe       1.00      1.00      1.00         1
#                          Common Cold mild       1.00      1.00      1.00         5
#                      Common Cold moderate       0.73      1.00      0.84         8
#                        Common Cold severe       0.00      0.00      0.00         3
#                        Diarrhoea moderate       0.00      0.00      0.00         0
#                           Diarrhoea other       0.00      0.00      0.00         1
#                    Eye Infection moderate       0.00      0.00      0.00         2
#                              Flu moderate       0.17      1.00      0.29         2
#                                 Flu other       0.00      0.00      0.00         2
#                                Flu severe       0.00      0.00      0.00         6
#                   Headache/Migraine other       0.00      0.00      0.00         1
#                    Nausea/Vomiting severe       1.00      1.00      1.00         1
# Other - see additional information severe       1.00      1.00      1.00         3
#              Other Viral Infection severe       1.00      1.00      1.00         2
#             Sore Throat/ Tonsillitis mild       0.80      1.00      0.89         4
#         Sore Throat/ Tonsillitis moderate       0.00      0.00      0.00         1
#           Sore Throat/ Tonsillitis severe       1.00      1.00      1.00         4
#
#                                  accuracy                           1.00    100107
#                                 macro avg       0.51      0.58      0.53    100107
#                              weighted avg       1.00      1.00      1.00    100107
#
# Random Forest Illness Prediction - Confusion Matrix:
# Logistic Regression Illness Prediction - Accuracy Score: 0.9998401710170118
# Logistic Regression Illness Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                            precision    recall  f1-score   support
#
#                                                 1.00      1.00      1.00    100060
#                  Chest Infection moderate       0.33      1.00      0.50         1
#                    Chest Infection severe       1.00      1.00      1.00         1
#                          Common Cold mild       1.00      1.00      1.00         5
#                      Common Cold moderate       0.73      1.00      0.84         8
#                        Common Cold severe       0.00      0.00      0.00         3
#                        Diarrhoea moderate       0.00      0.00      0.00         0
#                           Diarrhoea other       0.00      0.00      0.00         1
#                    Eye Infection moderate       0.00      0.00      0.00         2
#                              Flu moderate       0.20      1.00      0.33         2
#                                 Flu other       0.00      0.00      0.00         2
#                                Flu severe       0.00      0.00      0.00         6
#                   Headache/Migraine other       0.00      0.00      0.00         1
#                    Nausea/Vomiting severe       1.00      1.00      1.00         1
# ...
#               Knee Other moderate       1.00      1.00      1.00         3
#              Knee Sprain moderate       1.00      1.00      1.00         1
#                  Knee Strain mild       0.00      0.00      0.00         0
#              Knee Strain moderate       1.00      1.00      1.00         3
#                 Knee Strain other       0.00      0.00      0.00         1
#                Knee Strain severe       1.00      1.00      1.00         1
#     Lumbar Fracture/Stress severe       0.00      0.00      0.00         1
#             Lumbar Other moderate       0.00      0.00      0.00         2
#            Lumbar Strain moderate       0.50      1.00      0.67         2
#              Lumbar Strain severe       1.00      1.00      1.00         1
# Other - see notes Sprain moderate       0.00      0.00      0.00         0
#   Other - see notes Sprain severe       0.00      0.00      0.00         1
#     Ribs Fracture/Stress moderate       0.00      0.00      0.00         0
#     Shoulder Dislocation moderate       0.00      0.00      0.00         0
#              Shoulder Strain mild       0.00      0.00      0.00         1
#          Shoulder Strain moderate       1.00      1.00      1.00         4
#             Shoulder Strain other       0.50      1.00      0.67         1
#            Shoulder Strain severe       1.00      1.00      1.00         1
#       Shoulder Subluxation severe       1.00      1.00      1.00         1
#             Thumb Sprain moderate       1.00      1.00      1.00         1
#          Upper Leg Other moderate       1.00      1.00      1.00         1
#     Wrist Fracture/Break moderate       0.00      0.00      0.00         2
#                Wrist Sprain other       0.00      0.00      0.00         0
#
#                          accuracy                           1.00    100107
#                         macro avg       0.45      0.48      0.46    100107
#                      weighted avg       1.00      1.00      1.00    100107
#
# Random Forest Injury Prediction - Confusion Matrix:
# Logistic Regression Injury Prediction - Accuracy Score: 0.9998002137712647
# Logistic Regression Injury Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                         precision    recall  f1-score   support
#
#                                              1.00      1.00      1.00    100034
#          Ankle Fracture/Break moderate       0.00      0.00      0.00         0
#              Ankle Laceration moderate       1.00      1.00      1.00         1
#                     Ankle Other severe       1.00      1.00      1.00         1
#                      Ankle Sprain mild       1.00      1.00      1.00         5
#                  Ankle Sprain moderate       1.00      1.00      1.00         6
#                     Ankle Sprain other       0.00      0.00      0.00         1
#                    Ankle Sprain severe       1.00      1.00      1.00         2
#                  Ankle Strain moderate       1.00      1.00      1.00         1
#                     Ankle Strain other       0.00      0.00      0.00         0
#                       Chest Other mild       0.00      0.00      0.00         1
#             Elbow Dislocation moderate       0.00      0.00      0.00         1
#                  Elbow Sprain moderate       0.00      0.00      0.00         0
#             Fingers Dislocation severe       0.00      0.00      0.00         1
#            Fingers Fracture/Break mild       0.00      0.00      0.00         1
#        Fingers Fracture/Break moderate       0.25      1.00      0.40         1
#          Fingers Fracture/Break severe       0.00      0.00      0.00         1
#                     Fingers Other mild       0.00      0.00      0.00         0
#                    Fingers Sprain mild       0.00      0.00      0.00         1
#                Fingers Sprain moderate       0.00      0.00      0.00         1
#                      Foot Other severe       1.00      1.00      1.00         2
#                      Groin Strain mild       0.00      0.00      0.00         1
#                  Groin Strain moderate       0.00      0.00      0.00         0
#              Hand Fracture/Break other       0.00      0.00      0.00         0
#             Hand Fracture/Break severe       0.00      0.00      0.00         1
#                   Hand Sprain moderate       1.00      1.00      1.00         1
#               Head Concussion moderate       1.00      1.00      1.00         4
#                  Head Concussion other       1.00      1.00      1.00         1
#                 Head Concussion severe       1.00      1.00      1.00         5
#                        Hip Strain mild       1.00      1.00      1.00         2
#                Knee Dislocation severe       0.00      0.00      0.00         1
#            Knee Fracture/Stress severe       0.00      0.00      0.00         1
#                        Knee Other mild       1.00      1.00      1.00         1
#                    Knee Other moderate       1.00      1.00      1.00         3
#                   Knee Sprain moderate       1.00      1.00      1.00         1
#                   Knee Strain moderate       1.00      1.00      1.00         3
#                      Knee Strain other       0.00      0.00      0.00         1
#                     Knee Strain severe       1.00      1.00      1.00         1
#          Lumbar Fracture/Stress severe       0.00      0.00      0.00         1
#                  Lumbar Other moderate       0.00      0.00      0.00         2
#                    Lumbar Other severe       0.00      0.00      0.00         0
#                 Lumbar Strain moderate       1.00      1.00      1.00         2
#                   Lumbar Strain severe       1.00      1.00      1.00         1
# Other - see notes Fracture/Stress mild       0.00      0.00      0.00         0
#           Other - see notes Other mild       0.00      0.00      0.00         0
#         Other - see notes Other severe       0.00      0.00      0.00         0
#        Other - see notes Sprain severe       0.00      0.00      0.00         1
#            Shoulder Dislocation severe       0.00      0.00      0.00         0
#                   Shoulder Sprain mild       0.00      0.00      0.00         0
#                   Shoulder Strain mild       0.00      0.00      0.00         1
#               Shoulder Strain moderate       1.00      1.00      1.00         4
#                  Shoulder Strain other       1.00      1.00      1.00         1
#                 Shoulder Strain severe       1.00      1.00      1.00         1
#            Shoulder Subluxation severe       1.00      1.00      1.00         1
#                  Thumb Sprain moderate       1.00      1.00      1.00         1
#               Upper Leg Other moderate       1.00      1.00      1.00         1
#          Wrist Fracture/Break moderate       0.00      0.00      0.00         2
#
#                               accuracy                           1.00    100107
#                              macro avg       0.46      0.47      0.46    100107
#                           weighted avg       1.00      1.00      1.00    100107
#
# Logistic Regression Injury Prediction - Confusion Matrix:
# XGBoost Injury Prediction - Accuracy Score: 0.9998002137712647
# XGBoost Injury Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                    precision    recall  f1-score   support
#
#                                         1.00      1.00      1.00    100034
#         Ankle Laceration moderate       1.00      1.00      1.00         1
#                  Ankle Other mild       0.00      0.00      0.00         0
#                Ankle Other severe       1.00      1.00      1.00         1
#                 Ankle Sprain mild       1.00      1.00      1.00         5
#             Ankle Sprain moderate       1.00      1.00      1.00         6
#                Ankle Sprain other       0.00      0.00      0.00         1
#               Ankle Sprain severe       1.00      1.00      1.00         2
#             Ankle Strain moderate       1.00      1.00      1.00         1
#                Ankle Strain other       0.00      0.00      0.00         0
#                  Chest Other mild       0.00      0.00      0.00         1
#        Elbow Dislocation moderate       0.00      0.00      0.00         1
#         Eye Fracture/Break severe       0.00      0.00      0.00         0
#         Fingers Abrasion moderate       0.00      0.00      0.00         0
#        Fingers Dislocation severe       0.00      0.00      0.00         1
#       Fingers Fracture/Break mild       0.00      0.00      0.00         1
#   Fingers Fracture/Break moderate       0.33      1.00      0.50         1
#     Fingers Fracture/Break severe       0.00      0.00      0.00         1
#                Fingers Other mild       0.00      0.00      0.00         0
#               Fingers Sprain mild       0.00      0.00      0.00         1
#           Fingers Sprain moderate       0.00      0.00      0.00         1
#                 Foot Other severe       1.00      1.00      1.00         2
#             Groin Sprain moderate       0.00      0.00      0.00         0
#                 Groin Strain mild       0.00      0.00      0.00         1
#           Hand Dislocation severe       0.00      0.00      0.00         0
#         Hand Fracture/Break other       0.00      0.00      0.00         0
#        Hand Fracture/Break severe       0.00      0.00      0.00         1
#              Hand Sprain moderate       1.00      1.00      1.00         1
#          Head Concussion moderate       1.00      1.00      1.00         4
#             Head Concussion other       1.00      1.00      1.00         1
#            Head Concussion severe       1.00      1.00      1.00         5
#                   Hip Strain mild       1.00      1.00      1.00         2
#           Knee Dislocation severe       0.00      0.00      0.00         1
#       Knee Fracture/Stress severe       0.00      0.00      0.00         1
#             Knee Laceration other       0.00      0.00      0.00         0
#                   Knee Other mild       1.00      1.00      1.00         1
#               Knee Other moderate       1.00      1.00      1.00         3
#              Knee Sprain moderate       1.00      1.00      1.00         1
#                  Knee Strain mild       0.00      0.00      0.00         0
#              Knee Strain moderate       1.00      1.00      1.00         3
#                 Knee Strain other       0.00      0.00      0.00         1
#                Knee Strain severe       1.00      1.00      1.00         1
#     Lumbar Fracture/Stress severe       0.00      0.00      0.00         1
#             Lumbar Other moderate       0.00      0.00      0.00         2
#                Lumbar Sprain mild       0.00      0.00      0.00         0
#            Lumbar Strain moderate       1.00      1.00      1.00         2
#              Lumbar Strain severe       0.33      1.00      0.50         1
# Other - see notes Sprain moderate       0.00      0.00      0.00         0
#   Other - see notes Sprain severe       0.00      0.00      0.00         1
#     Shoulder Dislocation moderate       0.00      0.00      0.00         0
#              Shoulder Sprain mild       0.00      0.00      0.00         0
#              Shoulder Strain mild       0.00      0.00      0.00         1
#          Shoulder Strain moderate       1.00      1.00      1.00         4
#             Shoulder Strain other       1.00      1.00      1.00         1
#            Shoulder Strain severe       1.00      1.00      1.00         1
#       Shoulder Subluxation severe       1.00      1.00      1.00         1
#             Thumb Sprain moderate       1.00      1.00      1.00         1
#          Upper Leg Other moderate       1.00      1.00      1.00         1
#     Wrist Fracture/Break moderate       0.00      0.00      0.00         2
#
#                          accuracy                           1.00    100107
#                         macro avg       0.44      0.46      0.44    100107
#                      weighted avg       1.00      1.00      1.00    100107
#
# XGBoost Injury Prediction - Confusion Matrix:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
import xgboost as xgb
import matplotlib.pyplot as plt
import openpyxl
from openpyxl.styles import PatternFill
from openpyxl.drawing.image import Image
from openpyxl import Workbook
import os
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib
from imblearn.over_sampling import RandomOverSampler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
import shutil

# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-1:  Model Initializing for Injury/Illness Details Prediction
print("start execution")

# directory to save models
model_dir = 'saved_models_additional_v2_no_severity'

if os.path.exists(model_dir):
    shutil.rmtree(model_dir)
os.makedirs(model_dir)
    
# set GPU acceleration
def setup_gpu_acceleration():
    try:
        from xgboost import XGBClassifier
        return XGBClassifier(tree_method='hist', device='cpu')
    except ImportError:
        print("Metal acceleration not available. Falling back to CPU.")
        return XGBClassifier(tree_method='hist', device='cpu')

# set checkpoints
def train_model_with_checkpoints(model, X_train, y_train, model_path, model_type="injury", checkpoint_interval=1, max_rounds=20):
    checkpoint_path = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint.pkl')
    checkpoint_file = os.path.join(model_dir, f'xgb_{model_type}_model_checkpoint_rounds.txt')
    start_iteration = 0

    # check if there's an existing model or checkpoint to resume from
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        model = joblib.load(model_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration
    elif os.path.exists(checkpoint_path):
        print(f"Resuming training from checkpoint: {checkpoint_path}")
        model = joblib.load(checkpoint_path)
        if hasattr(model, 'best_iteration'):
            start_iteration = model.best_iteration

        if os.path.exists(checkpoint_file):
            with open(checkpoint_file, 'r') as f:
                checkpoint_rounds = int(f.read().strip())
                print(f"Resuming from saved round: {checkpoint_rounds}")
                start_iteration = checkpoint_rounds

            if checkpoint_rounds is not None:
                start_iteration = checkpoint_rounds

    # training the model
    eval_set = [(X_train, y_train)]

    # if continuing from an existing model or checkpoint, resume training
    for i in range(start_iteration, max_rounds):
        model.fit(X_train, y_train, eval_set=eval_set, verbose=True, xgb_model=model.get_booster() if i > 0 else None)
        
        # save checkpoint after each round
        print(f"Saving model after iteration {i+1}")
        joblib.dump(model, checkpoint_path)  # save the model checkpoint
        
        # save the round checkpoint number
        with open(checkpoint_file, 'w') as f:
            f.write(str(i + 1))

    # save the final model
    joblib.dump(model, model_path)

    return model

# load training and testing data
train_df = pd.read_excel("cleaned_training_data_v3.xlsx")
test_df = pd.read_excel("cleaned_test_data_v3.xlsx")
realuse_df = pd.read_excel("cleaned_realuse_data_v3.xlsx")

# preprocessing the numeric features
numeric_features = ['Gender_m2f1', 'Menstruation_y1n0', 'Mood state', 'Energy levels',
                    'Muscle readiness', 'Academic Pressure', 'Diet Yesterday', 'Sleep quality',
                    'Sleep duration', 'sleep_score', 'total_training_load', 'total_training_duration',
                    'weekly_training_load', 'weekly_training_duration', 'ACWR', 'RTT', 'illed', 'injured']

# separate numeric features from the rest
X_train = train_df[numeric_features]
X_test = test_df[numeric_features]
X_real = realuse_df[numeric_features]

# preprocessing the text data

# combine text columns for illness and injury separately
illness_columns = ['Type of illness', 'Illness severity']
injury_columns = ['Injury location', 'Injury type']

# fill missing values with empty strings and concatenate the text columns
train_df['illness_text'] = train_df[illness_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_text'] = train_df[injury_columns].fillna('').agg(' '.join, axis=1)
test_df['illness_text'] = test_df[illness_columns].fillna('').agg(' '.join, axis=1)
test_df['injury_text'] = test_df[injury_columns].fillna('').agg(' '.join, axis=1)
realuse_df['illness_text'] = realuse_df[illness_columns].fillna('').agg(' '.join, axis=1)
realuse_df['injury_text'] = realuse_df[injury_columns].fillna('').agg(' '.join, axis=1)
train_df['injury_information'] = train_df['injury_text'].fillna("No Injury")
train_df['illness_information'] = train_df['illness_text'].fillna("No Illness")
test_df['injury_information'] = test_df['injury_text'].fillna("No Injury")
test_df['illness_information'] = test_df['illness_text'].fillna("No Illness")
realuse_df['injury_information'] = realuse_df['injury_text'].fillna("No Injury")
realuse_df['illness_information'] = realuse_df['illness_text'].fillna("No Illness")

vectorizer_files = ['tfidf_vectorizer_illness.pkl', 'tfidf_vectorizer_injury.pkl']
for file in vectorizer_files:
    filepath = os.path.join(model_dir, file)
    if os.path.exists(filepath):
        os.remove(filepath)
        
# vectorize the text data using TfidfVectorizer
tfidf_vectorizer_illness = TfidfVectorizer(max_features=500)
tfidf_vectorizer_injury = TfidfVectorizer(max_features=500)

# fit on training data, then transform test and real use data
X_illness_train = tfidf_vectorizer_illness.fit_transform(train_df['illness_information'])
X_injury_train = tfidf_vectorizer_injury.fit_transform(train_df['injury_information'])

# save the vectorizers
print("Saving vectorizers...")
joblib.dump(tfidf_vectorizer_illness, os.path.join(model_dir, 'tfidf_vectorizer_illness.pkl'))
joblib.dump(tfidf_vectorizer_injury, os.path.join(model_dir, 'tfidf_vectorizer_injury.pkl'))

X_illness_test = tfidf_vectorizer_illness.transform(test_df['illness_information'])
X_injury_test = tfidf_vectorizer_injury.transform(test_df['injury_information'])
print("Injury test shape:", X_injury_test.shape)
X_illness_real = tfidf_vectorizer_illness.transform(realuse_df['illness_information'])
X_injury_real = tfidf_vectorizer_injury.transform(realuse_df['injury_information'])
# check feature dimensions for test and real-use data
print("Test features for illness model:", X_illness_test.shape[1])
print("Real-use features for illness model:", X_illness_real.shape[1])
print("Test features for injury model:",X_injury_train.shape)
print("Real-use features for injury model:",X_injury_test.shape)

# create an instance of RandomOverSampler
ros = RandomOverSampler(random_state=42)

# resample the training data based on illness and injury (use RandomOverSampler instead of SMOTE)
X_resampled_illness, y_resampled_illness = ros.fit_resample(X_illness_train, train_df['illness_information'])
X_resampled_injury, y_resampled_injury = ros.fit_resample(X_injury_train, train_df['injury_information'])

X_train_illness, X_test_illness, y_train_illness, y_test_illness = train_test_split(X_resampled_illness, y_resampled_illness, test_size=0.2, random_state=42)
X_train_injury, X_test_injury, y_train_injury, y_test_injury = train_test_split(X_resampled_injury, y_resampled_injury, test_size=0.2, random_state=42)
# -----------------------------------------------------------------------------------------------------------------------------------------
## Step 4-2: Model Selection, Hyperparameters Fine Tuning, Training

# model file paths
rf_illness_model_path = os.path.join(model_dir, 'rf_model_illness.pkl')
rf_injury_model_path = os.path.join(model_dir, 'rf_model_injury.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_injury_model_path = os.path.join(model_dir, 'log_reg_model_injury.pkl')
xgb_illness_model_path = os.path.join(model_dir, 'xgb_model_illness.pkl')
xgb_injury_model_path = os.path.join(model_dir, 'xgb_model_injury.pkl')
xgb_illness_label_encoder_path = os.path.join(model_dir, 'xgb_illness_label_encoder.pkl')
xgb_injury_label_encoder_path = os.path.join(model_dir, 'xgb_injury_label_encoder.pkl')
log_reg_illness_model_path = os.path.join(model_dir, 'log_reg_model_illness.pkl')
log_reg_illness_label_encoder_path = os.path.join(model_dir, 'label_encoder_log_reg_illness.pkl')

# check if models are saved, and load them if available
def load_model(model_path):
    if os.path.exists(model_path):
        print(f"Loading saved model from: {model_path}")
        return joblib.load(model_path)
    return None

# load existing models or train if they exist
best_rf_model_illness = load_model(rf_illness_model_path)
best_rf_model_injury = load_model(rf_injury_model_path)
best_log_reg_model_illness = load_model(log_reg_illness_model_path)
best_log_reg_model_injury = load_model(log_reg_injury_model_path)
best_xgb_model_illness = load_model(xgb_illness_model_path)
best_xgb_model_injury = load_model(xgb_injury_model_path)

# if no model is loaded, perform hyperparameter tuning and training
if best_rf_model_illness is None:
    # randomForest for illness prediction with predefined hyperparameters
    rf_param_illness = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_illness = RandomForestClassifier(random_state=42, **rf_param_illness)
    best_rf_model_illness.fit(X_train_illness, y_train_illness)
    joblib.dump(best_rf_model_illness, rf_illness_model_path)

if best_rf_model_injury is None:
    # randomForest for injury prediction with predefined hyperparameters
    rf_param_injury = {
        'n_estimators': 200,
        'max_depth': 20,
        'min_samples_split': 5,
        'min_samples_leaf': 2,
        'max_features': 'sqrt',
        'class_weight': 'balanced'
    }
    best_rf_model_injury = RandomForestClassifier(random_state=42, **rf_param_injury)
    best_rf_model_injury.fit(X_train_injury, y_train_injury)
    joblib.dump(best_rf_model_injury, rf_injury_model_path)

if best_log_reg_model_illness is None:
    # encode the string labels to numeric labels
    label_encoder_illness = LabelEncoder()
    y_train_illness_encoded = label_encoder_illness.fit_transform(y_train_illness)
    joblib.dump(label_encoder_illness, 'label_encoder_log_reg_illness.pkl')
    # get unique classes in the encoded labels
    unique_classes_illness = np.unique(y_train_illness_encoded)
    # calculate class weights
    class_weights_illness = compute_class_weight('balanced', classes=unique_classes_illness, y=y_train_illness_encoded)
    class_weight_dict_illness = dict(zip(unique_classes_illness, class_weights_illness))
    log_reg_param_illness = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_illness
    }
    best_log_reg_model_illness = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_illness)
    best_log_reg_model_illness.fit(X_train_illness, y_train_illness_encoded)
    joblib.dump(best_log_reg_model_illness, log_reg_illness_model_path)


if best_log_reg_model_injury is None:
    # encode the string labels to numeric labels
    label_encoder_injury = LabelEncoder()
    y_train_injury_encoded = label_encoder_injury.fit_transform(y_train_injury)
    joblib.dump(label_encoder_injury, 'label_encoder_log_reg_injury.pkl')
    # get unique classes in the encoded labels
    unique_classes_injury = np.unique(y_train_injury_encoded)
    # calculate class weights
    class_weights_injury = compute_class_weight('balanced', classes=unique_classes_injury, y=y_train_injury_encoded)
    class_weight_dict_injury = dict(zip(unique_classes_injury, class_weights_injury))
    log_reg_param_injury = {
        'C': 1,
        'penalty': 'l2',
        'solver': 'liblinear',
        'class_weight': class_weight_dict_injury
    }
    best_log_reg_model_injury = LogisticRegression(random_state=42, max_iter=1000, **log_reg_param_injury)
    best_log_reg_model_injury.fit(X_train_injury, y_train_injury_encoded)
    joblib.dump(best_log_reg_model_injury, log_reg_injury_model_path)

# function to encode the target variable
def handle_label_encoder(y_train, encoder_path):
    if os.path.exists(encoder_path):
        os.remove(encoder_path)
        
    print(f"creating new label encoder for xgb: {encoder_path}")
    encoder = LabelEncoder()
    y_encoded = encoder.fit_transform(y_train)
    joblib.dump(encoder, encoder_path)
    return y_encoded, encoder

print("\n" + "="*50 + " handling xgb illness label encoder " + "="*50)
y_train_illness_encoded, illness_encoder = handle_label_encoder(y_train_illness, xgb_illness_label_encoder_path)

print("\n" + "="*50 + " handling xgb injury label encoder " + "="*50)
y_train_injury_encoded, injury_encoder = handle_label_encoder(y_train_injury, xgb_injury_label_encoder_path)

if best_xgb_model_illness is None:
    # XGBoost for illness prediction with GPU acceleration
    positive_class_count_illness = sum(y_train_illness_encoded == 1)
    negative_class_count_illness = sum(y_train_illness_encoded == 0)

    if positive_class_count_illness > 0:
        scale_pos_weight_illness = negative_class_count_illness / positive_class_count_illness
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist', 
            'device': 'cpu',
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10,
            'scale_pos_weight': scale_pos_weight_illness
        }
    else:
        xgb_param_illness = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 10
        }
    best_xgb_model_illness = xgb.XGBClassifier(random_state=42, **xgb_param_illness)
    best_xgb_model_illness = train_model_with_checkpoints(
        model=best_xgb_model_illness,
        X_train=X_train_illness,
        y_train=y_train_illness_encoded,
        model_path=xgb_illness_model_path,
        model_type="illness",
        checkpoint_interval=1,
        max_rounds=20
    )

if best_xgb_model_injury is None:
    # XGBoost for injury prediction with predefined hyperparameters
    positive_class_count_injury = np.sum(y_train_injury_encoded == 1)
    negative_class_count_injury = np.sum(y_train_injury_encoded == 0)
    if positive_class_count_injury > 0:
        scale_pos_weight_injury = negative_class_count_injury / positive_class_count_injury
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3,
            'scale_pos_weight': scale_pos_weight_injury
        }
    else:
        xgb_param_injury = {
            'n_estimators': 20,
            'learning_rate': 0.1,
            'max_depth': 5,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'enable_categorical':True,
            'tree_method': 'hist',  
            'device': 'cpu',  
            'eval_metric': 'mlogloss',
            'early_stopping_rounds': 3
        }
    best_xgb_model_injury = xgb.XGBClassifier(random_state=42, **xgb_param_injury)
    best_xgb_model_injury = train_model_with_checkpoints(
        model=best_xgb_model_injury,
        X_train=X_train_injury,
        y_train=y_train_injury_encoded,
        model_path=xgb_injury_model_path,
        model_type="injury",
        checkpoint_interval=1,
        max_rounds=20
    )

# after GridSearchCV, we can use the best models for prediction:
y_pred_illness_rf_test = best_rf_model_illness.predict(X_illness_test)
y_pred_injury_rf_test = best_rf_model_injury.predict(X_injury_test)

log_reg_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
y_pred_illness_lr_test = best_log_reg_model_illness.predict(X_illness_test)
y_pred_illness_lr_test_labels = log_reg_label_encoder_illness.inverse_transform(y_pred_illness_lr_test)
log_reg_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
y_pred_injury_lr_test = best_log_reg_model_injury.predict(X_injury_test)
y_pred_injury_lr_test_labels = log_reg_label_encoder_injury.inverse_transform(y_pred_injury_lr_test)

y_pred_illness_xgb_test = best_xgb_model_illness.predict(X_illness_test)
y_pred_injury_xgb_test = best_xgb_model_injury.predict(X_injury_test)

# -----------------------------------------------------------------------------------------------------------------------------------------
# model evaluation for all illness prediction
print("Random Forest Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_rf_test))
print("Random Forest Illness Prediction - Confusion Matrix:")
cm_illness_rf_test = confusion_matrix(test_df['illness_information'], y_pred_illness_rf_test)
sns.heatmap(cm_illness_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_lr_test_labels))
print("Logistic Regression Illness Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_illness_lr_test = confusion_matrix(test_df['illness_information'], y_pred_illness_lr_test_labels)
# load the logistic regression label encoder for illness
lr_label_encoder_illness = joblib.load('label_encoder_log_reg_illness.pkl')
sns.heatmap(cm_illness_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_illness.classes_,
            yticklabels=lr_label_encoder_illness.classes_)
plt.title("Logistic Regression - Illness Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_illness = joblib.load(xgb_illness_label_encoder_path)
# convert predictions back to original labels
y_pred_illness_xgb_test_labels = label_encoder_illness.inverse_transform(y_pred_illness_xgb_test)
print("XGBoost Illness Prediction - Accuracy Score:", accuracy_score(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Classification Report:")
print(classification_report(test_df['illness_information'], y_pred_illness_xgb_test_labels))
print("XGBoost Illness Prediction - Confusion Matrix:")
cm_illness_xgb_test = confusion_matrix(test_df['illness_information'], y_pred_illness_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_illness_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_illness.classes_,
            yticklabels=label_encoder_illness.classes_)
plt.title("XGBoost Illness Prediction - Confusion Matrix")
plt.show()

# model evaluation for all injury prediction
print("Random Forest Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_rf_test))
print("Random Forest Injury Prediction - Confusion Matrix:")
cm_injury_rf_test = confusion_matrix(test_df['injury_information'], y_pred_injury_rf_test)
sns.heatmap(cm_injury_rf_test, annot=True, fmt="d", cmap="Blues")
plt.show()

print("Logistic Regression Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_lr_test_labels))
print("Logistic Regression Injury Prediction - Confusion Matrix:")
plt.figure(figsize=(10, 8))
cm_injury_lr_test = confusion_matrix(test_df['injury_information'], y_pred_injury_lr_test_labels)
# load the logistic regression label encoder for injury
lr_label_encoder_injury = joblib.load('label_encoder_log_reg_injury.pkl')
sns.heatmap(cm_injury_lr_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=lr_label_encoder_injury.classes_,
            yticklabels=lr_label_encoder_injury.classes_)
plt.title("Logistic Regression - Injury Confusion Matrix")
plt.show()

# load label encoders for evaluation
label_encoder_injury = joblib.load(xgb_injury_label_encoder_path)
# convert predictions back to original labels
y_pred_injury_xgb_test_labels = label_encoder_injury.inverse_transform(y_pred_injury_xgb_test)
print("XGBoost Injury Prediction - Accuracy Score:", accuracy_score(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Classification Report:")
print(classification_report(test_df['injury_information'], y_pred_injury_xgb_test_labels))
print("XGBoost Injury Prediction - Confusion Matrix:")
cm_injury_xgb_test = confusion_matrix(test_df['injury_information'], y_pred_injury_xgb_test_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_injury_xgb_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder_injury.classes_,
            yticklabels=label_encoder_injury.classes_)
plt.title("XGBoost Injury Prediction - Confusion Matrix")
plt.show()
# Out:
# start execution
# Saving vectorizers...
# Injury test shape: (100107, 38)
# Test features for illness model: 19
# Real-use features for illness model: 19
# Test features for injury model: (138640, 38)
# Real-use features for injury model: (100107, 38)
#
# ================================================== handling xgb illness label encoder ==================================================
# creating new label encoder for xgb: saved_models_additional_v2_no_severity/xgb_illness_label_encoder.pkl
#
# ================================================== handling xgb injury label encoder ==================================================
# creating new label encoder for xgb: saved_models_additional_v2_no_severity/xgb_injury_label_encoder.pkl
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:1.98356
# [1]	validation_0-mlogloss:1.64422
# [2]	validation_0-mlogloss:1.40636
# [3]	validation_0-mlogloss:1.21864
# [4]	validation_0-mlogloss:1.07238
# [5]	validation_0-mlogloss:0.94845
# [6]	validation_0-mlogloss:0.84121
# [7]	validation_0-mlogloss:0.75045
# [8]	validation_0-mlogloss:0.67020
# [9]	validation_0-mlogloss:0.59992
# [10]	validation_0-mlogloss:0.53891
# [11]	validation_0-mlogloss:0.48399
# [12]	validation_0-mlogloss:0.43518
# [13]	validation_0-mlogloss:0.39217
# [14]	validation_0-mlogloss:0.35375
# [15]	validation_0-mlogloss:0.31922
# [16]	validation_0-mlogloss:0.28849
# [17]	validation_0-mlogloss:0.26083
# [18]	validation_0-mlogloss:0.23541
# [19]	validation_0-mlogloss:0.21255
# Saving model after iteration 1
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.37633
# [1]	validation_0-mlogloss:0.33068
# [2]	validation_0-mlogloss:0.29304
# [3]	validation_0-mlogloss:0.26149
# [4]	validation_0-mlogloss:0.23404
# [5]	validation_0-mlogloss:0.21039
# [6]	validation_0-mlogloss:0.18901
# [7]	validation_0-mlogloss:0.17003
# [8]	validation_0-mlogloss:0.15321
# [9]	validation_0-mlogloss:0.13817
# [10]	validation_0-mlogloss:0.12475
# [11]	validation_0-mlogloss:0.11271
# [12]	validation_0-mlogloss:0.10174
# [13]	validation_0-mlogloss:0.09187
# [14]	validation_0-mlogloss:0.08298
# [15]	validation_0-mlogloss:0.07497
# [16]	validation_0-mlogloss:0.06784
# [17]	validation_0-mlogloss:0.06131
# [18]	validation_0-mlogloss:0.05549
# [19]	validation_0-mlogloss:0.05020
# Saving model after iteration 2
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.17199
# [1]	validation_0-mlogloss:0.15169
# [2]	validation_0-mlogloss:0.13461
# [3]	validation_0-mlogloss:0.11997
# [4]	validation_0-mlogloss:0.10724
# [5]	validation_0-mlogloss:0.09609
# [6]	validation_0-mlogloss:0.08629
# [7]	validation_0-mlogloss:0.07758
# [8]	validation_0-mlogloss:0.06983
# [9]	validation_0-mlogloss:0.06292
# [10]	validation_0-mlogloss:0.05671
# [11]	validation_0-mlogloss:0.05115
# [12]	validation_0-mlogloss:0.04617
# [13]	validation_0-mlogloss:0.04167
# [14]	validation_0-mlogloss:0.03763
# [15]	validation_0-mlogloss:0.03398
# [16]	validation_0-mlogloss:0.03070
# [17]	validation_0-mlogloss:0.02774
# [18]	validation_0-mlogloss:0.02508
# [19]	validation_0-mlogloss:0.02267
# Saving model after iteration 3
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.07735
# [1]	validation_0-mlogloss:0.06947
# [2]	validation_0-mlogloss:0.06246
# [3]	validation_0-mlogloss:0.05622
# [4]	validation_0-mlogloss:0.05064
# [5]	validation_0-mlogloss:0.04565
# [6]	validation_0-mlogloss:0.04117
# [7]	validation_0-mlogloss:0.03715
# [8]	validation_0-mlogloss:0.03354
# [9]	validation_0-mlogloss:0.03028
# [10]	validation_0-mlogloss:0.02735
# [11]	validation_0-mlogloss:0.02471
# [12]	validation_0-mlogloss:0.02233
# [13]	validation_0-mlogloss:0.02018
# [14]	validation_0-mlogloss:0.01824
# [15]	validation_0-mlogloss:0.01650
# [16]	validation_0-mlogloss:0.01492
# [17]	validation_0-mlogloss:0.01349
# [18]	validation_0-mlogloss:0.01220
# [19]	validation_0-mlogloss:0.01103
# Saving model after iteration 4
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.04948
# [1]	validation_0-mlogloss:0.04459
# [2]	validation_0-mlogloss:0.04021
# [3]	validation_0-mlogloss:0.03627
# [4]	validation_0-mlogloss:0.03273
# [5]	validation_0-mlogloss:0.02955
# [6]	validation_0-mlogloss:0.02669
# [7]	validation_0-mlogloss:0.02411
# [8]	validation_0-mlogloss:0.02178
# [9]	validation_0-mlogloss:0.01968
# [10]	validation_0-mlogloss:0.01779
# [11]	validation_0-mlogloss:0.01608
# [12]	validation_0-mlogloss:0.01454
# [13]	validation_0-mlogloss:0.01315
# [14]	validation_0-mlogloss:0.01189
# [15]	validation_0-mlogloss:0.01075
# [16]	validation_0-mlogloss:0.00972
# [17]	validation_0-mlogloss:0.00879
# [18]	validation_0-mlogloss:0.00795
# [19]	validation_0-mlogloss:0.00719
# Saving model after iteration 5
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03094
# [1]	validation_0-mlogloss:0.02793
# [2]	validation_0-mlogloss:0.02522
# [3]	validation_0-mlogloss:0.02278
# [4]	validation_0-mlogloss:0.02058
# [5]	validation_0-mlogloss:0.01859
# [6]	validation_0-mlogloss:0.01680
# [7]	validation_0-mlogloss:0.01519
# [8]	validation_0-mlogloss:0.01373
# [9]	validation_0-mlogloss:0.01241
# [10]	validation_0-mlogloss:0.01122
# [11]	validation_0-mlogloss:0.01015
# [12]	validation_0-mlogloss:0.00918
# [13]	validation_0-mlogloss:0.00830
# [14]	validation_0-mlogloss:0.00751
# [15]	validation_0-mlogloss:0.00679
# [16]	validation_0-mlogloss:0.00614
# [17]	validation_0-mlogloss:0.00556
# [18]	validation_0-mlogloss:0.00503
# [19]	validation_0-mlogloss:0.00455
# Saving model after iteration 6
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02316
# [1]	validation_0-mlogloss:0.02092
# [2]	validation_0-mlogloss:0.01890
# [3]	validation_0-mlogloss:0.01708
# [4]	validation_0-mlogloss:0.01543
# [5]	validation_0-mlogloss:0.01395
# [6]	validation_0-mlogloss:0.01261
# [7]	validation_0-mlogloss:0.01140
# [8]	validation_0-mlogloss:0.01031
# [9]	validation_0-mlogloss:0.00932
# [10]	validation_0-mlogloss:0.00843
# [11]	validation_0-mlogloss:0.00762
# [12]	validation_0-mlogloss:0.00690
# [13]	validation_0-mlogloss:0.00624
# [14]	validation_0-mlogloss:0.00564
# [15]	validation_0-mlogloss:0.00510
# [16]	validation_0-mlogloss:0.00462
# [17]	validation_0-mlogloss:0.00418
# [18]	validation_0-mlogloss:0.00378
# [19]	validation_0-mlogloss:0.00342
# Saving model after iteration 7
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:48:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01683
# [1]	validation_0-mlogloss:0.01521
# [2]	validation_0-mlogloss:0.01374
# [3]	validation_0-mlogloss:0.01242
# [4]	validation_0-mlogloss:0.01123
# [5]	validation_0-mlogloss:0.01016
# [6]	validation_0-mlogloss:0.00918
# [7]	validation_0-mlogloss:0.00830
# [8]	validation_0-mlogloss:0.00751
# [9]	validation_0-mlogloss:0.00679
# [10]	validation_0-mlogloss:0.00614
# [11]	validation_0-mlogloss:0.00556
# [12]	validation_0-mlogloss:0.00503
# [13]	validation_0-mlogloss:0.00455
# [14]	validation_0-mlogloss:0.00411
# [15]	validation_0-mlogloss:0.00372
# [16]	validation_0-mlogloss:0.00337
# [17]	validation_0-mlogloss:0.00305
# [18]	validation_0-mlogloss:0.00276
# [19]	validation_0-mlogloss:0.00249
# Saving model after iteration 8
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:49:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01151
# [1]	validation_0-mlogloss:0.01040
# [2]	validation_0-mlogloss:0.00941
# [3]	validation_0-mlogloss:0.00851
# [4]	validation_0-mlogloss:0.00769
# [5]	validation_0-mlogloss:0.00696
# [6]	validation_0-mlogloss:0.00629
# [7]	validation_0-mlogloss:0.00569
# [8]	validation_0-mlogloss:0.00515
# [9]	validation_0-mlogloss:0.00466
# [10]	validation_0-mlogloss:0.00422
# [11]	validation_0-mlogloss:0.00381
# [12]	validation_0-mlogloss:0.00345
# [13]	validation_0-mlogloss:0.00312
# [14]	validation_0-mlogloss:0.00283
# [15]	validation_0-mlogloss:0.00256
# [16]	validation_0-mlogloss:0.00231
# [17]	validation_0-mlogloss:0.00209
# [18]	validation_0-mlogloss:0.00189
# [19]	validation_0-mlogloss:0.00171
# Saving model after iteration 9
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:49:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00916
# [1]	validation_0-mlogloss:0.00828
# [2]	validation_0-mlogloss:0.00749
# [3]	validation_0-mlogloss:0.00677
# [4]	validation_0-mlogloss:0.00613
# [5]	validation_0-mlogloss:0.00554
# [6]	validation_0-mlogloss:0.00501
# [7]	validation_0-mlogloss:0.00454
# [8]	validation_0-mlogloss:0.00410
# [9]	validation_0-mlogloss:0.00371
# [10]	validation_0-mlogloss:0.00336
# [11]	validation_0-mlogloss:0.00304
# [12]	validation_0-mlogloss:0.00275
# [13]	validation_0-mlogloss:0.00249
# [14]	validation_0-mlogloss:0.00225
# [15]	validation_0-mlogloss:0.00204
# [16]	validation_0-mlogloss:0.00184
# [17]	validation_0-mlogloss:0.00167
# [18]	validation_0-mlogloss:0.00151
# [19]	validation_0-mlogloss:0.00137
# Saving model after iteration 10
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:49:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00565
# [1]	validation_0-mlogloss:0.00511
# [2]	validation_0-mlogloss:0.00462
# [3]	validation_0-mlogloss:0.00418
# [4]	validation_0-mlogloss:0.00379
# [5]	validation_0-mlogloss:0.00342
# [6]	validation_0-mlogloss:0.00310
# [7]	validation_0-mlogloss:0.00280
# [8]	validation_0-mlogloss:0.00254
# [9]	validation_0-mlogloss:0.00230
# [10]	validation_0-mlogloss:0.00208
# [11]	validation_0-mlogloss:0.00188
# [12]	validation_0-mlogloss:0.00170
# [13]	validation_0-mlogloss:0.00154
# [14]	validation_0-mlogloss:0.00139
# [15]	validation_0-mlogloss:0.00126
# [16]	validation_0-mlogloss:0.00114
# [17]	validation_0-mlogloss:0.00103
# [18]	validation_0-mlogloss:0.00094
# [19]	validation_0-mlogloss:0.00085
# Saving model after iteration 11
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:49:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00431
# [1]	validation_0-mlogloss:0.00390
# [2]	validation_0-mlogloss:0.00353
# [3]	validation_0-mlogloss:0.00320
# [4]	validation_0-mlogloss:0.00289
# [5]	validation_0-mlogloss:0.00262
# [6]	validation_0-mlogloss:0.00237
# [7]	validation_0-mlogloss:0.00214
# [8]	validation_0-mlogloss:0.00194
# [9]	validation_0-mlogloss:0.00175
# [10]	validation_0-mlogloss:0.00159
# [11]	validation_0-mlogloss:0.00144
# [12]	validation_0-mlogloss:0.00130
# [13]	validation_0-mlogloss:0.00118
# [14]	validation_0-mlogloss:0.00107
# [15]	validation_0-mlogloss:0.00097
# [16]	validation_0-mlogloss:0.00087
# [17]	validation_0-mlogloss:0.00079
# [18]	validation_0-mlogloss:0.00072
# [19]	validation_0-mlogloss:0.00065
# Saving model after iteration 12
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:49:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00421
# [1]	validation_0-mlogloss:0.00381
# [2]	validation_0-mlogloss:0.00344
# [3]	validation_0-mlogloss:0.00312
# [4]	validation_0-mlogloss:0.00282
# [5]	validation_0-mlogloss:0.00255
# [6]	validation_0-mlogloss:0.00231
# [7]	validation_0-mlogloss:0.00209
# [8]	validation_0-mlogloss:0.00189
# [9]	validation_0-mlogloss:0.00171
# [10]	validation_0-mlogloss:0.00155
# [11]	validation_0-mlogloss:0.00140
# [12]	validation_0-mlogloss:0.00127
# [13]	validation_0-mlogloss:0.00115
# [14]	validation_0-mlogloss:0.00104
# [15]	validation_0-mlogloss:0.00094
# [16]	validation_0-mlogloss:0.00085
# [17]	validation_0-mlogloss:0.00077
# [18]	validation_0-mlogloss:0.00070
# [19]	validation_0-mlogloss:0.00063
# Saving model after iteration 13
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:49:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00446
# [1]	validation_0-mlogloss:0.00403
# [2]	validation_0-mlogloss:0.00365
# [3]	validation_0-mlogloss:0.00330
# [4]	validation_0-mlogloss:0.00299
# [5]	validation_0-mlogloss:0.00270
# [6]	validation_0-mlogloss:0.00245
# [7]	validation_0-mlogloss:0.00221
# [8]	validation_0-mlogloss:0.00200
# [9]	validation_0-mlogloss:0.00181
# [10]	validation_0-mlogloss:0.00164
# [11]	validation_0-mlogloss:0.00148
# [12]	validation_0-mlogloss:0.00134
# [13]	validation_0-mlogloss:0.00122
# [14]	validation_0-mlogloss:0.00110
# [15]	validation_0-mlogloss:0.00100
# [16]	validation_0-mlogloss:0.00090
# [17]	validation_0-mlogloss:0.00082
# [18]	validation_0-mlogloss:0.00074
# [19]	validation_0-mlogloss:0.00067
# Saving model after iteration 14
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:49:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00424
# [1]	validation_0-mlogloss:0.00384
# [2]	validation_0-mlogloss:0.00347
# [3]	validation_0-mlogloss:0.00314
# [4]	validation_0-mlogloss:0.00284
# [5]	validation_0-mlogloss:0.00257
# [6]	validation_0-mlogloss:0.00233
# [7]	validation_0-mlogloss:0.00211
# [8]	validation_0-mlogloss:0.00191
# [9]	validation_0-mlogloss:0.00172
# [10]	validation_0-mlogloss:0.00156
# [11]	validation_0-mlogloss:0.00141
# [12]	validation_0-mlogloss:0.00128
# [13]	validation_0-mlogloss:0.00116
# [14]	validation_0-mlogloss:0.00105
# [15]	validation_0-mlogloss:0.00095
# [16]	validation_0-mlogloss:0.00086
# [17]	validation_0-mlogloss:0.00078
# [18]	validation_0-mlogloss:0.00070
# [19]	validation_0-mlogloss:0.00064
# Saving model after iteration 15
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:50:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00559
# [1]	validation_0-mlogloss:0.00506
# [2]	validation_0-mlogloss:0.00457
# [3]	validation_0-mlogloss:0.00414
# [4]	validation_0-mlogloss:0.00374
# [5]	validation_0-mlogloss:0.00339
# [6]	validation_0-mlogloss:0.00306
# [7]	validation_0-mlogloss:0.00277
# [8]	validation_0-mlogloss:0.00251
# [9]	validation_0-mlogloss:0.00227
# [10]	validation_0-mlogloss:0.00205
# [11]	validation_0-mlogloss:0.00186
# [12]	validation_0-mlogloss:0.00168
# [13]	validation_0-mlogloss:0.00152
# [14]	validation_0-mlogloss:0.00138
# [15]	validation_0-mlogloss:0.00125
# [16]	validation_0-mlogloss:0.00113
# [17]	validation_0-mlogloss:0.00102
# [18]	validation_0-mlogloss:0.00093
# [19]	validation_0-mlogloss:0.00084
# Saving model after iteration 16
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:50:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00649
# [1]	validation_0-mlogloss:0.00587
# [2]	validation_0-mlogloss:0.00531
# [3]	validation_0-mlogloss:0.00480
# [4]	validation_0-mlogloss:0.00434
# [5]	validation_0-mlogloss:0.00393
# [6]	validation_0-mlogloss:0.00355
# [7]	validation_0-mlogloss:0.00321
# [8]	validation_0-mlogloss:0.00291
# [9]	validation_0-mlogloss:0.00263
# [10]	validation_0-mlogloss:0.00238
# [11]	validation_0-mlogloss:0.00215
# [12]	validation_0-mlogloss:0.00195
# [13]	validation_0-mlogloss:0.00176
# [14]	validation_0-mlogloss:0.00160
# [15]	validation_0-mlogloss:0.00144
# [16]	validation_0-mlogloss:0.00131
# [17]	validation_0-mlogloss:0.00118
# [18]	validation_0-mlogloss:0.00107
# [19]	validation_0-mlogloss:0.00097
# Saving model after iteration 17
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:50:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.00879
# [1]	validation_0-mlogloss:0.00795
# [2]	validation_0-mlogloss:0.00718
# [3]	validation_0-mlogloss:0.00650
# [4]	validation_0-mlogloss:0.00588
# [5]	validation_0-mlogloss:0.00531
# [6]	validation_0-mlogloss:0.00481
# [7]	validation_0-mlogloss:0.00435
# [8]	validation_0-mlogloss:0.00393
# [9]	validation_0-mlogloss:0.00356
# [10]	validation_0-mlogloss:0.00322
# [11]	validation_0-mlogloss:0.00291
# [12]	validation_0-mlogloss:0.00263
# [13]	validation_0-mlogloss:0.00238
# [14]	validation_0-mlogloss:0.00216
# [15]	validation_0-mlogloss:0.00195
# [16]	validation_0-mlogloss:0.00177
# [17]	validation_0-mlogloss:0.00160
# [18]	validation_0-mlogloss:0.00145
# [19]	validation_0-mlogloss:0.00131
# Saving model after iteration 18
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:50:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01005
# [1]	validation_0-mlogloss:0.00908
# [2]	validation_0-mlogloss:0.00821
# [3]	validation_0-mlogloss:0.00742
# [4]	validation_0-mlogloss:0.00671
# [5]	validation_0-mlogloss:0.00607
# [6]	validation_0-mlogloss:0.00549
# [7]	validation_0-mlogloss:0.00496
# [8]	validation_0-mlogloss:0.00449
# [9]	validation_0-mlogloss:0.00406
# [10]	validation_0-mlogloss:0.00367
# [11]	validation_0-mlogloss:0.00332
# [12]	validation_0-mlogloss:0.00301
# [13]	validation_0-mlogloss:0.00272
# [14]	validation_0-mlogloss:0.00246
# [15]	validation_0-mlogloss:0.00223
# [16]	validation_0-mlogloss:0.00201
# [17]	validation_0-mlogloss:0.00182
# [18]	validation_0-mlogloss:0.00165
# [19]	validation_0-mlogloss:0.00149
# Saving model after iteration 19
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:51:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.01242
# [1]	validation_0-mlogloss:0.01122
# [2]	validation_0-mlogloss:0.01014
# [3]	validation_0-mlogloss:0.00916
# [4]	validation_0-mlogloss:0.00828
# [5]	validation_0-mlogloss:0.00749
# [6]	validation_0-mlogloss:0.00677
# [7]	validation_0-mlogloss:0.00612
# [8]	validation_0-mlogloss:0.00554
# [9]	validation_0-mlogloss:0.00501
# [10]	validation_0-mlogloss:0.00453
# [11]	validation_0-mlogloss:0.00410
# [12]	validation_0-mlogloss:0.00371
# [13]	validation_0-mlogloss:0.00335
# [14]	validation_0-mlogloss:0.00303
# [15]	validation_0-mlogloss:0.00274
# [16]	validation_0-mlogloss:0.00248
# [17]	validation_0-mlogloss:0.00225
# [18]	validation_0-mlogloss:0.00203
# [19]	validation_0-mlogloss:0.00184
# Saving model after iteration 20
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:51:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:1.32042
# [1]	validation_0-mlogloss:1.10006
# [2]	validation_0-mlogloss:0.97715
# [3]	validation_0-mlogloss:0.87187
# [4]	validation_0-mlogloss:0.78239
# [5]	validation_0-mlogloss:0.70394
# [6]	validation_0-mlogloss:0.63448
# [7]	validation_0-mlogloss:0.57305
# [8]	validation_0-mlogloss:0.51881
# [9]	validation_0-mlogloss:0.47086
# [10]	validation_0-mlogloss:0.42684
# [11]	validation_0-mlogloss:0.38734
# [12]	validation_0-mlogloss:0.35215
# [13]	validation_0-mlogloss:0.32048
# [14]	validation_0-mlogloss:0.29120
# [15]	validation_0-mlogloss:0.26494
# [16]	validation_0-mlogloss:0.24096
# [17]	validation_0-mlogloss:0.21964
# [18]	validation_0-mlogloss:0.20007
# [19]	validation_0-mlogloss:0.18292
# Saving model after iteration 1
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:52:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.59043
# [1]	validation_0-mlogloss:0.51059
# [2]	validation_0-mlogloss:0.44938
# [3]	validation_0-mlogloss:0.39907
# [4]	validation_0-mlogloss:0.35716
# [5]	validation_0-mlogloss:0.32093
# [6]	validation_0-mlogloss:0.28910
# [7]	validation_0-mlogloss:0.26103
# [8]	validation_0-mlogloss:0.23614
# [9]	validation_0-mlogloss:0.21369
# [10]	validation_0-mlogloss:0.19395
# [11]	validation_0-mlogloss:0.17585
# [12]	validation_0-mlogloss:0.15998
# [13]	validation_0-mlogloss:0.14551
# [14]	validation_0-mlogloss:0.13241
# [15]	validation_0-mlogloss:0.12041
# [16]	validation_0-mlogloss:0.10964
# [17]	validation_0-mlogloss:0.10001
# [18]	validation_0-mlogloss:0.09112
# [19]	validation_0-mlogloss:0.08305
# Saving model after iteration 2
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:54:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.37357
# [1]	validation_0-mlogloss:0.31963
# [2]	validation_0-mlogloss:0.27960
# [3]	validation_0-mlogloss:0.24712
# [4]	validation_0-mlogloss:0.21980
# [5]	validation_0-mlogloss:0.19650
# [6]	validation_0-mlogloss:0.17635
# [7]	validation_0-mlogloss:0.15871
# [8]	validation_0-mlogloss:0.14307
# [9]	validation_0-mlogloss:0.12923
# [10]	validation_0-mlogloss:0.11684
# [11]	validation_0-mlogloss:0.10585
# [12]	validation_0-mlogloss:0.09587
# [13]	validation_0-mlogloss:0.08694
# [14]	validation_0-mlogloss:0.07888
# [15]	validation_0-mlogloss:0.07161
# [16]	validation_0-mlogloss:0.06509
# [17]	validation_0-mlogloss:0.05917
# [18]	validation_0-mlogloss:0.05380
# [19]	validation_0-mlogloss:0.04891
# Saving model after iteration 3
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:55:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.30536
# [1]	validation_0-mlogloss:0.25890
# [2]	validation_0-mlogloss:0.22457
# [3]	validation_0-mlogloss:0.19727
# [4]	validation_0-mlogloss:0.17477
# [5]	validation_0-mlogloss:0.15559
# [6]	validation_0-mlogloss:0.13912
# [7]	validation_0-mlogloss:0.12471
# [8]	validation_0-mlogloss:0.11209
# [9]	validation_0-mlogloss:0.10100
# [10]	validation_0-mlogloss:0.09104
# [11]	validation_0-mlogloss:0.08217
# [12]	validation_0-mlogloss:0.07425
# [13]	validation_0-mlogloss:0.06712
# [14]	validation_0-mlogloss:0.06074
# [15]	validation_0-mlogloss:0.05498
# [16]	validation_0-mlogloss:0.04980
# [17]	validation_0-mlogloss:0.04514
# [18]	validation_0-mlogloss:0.04095
# [19]	validation_0-mlogloss:0.03715
# Saving model after iteration 4
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:57:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.22942
# [1]	validation_0-mlogloss:0.19829
# [2]	validation_0-mlogloss:0.17387
# [3]	validation_0-mlogloss:0.15372
# [4]	validation_0-mlogloss:0.13668
# [5]	validation_0-mlogloss:0.12204
# [6]	validation_0-mlogloss:0.10927
# [7]	validation_0-mlogloss:0.09805
# [8]	validation_0-mlogloss:0.08815
# [9]	validation_0-mlogloss:0.07938
# [10]	validation_0-mlogloss:0.07159
# [11]	validation_0-mlogloss:0.06459
# [12]	validation_0-mlogloss:0.05831
# [13]	validation_0-mlogloss:0.05268
# [14]	validation_0-mlogloss:0.04762
# [15]	validation_0-mlogloss:0.04307
# [16]	validation_0-mlogloss:0.03898
# [17]	validation_0-mlogloss:0.03528
# [18]	validation_0-mlogloss:0.03196
# [19]	validation_0-mlogloss:0.02897
# Saving model after iteration 5
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [21:59:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.17307
# [1]	validation_0-mlogloss:0.15171
# [2]	validation_0-mlogloss:0.13433
# [3]	validation_0-mlogloss:0.11947
# [4]	validation_0-mlogloss:0.10667
# [5]	validation_0-mlogloss:0.09552
# [6]	validation_0-mlogloss:0.08571
# [7]	validation_0-mlogloss:0.07705
# [8]	validation_0-mlogloss:0.06938
# [9]	validation_0-mlogloss:0.06254
# [10]	validation_0-mlogloss:0.05640
# [11]	validation_0-mlogloss:0.05089
# [12]	validation_0-mlogloss:0.04596
# [13]	validation_0-mlogloss:0.04151
# [14]	validation_0-mlogloss:0.03753
# [15]	validation_0-mlogloss:0.03394
# [16]	validation_0-mlogloss:0.03069
# [17]	validation_0-mlogloss:0.02777
# [18]	validation_0-mlogloss:0.02513
# [19]	validation_0-mlogloss:0.02276
# Saving model after iteration 6
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:01:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.14034
# [1]	validation_0-mlogloss:0.12329
# [2]	validation_0-mlogloss:0.10926
# [3]	validation_0-mlogloss:0.09734
# [4]	validation_0-mlogloss:0.08702
# [5]	validation_0-mlogloss:0.07799
# [6]	validation_0-mlogloss:0.07003
# [7]	validation_0-mlogloss:0.06298
# [8]	validation_0-mlogloss:0.05670
# [9]	validation_0-mlogloss:0.05110
# [10]	validation_0-mlogloss:0.04608
# [11]	validation_0-mlogloss:0.04158
# [12]	validation_0-mlogloss:0.03754
# [13]	validation_0-mlogloss:0.03391
# [14]	validation_0-mlogloss:0.03064
# [15]	validation_0-mlogloss:0.02769
# [16]	validation_0-mlogloss:0.02503
# [17]	validation_0-mlogloss:0.02264
# [18]	validation_0-mlogloss:0.02049
# [19]	validation_0-mlogloss:0.01853
# Saving model after iteration 7
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:03:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.11754
# [1]	validation_0-mlogloss:0.10301
# [2]	validation_0-mlogloss:0.09118
# [3]	validation_0-mlogloss:0.08118
# [4]	validation_0-mlogloss:0.07255
# [5]	validation_0-mlogloss:0.06501
# [6]	validation_0-mlogloss:0.05837
# [7]	validation_0-mlogloss:0.05249
# [8]	validation_0-mlogloss:0.04725
# [9]	validation_0-mlogloss:0.04258
# [10]	validation_0-mlogloss:0.03839
# [11]	validation_0-mlogloss:0.03464
# [12]	validation_0-mlogloss:0.03127
# [13]	validation_0-mlogloss:0.02824
# [14]	validation_0-mlogloss:0.02551
# [15]	validation_0-mlogloss:0.02306
# [16]	validation_0-mlogloss:0.02084
# [17]	validation_0-mlogloss:0.01884
# [18]	validation_0-mlogloss:0.01704
# [19]	validation_0-mlogloss:0.01541
# Saving model after iteration 8
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:06:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.09303
# [1]	validation_0-mlogloss:0.08176
# [2]	validation_0-mlogloss:0.07250
# [3]	validation_0-mlogloss:0.06463
# [4]	validation_0-mlogloss:0.05781
# [5]	validation_0-mlogloss:0.05184
# [6]	validation_0-mlogloss:0.04657
# [7]	validation_0-mlogloss:0.04189
# [8]	validation_0-mlogloss:0.03773
# [9]	validation_0-mlogloss:0.03400
# [10]	validation_0-mlogloss:0.03067
# [11]	validation_0-mlogloss:0.02768
# [12]	validation_0-mlogloss:0.02499
# [13]	validation_0-mlogloss:0.02257
# [14]	validation_0-mlogloss:0.02039
# [15]	validation_0-mlogloss:0.01843
# [16]	validation_0-mlogloss:0.01666
# [17]	validation_0-mlogloss:0.01506
# [18]	validation_0-mlogloss:0.01362
# [19]	validation_0-mlogloss:0.01231
# Saving model after iteration 9
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:08:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.07971
# [1]	validation_0-mlogloss:0.06996
# [2]	validation_0-mlogloss:0.06196
# [3]	validation_0-mlogloss:0.05518
# [4]	validation_0-mlogloss:0.04932
# [5]	validation_0-mlogloss:0.04420
# [6]	validation_0-mlogloss:0.03968
# [7]	validation_0-mlogloss:0.03568
# [8]	validation_0-mlogloss:0.03212
# [9]	validation_0-mlogloss:0.02894
# [10]	validation_0-mlogloss:0.02609
# [11]	validation_0-mlogloss:0.02354
# [12]	validation_0-mlogloss:0.02125
# [13]	validation_0-mlogloss:0.01919
# [14]	validation_0-mlogloss:0.01733
# [15]	validation_0-mlogloss:0.01566
# [16]	validation_0-mlogloss:0.01415
# [17]	validation_0-mlogloss:0.01279
# [18]	validation_0-mlogloss:0.01157
# [19]	validation_0-mlogloss:0.01046
# Saving model after iteration 10
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:11:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.06740
# [1]	validation_0-mlogloss:0.05890
# [2]	validation_0-mlogloss:0.05202
# [3]	validation_0-mlogloss:0.04623
# [4]	validation_0-mlogloss:0.04126
# [5]	validation_0-mlogloss:0.03693
# [6]	validation_0-mlogloss:0.03313
# [7]	validation_0-mlogloss:0.02978
# [8]	validation_0-mlogloss:0.02679
# [9]	validation_0-mlogloss:0.02413
# [10]	validation_0-mlogloss:0.02175
# [11]	validation_0-mlogloss:0.01962
# [12]	validation_0-mlogloss:0.01770
# [13]	validation_0-mlogloss:0.01598
# [14]	validation_0-mlogloss:0.01443
# [15]	validation_0-mlogloss:0.01305
# [16]	validation_0-mlogloss:0.01179
# [17]	validation_0-mlogloss:0.01066
# [18]	validation_0-mlogloss:0.00963
# [19]	validation_0-mlogloss:0.00871
# Saving model after iteration 11
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:13:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.05859
# [1]	validation_0-mlogloss:0.05114
# [2]	validation_0-mlogloss:0.04511
# [3]	validation_0-mlogloss:0.04005
# [4]	validation_0-mlogloss:0.03571
# [5]	validation_0-mlogloss:0.03195
# [6]	validation_0-mlogloss:0.02864
# [7]	validation_0-mlogloss:0.02573
# [8]	validation_0-mlogloss:0.02314
# [9]	validation_0-mlogloss:0.02083
# [10]	validation_0-mlogloss:0.01877
# [11]	validation_0-mlogloss:0.01693
# [12]	validation_0-mlogloss:0.01527
# [13]	validation_0-mlogloss:0.01380
# [14]	validation_0-mlogloss:0.01246
# [15]	validation_0-mlogloss:0.01126
# [16]	validation_0-mlogloss:0.01017
# [17]	validation_0-mlogloss:0.00919
# [18]	validation_0-mlogloss:0.00831
# [19]	validation_0-mlogloss:0.00751
# Saving model after iteration 12
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:16:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.05314
# [1]	validation_0-mlogloss:0.04639
# [2]	validation_0-mlogloss:0.04090
# [3]	validation_0-mlogloss:0.03630
# [4]	validation_0-mlogloss:0.03235
# [5]	validation_0-mlogloss:0.02893
# [6]	validation_0-mlogloss:0.02593
# [7]	validation_0-mlogloss:0.02328
# [8]	validation_0-mlogloss:0.02094
# [9]	validation_0-mlogloss:0.01885
# [10]	validation_0-mlogloss:0.01698
# [11]	validation_0-mlogloss:0.01531
# [12]	validation_0-mlogloss:0.01381
# [13]	validation_0-mlogloss:0.01247
# [14]	validation_0-mlogloss:0.01126
# [15]	validation_0-mlogloss:0.01017
# [16]	validation_0-mlogloss:0.00919
# [17]	validation_0-mlogloss:0.00830
# [18]	validation_0-mlogloss:0.00751
# [19]	validation_0-mlogloss:0.00679
# Saving model after iteration 13
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:19:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.04586
# [1]	validation_0-mlogloss:0.04018
# [2]	validation_0-mlogloss:0.03551
# [3]	validation_0-mlogloss:0.03156
# [4]	validation_0-mlogloss:0.02816
# [5]	validation_0-mlogloss:0.02520
# [6]	validation_0-mlogloss:0.02260
# [7]	validation_0-mlogloss:0.02030
# [8]	validation_0-mlogloss:0.01826
# [9]	validation_0-mlogloss:0.01645
# [10]	validation_0-mlogloss:0.01482
# [11]	validation_0-mlogloss:0.01337
# [12]	validation_0-mlogloss:0.01206
# [13]	validation_0-mlogloss:0.01089
# [14]	validation_0-mlogloss:0.00983
# [15]	validation_0-mlogloss:0.00888
# [16]	validation_0-mlogloss:0.00803
# [17]	validation_0-mlogloss:0.00725
# [18]	validation_0-mlogloss:0.00656
# [19]	validation_0-mlogloss:0.00593
# Saving model after iteration 14
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:23:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.04264
# [1]	validation_0-mlogloss:0.03731
# [2]	validation_0-mlogloss:0.03295
# [3]	validation_0-mlogloss:0.02927
# [4]	validation_0-mlogloss:0.02611
# [5]	validation_0-mlogloss:0.02336
# [6]	validation_0-mlogloss:0.02094
# [7]	validation_0-mlogloss:0.01881
# [8]	validation_0-mlogloss:0.01692
# [9]	validation_0-mlogloss:0.01523
# [10]	validation_0-mlogloss:0.01372
# [11]	validation_0-mlogloss:0.01238
# [12]	validation_0-mlogloss:0.01117
# [13]	validation_0-mlogloss:0.01008
# [14]	validation_0-mlogloss:0.00910
# [15]	validation_0-mlogloss:0.00822
# [16]	validation_0-mlogloss:0.00743
# [17]	validation_0-mlogloss:0.00672
# [18]	validation_0-mlogloss:0.00607
# [19]	validation_0-mlogloss:0.00549
# Saving model after iteration 15
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:26:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03675
# [1]	validation_0-mlogloss:0.03235
# [2]	validation_0-mlogloss:0.02867
# [3]	validation_0-mlogloss:0.02553
# [4]	validation_0-mlogloss:0.02281
# [5]	validation_0-mlogloss:0.02043
# [6]	validation_0-mlogloss:0.01834
# [7]	validation_0-mlogloss:0.01648
# [8]	validation_0-mlogloss:0.01483
# [9]	validation_0-mlogloss:0.01336
# [10]	validation_0-mlogloss:0.01204
# [11]	validation_0-mlogloss:0.01086
# [12]	validation_0-mlogloss:0.00980
# [13]	validation_0-mlogloss:0.00885
# [14]	validation_0-mlogloss:0.00799
# [15]	validation_0-mlogloss:0.00722
# [16]	validation_0-mlogloss:0.00653
# [17]	validation_0-mlogloss:0.00590
# [18]	validation_0-mlogloss:0.00533
# [19]	validation_0-mlogloss:0.00482
# Saving model after iteration 16
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:30:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03457
# [1]	validation_0-mlogloss:0.03042
# [2]	validation_0-mlogloss:0.02695
# [3]	validation_0-mlogloss:0.02399
# [4]	validation_0-mlogloss:0.02143
# [5]	validation_0-mlogloss:0.01919
# [6]	validation_0-mlogloss:0.01722
# [7]	validation_0-mlogloss:0.01548
# [8]	validation_0-mlogloss:0.01393
# [9]	validation_0-mlogloss:0.01254
# [10]	validation_0-mlogloss:0.01131
# [11]	validation_0-mlogloss:0.01020
# [12]	validation_0-mlogloss:0.00920
# [13]	validation_0-mlogloss:0.00831
# [14]	validation_0-mlogloss:0.00750
# [15]	validation_0-mlogloss:0.00678
# [16]	validation_0-mlogloss:0.00613
# [17]	validation_0-mlogloss:0.00554
# [18]	validation_0-mlogloss:0.00501
# [19]	validation_0-mlogloss:0.00453
# Saving model after iteration 17
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:33:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03378
# [1]	validation_0-mlogloss:0.02970
# [2]	validation_0-mlogloss:0.02630
# [3]	validation_0-mlogloss:0.02341
# [4]	validation_0-mlogloss:0.02090
# [5]	validation_0-mlogloss:0.01871
# [6]	validation_0-mlogloss:0.01679
# [7]	validation_0-mlogloss:0.01509
# [8]	validation_0-mlogloss:0.01357
# [9]	validation_0-mlogloss:0.01222
# [10]	validation_0-mlogloss:0.01102
# [11]	validation_0-mlogloss:0.00994
# [12]	validation_0-mlogloss:0.00897
# [13]	validation_0-mlogloss:0.00810
# [14]	validation_0-mlogloss:0.00731
# [15]	validation_0-mlogloss:0.00661
# [16]	validation_0-mlogloss:0.00597
# [17]	validation_0-mlogloss:0.00540
# [18]	validation_0-mlogloss:0.00488
# [19]	validation_0-mlogloss:0.00441
# Saving model after iteration 18
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:37:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.03134
# [1]	validation_0-mlogloss:0.02764
# [2]	validation_0-mlogloss:0.02454
# [3]	validation_0-mlogloss:0.02187
# [4]	validation_0-mlogloss:0.01955
# [5]	validation_0-mlogloss:0.01752
# [6]	validation_0-mlogloss:0.01573
# [7]	validation_0-mlogloss:0.01415
# [8]	validation_0-mlogloss:0.01273
# [9]	validation_0-mlogloss:0.01147
# [10]	validation_0-mlogloss:0.01034
# [11]	validation_0-mlogloss:0.00933
# [12]	validation_0-mlogloss:0.00842
# [13]	validation_0-mlogloss:0.00760
# [14]	validation_0-mlogloss:0.00687
# [15]	validation_0-mlogloss:0.00621
# [16]	validation_0-mlogloss:0.00561
# [17]	validation_0-mlogloss:0.00507
# [18]	validation_0-mlogloss:0.00458
# [19]	validation_0-mlogloss:0.00414
# Saving model after iteration 19
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/xgboost/callback.py:386: UserWarning: [22:42:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:0.02993
# [1]	validation_0-mlogloss:0.02640
# [2]	validation_0-mlogloss:0.02342
# [3]	validation_0-mlogloss:0.02087
# [4]	validation_0-mlogloss:0.01866
# [5]	validation_0-mlogloss:0.01672
# [6]	validation_0-mlogloss:0.01501
# [7]	validation_0-mlogloss:0.01350
# [8]	validation_0-mlogloss:0.01215
# [9]	validation_0-mlogloss:0.01094
# [10]	validation_0-mlogloss:0.00987
# [11]	validation_0-mlogloss:0.00890
# [12]	validation_0-mlogloss:0.00803
# [13]	validation_0-mlogloss:0.00725
# [14]	validation_0-mlogloss:0.00655
# [15]	validation_0-mlogloss:0.00592
# [16]	validation_0-mlogloss:0.00535
# [17]	validation_0-mlogloss:0.00484
# [18]	validation_0-mlogloss:0.00437
# [19]	validation_0-mlogloss:0.00395
# Saving model after iteration 20
# Random Forest Illness Prediction - Accuracy Score: 0.9998401710170118
# Random Forest Illness Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                            precision    recall  f1-score   support
#
#                                                 1.00      1.00      1.00    100060
#                  Chest Infection moderate       1.00      1.00      1.00         1
#                    Chest Infection severe       1.00      1.00      1.00         1
#                          Common Cold mild       1.00      1.00      1.00         5
#                      Common Cold moderate       0.73      1.00      0.84         8
#                        Common Cold severe       0.00      0.00      0.00         3
#                        Diarrhoea moderate       0.00      0.00      0.00         0
#                           Diarrhoea other       0.00      0.00      0.00         1
#                    Eye Infection moderate       0.00      0.00      0.00         2
#                              Flu moderate       0.17      1.00      0.29         2
#                                 Flu other       0.00      0.00      0.00         2
#                                Flu severe       0.00      0.00      0.00         6
#                   Headache/Migraine other       0.00      0.00      0.00         1
#                    Nausea/Vomiting severe       1.00      1.00      1.00         1
# Other - see additional information severe       1.00      1.00      1.00         3
#              Other Viral Infection severe       1.00      1.00      1.00         2
#             Sore Throat/ Tonsillitis mild       0.80      1.00      0.89         4
#         Sore Throat/ Tonsillitis moderate       0.00      0.00      0.00         1
#           Sore Throat/ Tonsillitis severe       1.00      1.00      1.00         4
#
#                                  accuracy                           1.00    100107
#                                 macro avg       0.51      0.58      0.53    100107
#                              weighted avg       1.00      1.00      1.00    100107
#
# Random Forest Illness Prediction - Confusion Matrix:
# Logistic Regression Illness Prediction - Accuracy Score: 0.9998401710170118
# Logistic Regression Illness Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                            precision    recall  f1-score   support
#
#                                                 1.00      1.00      1.00    100060
#                  Chest Infection moderate       0.33      1.00      0.50         1
#                    Chest Infection severe       1.00      1.00      1.00         1
#                          Common Cold mild       1.00      1.00      1.00         5
#                      Common Cold moderate       0.73      1.00      0.84         8
#                        Common Cold severe       0.00      0.00      0.00         3
#                        Diarrhoea moderate       0.00      0.00      0.00         0
#                           Diarrhoea other       0.00      0.00      0.00         1
#                    Eye Infection moderate       0.00      0.00      0.00         2
#                              Flu moderate       0.20      1.00      0.33         2
#                                 Flu other       0.00      0.00      0.00         2
#                                Flu severe       0.00      0.00      0.00         6
#                   Headache/Migraine other       0.00      0.00      0.00         1
# ...
#                                Flu severe       0.00      0.00      0.00         6
#                   Headache/Migraine other       0.00      0.00      0.00         1
#                    Nausea/Vomiting severe       1.00      1.00      1.00         1
# Other - see additional information severe       1.00      1.00      1.00         3
#              Other Viral Infection severe       1.00      1.00      1.00         2
#             Sore Throat/ Tonsillitis mild       0.80      1.00      0.89         4
#         Sore Throat/ Tonsillitis moderate       0.00      0.00      0.00         1
#           Sore Throat/ Tonsillitis severe       1.00      1.00      1.00         4
#
#                                  accuracy                           1.00    100107
#                                 macro avg       0.51      0.58      0.53    100107
#                              weighted avg       1.00      1.00      1.00    100107
#
# XGBoost Illness Prediction - Confusion Matrix:
# Random Forest Injury Prediction - Accuracy Score: 0.9999001068856324
# Random Forest Injury Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                           precision    recall  f1-score   support
#
#                                1.00      1.00      1.00    100034
#         Ankle Laceration       1.00      1.00      1.00         1
#              Ankle Other       1.00      1.00      1.00         1
#             Ankle Sprain       1.00      1.00      1.00        14
#             Ankle Strain       1.00      1.00      1.00         1
#              Chest Other       0.00      0.00      0.00         1
#        Elbow Dislocation       0.00      0.00      0.00         1
#      Fingers Dislocation       0.00      0.00      0.00         1
#   Fingers Fracture/Break       1.00      1.00      1.00         3
#  Fingers Fracture/Stress       0.00      0.00      0.00         0
#            Fingers Other       0.00      0.00      0.00         0
#           Fingers Sprain       0.00      0.00      0.00         2
#               Foot Other       1.00      1.00      1.00         2
#             Groin Strain       1.00      1.00      1.00         1
#         Hand Dislocation       0.00      0.00      0.00         0
#      Hand Fracture/Break       1.00      1.00      1.00         1
#              Hand Sprain       1.00      1.00      1.00         1
#          Head Concussion       1.00      1.00      1.00        10
#               Hip Strain       1.00      1.00      1.00         2
#         Knee Dislocation       0.00      0.00      0.00         1
#     Knee Fracture/Stress       0.00      0.00      0.00         1
#               Knee Other       1.00      1.00      1.00         4
#              Knee Sprain       1.00      1.00      1.00         1
#              Knee Strain       1.00      1.00      1.00         5
#   Lumbar Fracture/Stress       0.00      0.00      0.00         1
#             Lumbar Other       1.00      1.00      1.00         2
#            Lumbar Strain       1.00      1.00      1.00         3
#  Other - see notes Other       0.00      0.00      0.00         0
# Other - see notes Sprain       1.00      1.00      1.00         1
#     Ribs Fracture/Stress       0.00      0.00      0.00         0
#     Shoulder Dislocation       0.00      0.00      0.00         0
#          Shoulder Strain       1.00      1.00      1.00         7
#     Shoulder Subluxation       1.00      1.00      1.00         1
#             Thumb Sprain       1.00      1.00      1.00         1
#          Upper Leg Other       1.00      1.00      1.00         1
#     Wrist Fracture/Break       0.00      0.00      0.00         2
#             Wrist Sprain       0.00      0.00      0.00         0
#
#                 accuracy                           1.00    100107
#                macro avg       0.59      0.59      0.59    100107
#             weighted avg       1.00      1.00      1.00    100107
#
# Random Forest Injury Prediction - Confusion Matrix:
# Logistic Regression Injury Prediction - Accuracy Score: 0.9999001068856324
# Logistic Regression Injury Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                    precision    recall  f1-score   support
#
#                                         1.00      1.00      1.00    100034
#                  Ankle Laceration       1.00      1.00      1.00         1
#                       Ankle Other       1.00      1.00      1.00         1
#                      Ankle Sprain       1.00      1.00      1.00        14
#                      Ankle Strain       1.00      1.00      1.00         1
#                       Chest Other       0.00      0.00      0.00         1
#                 Elbow Dislocation       0.00      0.00      0.00         1
#                      Elbow Sprain       0.00      0.00      0.00         0
#               Fingers Dislocation       0.00      0.00      0.00         1
#            Fingers Fracture/Break       1.00      1.00      1.00         3
#           Fingers Fracture/Stress       0.00      0.00      0.00         0
#                     Fingers Other       0.00      0.00      0.00         0
#                    Fingers Sprain       0.00      0.00      0.00         2
#                        Foot Other       1.00      1.00      1.00         2
#                      Groin Strain       1.00      1.00      1.00         1
#               Hand Fracture/Break       1.00      1.00      1.00         1
#                       Hand Sprain       1.00      1.00      1.00         1
#                   Head Concussion       1.00      1.00      1.00        10
#                        Hip Strain       1.00      1.00      1.00         2
#                  Knee Dislocation       0.00      0.00      0.00         1
#              Knee Fracture/Stress       0.00      0.00      0.00         1
#                        Knee Other       1.00      1.00      1.00         4
#                       Knee Sprain       1.00      1.00      1.00         1
#                       Knee Strain       1.00      1.00      1.00         5
#            Lumbar Fracture/Stress       0.00      0.00      0.00         1
#                      Lumbar Other       1.00      1.00      1.00         2
#                     Lumbar Strain       1.00      1.00      1.00         3
# Other - see notes Fracture/Stress       0.00      0.00      0.00         0
#           Other - see notes Other       0.00      0.00      0.00         0
#          Other - see notes Sprain       1.00      1.00      1.00         1
#              Shoulder Dislocation       0.00      0.00      0.00         0
#                   Shoulder Strain       1.00      1.00      1.00         7
#              Shoulder Subluxation       1.00      1.00      1.00         1
#                      Thumb Sprain       1.00      1.00      1.00         1
#                   Upper Leg Other       1.00      1.00      1.00         1
#              Wrist Fracture/Break       0.00      0.00      0.00         2
#                      Wrist Sprain       0.00      0.00      0.00         0
#
#                          accuracy                           1.00    100107
#                         macro avg       0.59      0.59      0.59    100107
#                      weighted avg       1.00      1.00      1.00    100107
#
# Logistic Regression Injury Prediction - Confusion Matrix:
# XGBoost Injury Prediction - Accuracy Score: 0.9999001068856324
# XGBoost Injury Prediction - Classification Report:
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/dingyangzuo/miniconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                           precision    recall  f1-score   support
#
#                                1.00      1.00      1.00    100034
#         Ankle Laceration       1.00      1.00      1.00         1
#              Ankle Other       1.00      1.00      1.00         1
#             Ankle Sprain       1.00      1.00      1.00        14
#             Ankle Strain       1.00      1.00      1.00         1
#              Chest Other       0.00      0.00      0.00         1
#        Elbow Dislocation       0.00      0.00      0.00         1
#       Eye Fracture/Break       0.00      0.00      0.00         0
#         Fingers Abrasion       0.00      0.00      0.00         0
#      Fingers Dislocation       0.00      0.00      0.00         1
#   Fingers Fracture/Break       1.00      1.00      1.00         3
#           Fingers Sprain       0.00      0.00      0.00         2
#               Foot Other       1.00      1.00      1.00         2
#             Groin Strain       1.00      1.00      1.00         1
#         Hand Dislocation       0.00      0.00      0.00         0
#      Hand Fracture/Break       1.00      1.00      1.00         1
#              Hand Sprain       1.00      1.00      1.00         1
#          Head Concussion       1.00      1.00      1.00        10
#               Hip Strain       1.00      1.00      1.00         2
#         Knee Dislocation       0.00      0.00      0.00         1
#     Knee Fracture/Stress       0.00      0.00      0.00         1
#          Knee Laceration       0.00      0.00      0.00         0
#               Knee Other       1.00      1.00      1.00         4
#              Knee Sprain       1.00      1.00      1.00         1
#              Knee Strain       1.00      1.00      1.00         5
#   Lumbar Fracture/Stress       0.00      0.00      0.00         1
#             Lumbar Other       1.00      1.00      1.00         2
#            Lumbar Sprain       0.00      0.00      0.00         0
#            Lumbar Strain       1.00      1.00      1.00         3
#  Other - see notes Other       0.00      0.00      0.00         0
# Other - see notes Sprain       1.00      1.00      1.00         1
#     Shoulder Dislocation       0.00      0.00      0.00         0
#          Shoulder Strain       1.00      1.00      1.00         7
#     Shoulder Subluxation       1.00      1.00      1.00         1
#             Thumb Sprain       1.00      1.00      1.00         1
#          Upper Leg Other       1.00      1.00      1.00         1
#     Wrist Fracture/Break       0.00      0.00      0.00         2
#
#                 accuracy                           1.00    100107
#                macro avg       0.59      0.59      0.59    100107
#             weighted avg       1.00      1.00      1.00    100107
#
# XGBoost Injury Prediction - Confusion Matrix:
